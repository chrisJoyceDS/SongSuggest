# %% [markdown]
# # Spotipy: Get My Tracks and Audio Features
# ___

# %% [markdown]
# ## Introduction
# This project evolved several times over the course of the 5 weeks we had to work on it. This Introduction is a high level overview of my plans as they evolved and ultimately how the final product came to fruition. Hopefully these sections will help the reader navigate the notebooks in a way that is readable.<br>
# `Version 1`:
# - My original idea was around collaborative filtering and creating a network based on different users data. I was planning on authenticating 3rd Party Users via Spotify Oauth, and only request access to their library, their playlists, who they followed, who followed them, and the top tracks of each other user.
# - With this information create a network with Users being the origin point, and further breaking down into nodes for Artists, Albums, Tracks, and Genres with different nodes having different metadata and descriptive data made available by Spotify.
# - With this network, calculate and manipulate song suggestions based on the mean vector of a given set of tracks depending on how you filtered the network.
# - Unfortunately, after spending several weeks exploring different articles and walkthroughs of Collaborative Filtering and working on Spotify Oauth protocols, I found out that other user data is not actually available via a user's session. <br>
# `Version 2`:
# - Having learned that gathering data from multiple users was not a possibility, I attempted to pivot to a similar form of recommendation which was Content Based Filtering.
# - While I couldn't get other users information, I could get a lot of information and track information from a given profile. This could set me up well in relation to Content Based Filtering which recommends items by comparing the content of items and their relation to a user profile. For track data this could be split between explicit, implicit, and general interactions.
# - Explicit interactions would be any tracks that a user actively saved or was one of their top tracks e.g. the frequency of play over other songs could be interpreted as liking.
# - Implicit interactions would be any tracks that a user listened to but didnt explicitly like, which came from any playlists the users owned or followed, on top of the top tracks of any artist they followed.
# - General Pool was based on songs that were available to a given user based on their current Locale/Market ('US' for example)
# - This would creat our user profile on top of the library of tracks that existed in a given users profile.
# - However, after researching a couple of articles like https://towardsdatascience.com/introduction-to-two-approaches-of-content-based-recommendation-system-fc797460c18c and reading their notebooks, I realized:
#     - A: This wasn't exactly what I was trying to execute on which was identifying a mean vector of audio features to produce a signal of recommendations
#     - B: The techniques described weren't using any machine learning
# - Separately but in parallel, after trying to push my application code onto rendor for hosting the application, I quickly found some dependencies in relation to user authentication, redirect uris, and what streamlit/render allow within their libraries. This required me to pivot again, but in a way that I can plan for the future.<br>
# `Version 3`:
# - Create an application that doesnt authenticate 3rd Party users, but gets an access token to interact server to server. This still allows me to interact with certain API endpoints from Spotify that get tracks, audio features, artists, and genres.
# - This application will serve as a version 1 that can ultimately be built upon to create the original version down the line. Instead of pulling a user's profile, we will give the user 3 options, to get recommendations by:
#     - Track Names, Artists, Release Year
#     - Artist Names
#     - Genres
# - With each option the application would call the required endpoint to either pull the specific tracks provided by users, pull the top tracks from provided artists, pull 20 tracks per genre listed.
# - From there find the Mean Vector of the pulled track audio features, and use that mean vector to capture the closest cosine distances in relation to a scaled track data library of 400k songs.
# - There ultimately were some complications with this final version but we will get into those as the notebook progresses.

# %% [markdown]
# ___
# # Version 2&3 Data Collection: Unsupervised K-Means Clustering

# %% [markdown]
# - After pulling some of my own user data, tracks, playlists, etc. I was able to do some EDA to identify how my music taste follows an audio track pattern/frequency across the different audio track features.
# - I was even able to pull some initial scores from some classification models with different tuned hyper parameters as well as different pre-processed methods (Standard Scaler and Polynomial Features).
# - In either models case, none of them came close to beating the baseline score of my liked songs and songs from my profile (~75%).
# - As such, I am going back to pull even more data and try and pull as much track data as I can from one user.
# - I am going to represent a users explicit and implicit taste through:
#     - Explicit: Liked Songs, user took action on each track
#     - Explicit: Songs from playlists they created themselves or follow, user took action to make something with these songs or liked enough of the songs to follow the playlist
#     - Implicit: Songs from Artists they follow, like playlists, but users are not often the artists, and the library of songs under an Artist is more expansive than an individual playlist.
#     - Implicit: Songs from Artists who they may not follow, but have liked songs from them before
#     - General Pool: Featured Playlists and their songs which are made available by the profile
#     - General Pool: Category playlists and their songs which are made avilalbe by the profile
# - Combined with "One Hot Encoded" genres per track this will not only give us our signal, but the noise as well.

# %% [markdown]
# ### Handler FLow

# %% [markdown]
# - I want to be able to scale this application in the future, and I want to be able to add other features that might require different authentication scopes, I created a handler function.
# - Throughout this notebook and other notebooks where we interact with Spotify/Spotipy, we will call the handler to pull the required data
# - The first call in any handler call is to our authenticate function that:
#     - creates a SpotifyOAuth session
#     - checks if we have a cached token within that session
#     - and if not, generates a new token for us to use
#     - this handler function will be the basis of interactions on the webapp for simplicitity and scale
# - Code can be found in get_tracks_methods

# %%
# !pip3 install more_itertools

# %%
import pandas as pd
from get_tracks_methods import handler, authenticate, flatten_tracks,\
get_track_audio_features, merger
import time
from concurrent.futures import ThreadPoolExecutor
from more_itertools import chunked

# %% [markdown]
# Let's use the handler to pull my Liked Songs and turn them into a flattened dataframe:

# %% [markdown]
# ___
# ### Explicit Tracks: Tracks a user has saved

# %%
# %%time
user_liked_songs = handler("get_saved_tracks")
# Out:
# CPU times: user 427 ms, sys: 74 ms, total: 501 ms
# Wall time: 10.6 s

# %%
user_liked_songs.head()
# Out:
#                        id            track_name   artist  \
# 0  1nFtiJxYdhtFfFtfXBv06s  Something In The Way  Nirvana
# 1  5Ddlk6C2JVxb1SReZ6O1wk             Drain You  Nirvana
# 2  4l012k8ZcAdVbUvZ4kae5Q             Stay Away  Nirvana
# 3  2YodwKJnbPyNKe8XXSE9V7               Lithium  Nirvana
# 4  4P5KoWXOxwuobLmHXLMobV       Come As You Are  Nirvana
#
#                               artist_uri  \
# 0  spotify:artist:6olE6TJLqED3rqDCT0FyPh
# 1  spotify:artist:6olE6TJLqED3rqDCT0FyPh
# 2  spotify:artist:6olE6TJLqED3rqDCT0FyPh
# 3  spotify:artist:6olE6TJLqED3rqDCT0FyPh
# 4  spotify:artist:6olE6TJLqED3rqDCT0FyPh
#
#                               album_uri                   album release_date  \
# 0  spotify:album:2guirTSEqLizK7j9i1MTTZ  Nevermind (Remastered)   1991-09-26
# 1  spotify:album:2guirTSEqLizK7j9i1MTTZ  Nevermind (Remastered)   1991-09-26
# 2  spotify:album:2guirTSEqLizK7j9i1MTTZ  Nevermind (Remastered)   1991-09-26
# 3  spotify:album:2guirTSEqLizK7j9i1MTTZ  Nevermind (Remastered)   1991-09-26
# 4  spotify:album:2guirTSEqLizK7j9i1MTTZ  Nevermind (Remastered)   1991-09-26
#
#    popularity  explicit  user_liked
# 0          73     False           1
# 1          63     False           1
# 2          56     False           1
# 3          72     False           1
# 4          78     False           1

# %% [markdown]
# - Now having retrieved our saved tracks, let's add columns for playlist_name and user_liked to signify our user's explicit interaction with these recrods.

# %%
user_liked_songs['user_liked'] = 1

# %%
user_liked_songs.head()
# Out:
#                        id            track_name   artist  \
# 0  1nFtiJxYdhtFfFtfXBv06s  Something In The Way  Nirvana
# 1  5Ddlk6C2JVxb1SReZ6O1wk             Drain You  Nirvana
# 2  4l012k8ZcAdVbUvZ4kae5Q             Stay Away  Nirvana
# 3  2YodwKJnbPyNKe8XXSE9V7               Lithium  Nirvana
# 4  4P5KoWXOxwuobLmHXLMobV       Come As You Are  Nirvana
#
#                               artist_uri  \
# 0  spotify:artist:6olE6TJLqED3rqDCT0FyPh
# 1  spotify:artist:6olE6TJLqED3rqDCT0FyPh
# 2  spotify:artist:6olE6TJLqED3rqDCT0FyPh
# 3  spotify:artist:6olE6TJLqED3rqDCT0FyPh
# 4  spotify:artist:6olE6TJLqED3rqDCT0FyPh
#
#                               album_uri                   album release_date  \
# 0  spotify:album:2guirTSEqLizK7j9i1MTTZ  Nevermind (Remastered)   1991-09-26
# 1  spotify:album:2guirTSEqLizK7j9i1MTTZ  Nevermind (Remastered)   1991-09-26
# 2  spotify:album:2guirTSEqLizK7j9i1MTTZ  Nevermind (Remastered)   1991-09-26
# 3  spotify:album:2guirTSEqLizK7j9i1MTTZ  Nevermind (Remastered)   1991-09-26
# 4  spotify:album:2guirTSEqLizK7j9i1MTTZ  Nevermind (Remastered)   1991-09-26
#
#    popularity  explicit  user_liked
# 0          73     False           1
# 1          63     False           1
# 2          56     False           1
# 3          72     False           1
# 4          78     False           1

# %% [markdown]
# - Only one more group of songs for our explicit interaction and we can move onto implicit and general pool tracks. Let's grab the current users playlists owned and/or followed including their associated tracks:

# %%
# %%time
user_playlist_songs = handler("get_user_playlist_tracks")
# Out:
# Please authorize the app by visiting this URL: https://accounts.spotify.com/authorize?client_id=fd5183b4728840a989108098987ef843&response_type=code&redirect_uri=http%3A%2F%2Flocalhost%3A8080%2Fcallback&scope=user-library-read+playlist-read-private
# Enter the authorization code:  AQB9AujTu5kCTjg4M3AAAA_CdE4VclNw_4MqK2mZqX3Ph589ta31AqgtUXonumHO8L8MidM6bzN6jl8fd_3eg4f9uySu76sEAPdt4MRrlf-hly89iLblfsZmoq4m0BeHgVjxeLV2Tqefhq_iSsV67STqYio9IrGWtQm5rwYD5ZB1L1-hGAg-Rzm29RbO5PEAPqBXJ7FIiwHtMIc02PQrqU70R8KtNqGRFF7mYg
# CPU times: user 773 ms, sys: 158 ms, total: 931 ms
# Wall time: 27.3 s

# %%
user_playlist_songs.head()
# Out:
#                        id                          track_name  \
# 0  1pUsdir2xhSxP0RyBe9lLH                              Icarus
# 1  3H3cOQ6LBLSvmcaV7QkZEu                         Aerodynamic
# 2  7sLnn2UOttrEPBZSFyIsYh             Wolfgang's 5th Symphony
# 3  3ezkJgagRPZ39KCTrKcSI7  Ghosts 'n' Stuff (feat. Rob Swire)
# 4  0VffaI2jwQknRrxpECYHsF                           Greyhound
#
#                 artist                             artist_uri  \
# 0               Madeon  spotify:artist:4pb4rqWSoGUgxm63xmJ8xc
# 1            Daft Punk  spotify:artist:4tZwfgrHOc3mvqYlEYSvVi
# 2     Wolfgang Gartner  spotify:artist:3534yWWzmxx8NbKVoNolsK
# 3             deadmau5  spotify:artist:2CIMQHirSU0MQqyYHq0eOx
# 4  Swedish House Mafia  spotify:artist:1h6Cn3P4NGzXbaXidqURXs
#
#                               album_uri  \
# 0  spotify:album:3uKLwDjku2Us0c81LEmftR
# 1  spotify:album:2noRn2Aes5aoNVsU6iWThc
# 2  spotify:album:3kDILp9v0rDVPMAJUQYbZx
# 3  spotify:album:3eNZDL2rqTVvmiC1f0yFwF
# 4  spotify:album:4ljisoNarj0BpQSMIEv88L
#
#                                             album release_date  popularity  \
# 0                              Adventure (Deluxe)   2015-03-30          49
# 1                                       Discovery   2001-03-12          62
# 2                                      Back Story   2012-09-04          43
# 3  For Lack of a Better Name (The Extended Mixes)         2009          62
# 4                                       Until Now   2012-01-01          64
#
#    explicit  user_liked
# 0     False           1
# 1     False           1
# 2     False           1
# 3     False           1
# 4     False           1

# %%
user_playlist_songs.shape, user_liked_songs.shape
# Out:
# ((2396, 10), (643, 10))

# %% [markdown]
# - Let's combine into one df to have our explicit interactions df

# %%
user_exp_tracks = pd.concat([user_liked_songs, user_playlist_songs])

# %%
user_exp_tracks.shape
# Out:
# (3039, 10)

# %%
user_exp_tracks.drop_duplicates(subset=['id'],inplace=True)

# %%
user_exp_tracks.to_csv('../data/explicit_tracks.csv')

# %% [markdown]
# - Successfully captured our tracks where the user has explicitly shown interest in whether by saving individually, adding to a playlist they created themselves/own, or are frome a playlist they chose to follow.
#
# Now to collect implicit:
# - Implicit: Songs from Artists they follow, like playlists, but users are not often the artists, and the library of songs under an Artist is more expansive than an individual playlist.
# - Implicit: Songs from Artists who they may not follow, but have liked songs from them before

# %% [markdown]
# ___
# ### Implicit Tracks

# %% [markdown]
# - Collect all available Artists from our liked songs

# %%
artists = user_liked_songs['artist_uri']

# %%
sp = authenticate(scope='user-library-read user-follow-read')
# Out:
# Please authorize the app by visiting this URL: https://accounts.spotify.com/authorize?client_id=fd5183b4728840a989108098987ef843&response_type=code&redirect_uri=http%3A%2F%2Flocalhost%3A8080%2Fcallback&scope=user-library-read+user-follow-read
# Enter the authorization code:  AQBMCeoR_mkm_GhCS5tLfQJsHt4FSuL9V_VbDGufNS74Xmnka8fcLqOFuzVmubAqnHrLGs6OGEbmrPdujloTJs5qD52Pm84Tcr3dccxm1QF0XMkGbyqKywbEWeyXZ7Yatm9tNYe119jygKQckOqQZ_qi8Y2PFLCWDt3faIHeKaET8DEzhThT4Z3dxe6i5GgMU-8IwLf9N-TXqmefn8AeGcRgZ8QHhpU

# %% [markdown]
# - Collect all Artists a given user follows

# %%
followed_artists = sp.current_user_followed_artists(limit=50)

# %%
temp_artists = []
for artist in followed_artists['artists']['items']:
    temp_artists.append(artist['uri'])
    
temp = pd.Series(temp_artists)

# %%
imp_artists = pd.concat([artists,temp])

# %%
imp_artists
# Out:
# 0     spotify:artist:6olE6TJLqED3rqDCT0FyPh
# 1     spotify:artist:6olE6TJLqED3rqDCT0FyPh
# 2     spotify:artist:6olE6TJLqED3rqDCT0FyPh
# 3     spotify:artist:6olE6TJLqED3rqDCT0FyPh
# 4     spotify:artist:6olE6TJLqED3rqDCT0FyPh
#                       ...
# 27    spotify:artist:65c0gzsw9JsPUxm09QPjQj
# 28    spotify:artist:6P7H3ai06vU1sGvdpBwDmE
# 29    spotify:artist:6a1696QGUkDJgGuJHwS3zS
# 30    spotify:artist:70cRZdQywnSFp9pnc2WTCE
# 31    spotify:artist:73sIBHcqh3Z3NyqHKZ7FOL
# Length: 675, dtype: object

# %%
imp_artists.shape
# Out:
# (675,)

# %%
imp_artists.drop_duplicates(inplace=True)

# %%
imp_artists
# Out:
# 0     spotify:artist:6olE6TJLqED3rqDCT0FyPh
# 7     spotify:artist:3hyGGjxu73JuzBa757H6R5
# 8     spotify:artist:6V70yeZQCoSR2M3fyW8qiA
# 9     spotify:artist:5KeQyt1QJBjcutJ2AuLNO2
# 10    spotify:artist:4gzpq5DPGxSnKTe4SA8HAU
#                       ...
# 24    spotify:artist:5d4LM8c0ZhuhXFwZKs6lXR
# 25    spotify:artist:5h0EnezM11vvxMuGuGd7wJ
# 28    spotify:artist:6P7H3ai06vU1sGvdpBwDmE
# 29    spotify:artist:6a1696QGUkDJgGuJHwS3zS
# 30    spotify:artist:70cRZdQywnSFp9pnc2WTCE
# Length: 332, dtype: object

# %%
imp_artists.shape
# Out:
# (332,)

# %% [markdown]
# - Function to pull artists top tracks from list of implicit artists

# %%
tracks = []
for artist_uri in imp_artists:
    
    artist_tracks = sp.artist_top_tracks(artist_id=artist_uri)
    tracks.extend(artist_tracks['tracks'])

# %% [markdown]
# - First Item of Artist Top Tracks Collection

# %%
tracks[0]
# Out:
# {'album': {'album_group': 'album',
#   'album_type': 'album',
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6olE6TJLqED3rqDCT0FyPh'},
#     'href': 'https://api.spotify.com/v1/artists/6olE6TJLqED3rqDCT0FyPh',
#     'id': '6olE6TJLqED3rqDCT0FyPh',
#     'name': 'Nirvana',
#     'type': 'artist',
#     'uri': 'spotify:artist:6olE6TJLqED3rqDCT0FyPh'}],
#   'external_urls': {'spotify': 'https://open.spotify.com/album/2guirTSEqLizK7j9i1MTTZ'},
#   'href': 'https://api.spotify.com/v1/albums/2guirTSEqLizK7j9i1MTTZ',
#   'id': '2guirTSEqLizK7j9i1MTTZ',
#   'images': [{'height': 640,
#     'url': 'https://i.scdn.co/image/ab67616d0000b273e175a19e530c898d167d39bf',
#     'width': 640},
#    {'height': 300,
#     'url': 'https://i.scdn.co/image/ab67616d00001e02e175a19e530c898d167d39bf',
#     'width': 300},
#    {'height': 64,
#     'url': 'https://i.scdn.co/image/ab67616d00004851e175a19e530c898d167d39bf',
#     'width': 64}],
#   'is_playable': True,
#   'name': 'Nevermind (Remastered)',
#   'release_date': '1991-09-26',
#   'release_date_precision': 'day',
#   'total_tracks': 13,
#   'type': 'album',
#   'uri': 'spotify:album:2guirTSEqLizK7j9i1MTTZ'},
#  'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6olE6TJLqED3rqDCT0FyPh'},
#    'href': 'https://api.spotify.com/v1/artists/6olE6TJLqED3rqDCT0FyPh',
#    'id': '6olE6TJLqED3rqDCT0FyPh',
#    'name': 'Nirvana',
#    'type': 'artist',
#    'uri': 'spotify:artist:6olE6TJLqED3rqDCT0FyPh'}],
#  'disc_number': 1,
#  'duration_ms': 301920,
#  'explicit': False,
#  'external_ids': {'isrc': 'USGF19942501'},
#  'external_urls': {'spotify': 'https://open.spotify.com/track/5ghIJDpPoe3CfHMGu71E6T'},
#  'href': 'https://api.spotify.com/v1/tracks/5ghIJDpPoe3CfHMGu71E6T',
#  'id': '5ghIJDpPoe3CfHMGu71E6T',
#  'is_local': False,
#  'is_playable': True,
#  'name': 'Smells Like Teen Spirit',
#  'popularity': 80,
#  'preview_url': 'https://p.scdn.co/mp3-preview/91219ebc0d0505a1001c4b854f8b2451fcec95b8?cid=fd5183b4728840a989108098987ef843',
#  'track_number': 1,
#  'type': 'track',
#  'uri': 'spotify:track:5ghIJDpPoe3CfHMGu71E6T'}

# %% [markdown]
# - Before we created this as a function in get_track_methods.py it was plain text
# - Creates a dictionary per track in a list pulling out certain metadata features for further data collection such as audio features

# %%
flattened_tracks = []

for track in tracks:
    
    try:

        flattened_track = {
                "id": track["id"],
                "track_name": track["name"],
                "artist": track["artists"][0]["name"],
                "artist_uri": track["artists"][0]["uri"],
                "album_uri": track["album"]["uri"],
                "album": track["album"]["name"],
                "release_date": track["album"]["release_date"],
                "popularity": track["popularity"],
                "explicit": track["explicit"],
                "user_liked": 0
            }

        flattened_tracks.append(flattened_track)
    except:
        continue

# %%
len(flattened_tracks)
# Out:
# 3260

# %%
implicit_tracks = pd.DataFrame(flattened_tracks)

# %%
user_exp_tracks.shape, implicit_tracks.shape
# Out:
# ((2518, 10), (3260, 10))

# %% [markdown]
# - After collecting examples of both explicit and implicit tracks, combine to create a new collection of tracks for the mean vector

# %%
exp_imp_tracks = pd.concat([user_exp_tracks, implicit_tracks])

# %%
exp_imp_tracks.shape
# Out:
# (5778, 10)

# %% [markdown]
# - Sort values by the user liked column, in descending order
# - user_liked is a feature used to designate if the user explicitly or implicitly interatcted with a given track

# %%
exp_imp_tracks.sort_values(by=['user_liked'],ascending=False)
# Out:
#                           id                                       track_name  \
# 0     1nFtiJxYdhtFfFtfXBv06s                             Something In The Way
# 1464  3BCe21LqWVOWWDfHjuoeeR                         Nightcall - From "Drive"
# 1457  19L0jgD9mr8QOy9kxr7LZS  Total Eclipse of the Heart (feat. Simply Three)
# 1458  6Pk7XpaiMsXAM6dXN3kQEo                                         Firework
# 1459  0zOI6bMCkjd10vCrDy3voc                           Wellerman (arr. piano)
# ...                      ...                                              ...
# 1089  3C41w4YPDCfGuxzQNjvk8O                                  Quality Control
# 1090  2IdUqeF20MzmtyetmQCRU6                                    High Fidelity
# 1091  4zVtyyuXiLAzSs9I5meIyO                                            Jayou
# 1092  0XtcvtK0d2dbBZSBQIP7XU                                        Thin Line
# 3259  0dzbfio3qTYG9uk40SJNcr     The 59th Street Bridge Song (Feelin' Groovy)
#
#                       artist                             artist_uri  \
# 0                    Nirvana  spotify:artist:6olE6TJLqED3rqDCT0FyPh
# 1464         Thibault Cauvin  spotify:artist:6d81rjlV6r9u8qPMAjavRV
# 1457  Vitamin String Quartet  spotify:artist:6MERXsiRbur2oJZFgYRDKz
# 1458            Jeremy Green  spotify:artist:32jiRxDN9Nb9QbXh88uo42
# 1459    Music Lab Collective  spotify:artist:1ylcY77FWeSVQKh5et1VGp
# ...                      ...                                    ...
# 1089              Jurassic 5  spotify:artist:6wFId9Jhuf9AKVzWboOj2B
# 1090              Jurassic 5  spotify:artist:6wFId9Jhuf9AKVzWboOj2B
# 1091              Jurassic 5  spotify:artist:6wFId9Jhuf9AKVzWboOj2B
# 1092              Jurassic 5  spotify:artist:6wFId9Jhuf9AKVzWboOj2B
# 3259       Simon & Garfunkel  spotify:artist:70cRZdQywnSFp9pnc2WTCE
#
#                                  album_uri  \
# 0     spotify:album:2guirTSEqLizK7j9i1MTTZ
# 1464  spotify:album:3j4Luk2uwaiahexJJUIioz
# 1457  spotify:album:0sZwPaM40mIDElKRmnYvAb
# 1458  spotify:album:7wBmPhdZlYiDa4h6rGDSbG
# 1459  spotify:album:1f9nDMa1wlNsPxDtygkg4B
# ...                                    ...
# 1089  spotify:album:4ePjDIN5keSHlmc93FKN0r
# 1090  spotify:album:7HvVxQBTNKoxY2aLexcEQH
# 1091  spotify:album:5Lj4qWG2xATA2XNz3l6BZT
# 1092  spotify:album:7HvVxQBTNKoxY2aLexcEQH
# 3259  spotify:album:1sh32o99zA04PJIUJUpEj7
#
#                                                 album release_date  \
# 0                              Nevermind (Remastered)   1991-09-26
# 1464                         Nightcall (From "Drive")   2021-04-23
# 1457  Total Eclipse of the Heart (feat. Simply Three)   2021-05-21
# 1458                                         Firework   2022-01-21
# 1459                           Wellerman (arr. piano)   2021-07-30
# ...                                               ...          ...
# 1089                                  Quality Control   2000-01-01
# 1090                                 Power In Numbers   2002-01-01
# 1091                              J5 (Deluxe Edition)   2008-02-06
# 1092                                 Power In Numbers   2002-01-01
# 3259                Parsley, Sage, Rosemary And Thyme   1966-10-10
#
#       popularity  explicit  user_liked
# 0             73     False           1
# 1464          45     False           1
# 1457          46     False           1
# 1458          43     False           1
# 1459          48     False           1
# ...          ...       ...         ...
# 1089          44     False           0
# 1090          42     False           0
# 1091          49      True           0
# 1092          42     False           0
# 3259          65     False           0
#
# [5778 rows x 10 columns]

# %% [markdown]
# - We sorted by user_liked in order to drop duplicates in case there was any cross over from the implicit tracks and explicit tracks.
# - IF there are duplicates, we want to preserve the explicit track as it is of a higher order data wise

# %%
exp_imp_tracks.drop_duplicates(subset=['id'],keep='first',inplace=True)

# %%
exp_imp_tracks[exp_imp_tracks['user_liked']==1].shape
# Out:
# (2518, 10)

# %% [markdown]
# - Save explicit implicit track library

# %%
exp_imp_tracks.to_csv('../data/explicit_implicit_tracks.csv')

# %% [markdown]
# Successfully pulled 3k additional songs for the implicit library. Finally let's pull from featured playlists and category playlists

# %% [markdown]
# ### General Tracks
# - General Pool: Featured Playlists and their songs which are made available by the profile
#     - Country/Market
#     - limit 50
# - General Pool: Category playlists and their songs which are made avilalbe by the profile
#     - Get Several Browse Categories
#     - For each category, pull category playlist
#         - both need Country/Market
#         - Each have a limit of 50

# %% [markdown]
# ___
# ### Featured Playlists

# %%
sp = authenticate(scope='user-read-private')
# Out:
# Please authorize the app by visiting this URL: https://accounts.spotify.com/authorize?client_id=fd5183b4728840a989108098987ef843&response_type=code&redirect_uri=http%3A%2F%2Flocalhost%3A8080%2Fcallback&scope=user-read-private
# Enter the authorization code:  AQA1cVjLFLfRy-yy4pcfkieKFOhszfAOw-TUsGm2LL_vLbpaX-z2OClFIMTAwOxZnh2fadOFXOdHArL2Ql3vhFwwNwPX-Z3i4eW8qGu8ocxabdPz6MTS3OJOQEmZIuq7r8qfxYe3Eh5LJVQYKxP3lGDVpwabWcw95NZM9RXvUvT8y5fyrjsDboRqWJmEwjVyPlQNN8g

# %%
current_market = sp.current_user()['country']

# %%
current_market
# Out:
# 'US'

# %% [markdown]
# - Gather featured playlists within a given market, my given market is the US

# %%
featured_playlists = sp.featured_playlists(country=current_market, limit=50)

# %%
featured_playlists = featured_playlists['playlists']['items']

# %%
featured_playlists
# Out:
# [{'collaborative': False,
#   'description': 'Relax with these timeless tunes. Cover: John Denver',
#   'external_urls': {'spotify': 'https://open.spotify.com/playlist/37i9dQZF1DWTQwRw56TKNc'},
#   'href': 'https://api.spotify.com/v1/playlists/37i9dQZF1DWTQwRw56TKNc',
#   'id': '37i9dQZF1DWTQwRw56TKNc',
#   'images': [{'height': None,
#     'url': 'https://i.scdn.co/image/ab67706f00000003a83b6c9332a62267ed6d4f5f',
#     'width': None}],
#   'name': 'Mellow Classics',
#   'owner': {'display_name': 'Spotify',
#    'external_urls': {'spotify': 'https://open.spotify.com/user/spotify'},
#    'href': 'https://api.spotify.com/v1/users/spotify',
#    'id': 'spotify',
#    'type': 'user',
#    'uri': 'spotify:user:spotify'},
#   'primary_color': None,
#   'public': None,
#   'snapshot_id': 'MTY3NTEwMjE2NSwwMDAwMDAwMDdkYWI0MzAxYTEzYTY0NjNkZWJmNzAxNGQ2Zjg0MDg1',
#   'tracks': {'href': 'https://api.spotify.com/v1/playlists/37i9dQZF1DWTQwRw56TKNc/tracks',
#    'total': 70},
#   'type': 'playlist',
#   'uri': 'spotify:playlist:37i9dQZF1DWTQwRw56TKNc'},
#  {'collaborative': False,
#   'description': 'Get into a morning flow with this focus playlist.',
#   'external_urls': {'spotify': 'https://open.spotify.com/playlist/37i9dQZF1DX6T5dWVv97mp'},
#   'href': 'https://api.spotify.com/v1/playlists/37i9dQZF1DX6T5dWVv97mp',
#   'id': '37i9dQZF1DX6T5dWVv97mp',
#   'images': [{'height': None,
#     'url': 'https://i.scdn.co/image/ab67706f0000000322a60413dd16e2fec72b1239',
#     'width': None}],
#   'name': 'Productive Morning',
#   'owner': {'display_name': 'Spotify',
#    'external_urls': {'spotify': 'https://open.spotify.com/user/spotify'},
#    'href': 'https://api.spotify.com/v1/users/spotify',
#    'id': 'spotify',
#    'type': 'user',
#    'uri': 'spotify:user:spotify'},
#   'primary_color': None,
#   'public': None,
#   'snapshot_id': 'MTY4MzI5OTM1OCwwMDAwMDAwMDEzNDJlOGZiMjYxOTJjMjhkZjZkODNmMjgzNWZmOTAx',
#   'tracks': {'href': 'https://api.spotify.com/v1/playlists/37i9dQZF1DX6T5dWVv97mp/tracks',
#    'total': 98},
#   'type': 'playlist',
#   'uri': 'spotify:playlist:37i9dQZF1DX6T5dWVv97mp'},
#  {'collaborative': False,
#   'description': 'Recent hits and new songs from your fave artists. Cover: Bebe Rexha & Dolly Parton',
#   'external_urls': {'spotify': 'https://open.spotify.com/playlist/37i9dQZF1DX0b1hHYQtJjp'},
#   'href': 'https://api.spotify.com/v1/playlists/37i9dQZF1DX0b1hHYQtJjp',
#   'id': '37i9dQZF1DX0b1hHYQtJjp',
#   'images': [{'height': None,
#     'url': 'https://i.scdn.co/image/ab67706f000000031476bb7dddbd2ce04b59edcc',
#     'width': None}],
#   'name': 'Just Good Music',
#   'owner': {'display_name': 'Spotify',
#    'external_urls': {'spotify': 'https://open.spotify.com/user/spotify'},
#    'href': 'https://api.spotify.com/v1/users/spotify',
#    'id': 'spotify',
#    'type': 'user',
#    'uri': 'spotify:user:spotify'},
#   'primary_color': None,
#   'public': None,
#   'snapshot_id': 'MTY4MzI1OTIwMCwwMDAwMDAwMGRkMTZlYmFlZGM1YjFmZGQ1ZTRhOTdmM2IxMTg2Njc2',
#   'tracks': {'href': 'https://api.spotify.com/v1/playlists/37i9dQZF1DX0b1hHYQtJjp/tracks',
#    'total': 80},
#   'type': 'playlist',
#   'uri': 'spotify:playlist:37i9dQZF1DX0b1hHYQtJjp'},
#  {'collaborative': False,
#   'description': 'The official voice of the next generation. Cover: <a href="spotify:artist:57n1OF36WvtOeATY6WQ6iw">Digga D</a>',
#   'external_urls': {'spotify': 'https://open.spotify.com/playlist/37i9dQZF1DX2RxBh64BHjQ'},
#   'href': 'https://api.spotify.com/v1/playlists/37i9dQZF1DX2RxBh64BHjQ',
#   'id': '37i9dQZF1DX2RxBh64BHjQ',
#   'images': [{'height': None,
#     'url': 'https://i.scdn.co/image/ab67706f00000003b9727c053ee0c28a03f912f9',
#     'width': None}],
#   'name': 'Most Necessary',
#   'owner': {'display_name': 'Spotify',
#    'external_urls': {'spotify': 'https://open.spotify.com/user/spotify'},
#    'href': 'https://api.spotify.com/v1/users/spotify',
#    'id': 'spotify',
#    'type': 'user',
#    'uri': 'spotify:user:spotify'},
#   'primary_color': None,
#   'public': None,
#   'snapshot_id': 'MTY4MzMxMjU4MSwwMDAwMDAwMDMwMGU0ZWRjMDEzM2FlZmJiYmMxODUyN2Q5ZGI0MjE1',
#   'tracks': {'href': 'https://api.spotify.com/v1/playlists/37i9dQZF1DX2RxBh64BHjQ/tracks',
#    'total': 100},
#   'type': 'playlist',
#   'uri': 'spotify:playlist:37i9dQZF1DX2RxBh64BHjQ'},
#  {'collaborative': False,
#   'description': 'Soothing piano and strings to help you concentrate.',
#   'external_urls': {'spotify': 'https://open.spotify.com/playlist/37i9dQZF1DWYmSg58uBxin'},
#   'href': 'https://api.spotify.com/v1/playlists/37i9dQZF1DWYmSg58uBxin',
#   'id': '37i9dQZF1DWYmSg58uBxin',
#   'images': [{'height': None,
#     'url': 'https://i.scdn.co/image/ab67706f000000034b21e73cb07c660647413cf1',
#     'width': None}],
#   'name': 'Positive Focus',
#   'owner': {'display_name': 'Spotify',
#    'external_urls': {'spotify': 'https://open.spotify.com/user/spotify'},
#    'href': 'https://api.spotify.com/v1/users/spotify',
#    'id': 'spotify',
#    'type': 'user',
#    'uri': 'spotify:user:spotify'},
#   'primary_color': None,
#   'public': None,
#   'snapshot_id': 'MTY2MjY4MTYwMCwwMDAwMDAwMGVkMDFlZTc4NzE2YWMzYTc3MjQyYjI1ZWFjY2I5N2Fm',
#   'tracks': {'href': 'https://api.spotify.com/v1/playlists/37i9dQZF1DWYmSg58uBxin/tracks',
#    'total': 143},
#   'type': 'playlist',
#   'uri': 'spotify:playlist:37i9dQZF1DWYmSg58uBxin'},
#  {'collaborative': False,
#   'description': 'All the indescribable feelings that music gives you. cover: hemlocke springs',
#   'external_urls': {'spotify': 'https://open.spotify.com/playlist/37i9dQZF1DXdwmD5Q7Gxah'},
#   'href': 'https://api.spotify.com/v1/playlists/37i9dQZF1DXdwmD5Q7Gxah',
#   'id': '37i9dQZF1DXdwmD5Q7Gxah',
#   'images': [{'height': None,
#     'url': 'https://i.scdn.co/image/ab67706f000000037f4a6f534e61920bcf380655',
#     'width': None}],
#   'name': 'Lorem',
#   'owner': {'display_name': 'Spotify',
#    'external_urls': {'spotify': 'https://open.spotify.com/user/spotify'},
#    'href': 'https://api.spotify.com/v1/users/spotify',
#    'id': 'spotify',
#    'type': 'user',
#    'uri': 'spotify:user:spotify'},
#   'primary_color': None,
#   'public': None,
#   'snapshot_id': 'MTY4MzI1OTIwMCwwMDAwMDAwMDIyYjU4MjA1MzBiNmEwOTVhYzgzZTJmNTQ1YWFjMDNi',
#   'tracks': {'href': 'https://api.spotify.com/v1/playlists/37i9dQZF1DXdwmD5Q7Gxah/tracks',
#    'total': 107},
#   'type': 'playlist',
#   'uri': 'spotify:playlist:37i9dQZF1DXdwmD5Q7Gxah'},
#  {'collaborative': False,
#   'description': 'Classical tunes to make you feel good. ',
#   'external_urls': {'spotify': 'https://open.spotify.com/playlist/37i9dQZF1DX5Lm1ZiObdc3'},
#   'href': 'https://api.spotify.com/v1/playlists/37i9dQZF1DX5Lm1ZiObdc3',
#   'id': '37i9dQZF1DX5Lm1ZiObdc3',
#   'images': [{'height': None,
#     'url': 'https://i.scdn.co/image/ab67706f000000032006c28bcecfda6c7495afa2',
#     'width': None}],
#   'name': 'Feel Good Classical',
#   'owner': {'display_name': 'Spotify',
#    'external_urls': {'spotify': 'https://open.spotify.com/user/spotify'},
#    'href': 'https://api.spotify.com/v1/users/spotify',
#    'id': 'spotify',
#    'type': 'user',
#    'uri': 'spotify:user:spotify'},
#   'primary_color': None,
#   'public': None,
#   'snapshot_id': 'MTY4MDI1NDA0OCwwMDAwMDAwMDhjNTM5N2I0MmMxZjYxMTU5Yzk2MTQwNzBiMmZiNTE3',
#   'tracks': {'href': 'https://api.spotify.com/v1/playlists/37i9dQZF1DX5Lm1ZiObdc3/tracks',
#    'total': 47},
#   'type': 'playlist',
#   'uri': 'spotify:playlist:37i9dQZF1DX5Lm1ZiObdc3'},
#  {'collaborative': False,
#   'description': '<a href="spotify:genre:space:electronica_chill">Hypnotic electronic</a> for studies and a relax.',
#   'external_urls': {'spotify': 'https://open.spotify.com/playlist/37i9dQZF1DWXLeA8Omikj7'},
#   'href': 'https://api.spotify.com/v1/playlists/37i9dQZF1DWXLeA8Omikj7',
#   'id': '37i9dQZF1DWXLeA8Omikj7',
#   'images': [{'height': None,
#     'url': 'https://i.scdn.co/image/ab67706f000000031888f73e300bd0ee976b0180',
#     'width': None}],
#   'name': 'Brain Food',
#   'owner': {'display_name': 'Spotify',
#    'external_urls': {'spotify': 'https://open.spotify.com/user/spotify'},
#    'href': 'https://api.spotify.com/v1/users/spotify',
#    'id': 'spotify',
#    'type': 'user',
#    'uri': 'spotify:user:spotify'},
#   'primary_color': None,
#   'public': None,
#   'snapshot_id': 'MTY4MzI5MzA1OSwwMDAwMDAwMDMyNmFkODZmOWZlMjEyMmIwNTg0NGZmMmJkOTJjNDJj',
#   'tracks': {'href': 'https://api.spotify.com/v1/playlists/37i9dQZF1DWXLeA8Omikj7/tracks',
#    'total': 100},
#   'type': 'playlist',
#   'uri': 'spotify:playlist:37i9dQZF1DWXLeA8Omikj7'},
#  {'collaborative': False,
#   'description': "A look back at this fruitful era comprising trip-hop heavyweights, electronica's vanguard and everything in between.",
#   'external_urls': {'spotify': 'https://open.spotify.com/playlist/37i9dQZF1DXcG4kXwIFULb'},
#   'href': 'https://api.spotify.com/v1/playlists/37i9dQZF1DXcG4kXwIFULb',
#   'id': '37i9dQZF1DXcG4kXwIFULb',
#   'images': [{'height': None,
#     'url': 'https://i.scdn.co/image/ab67706f000000030ad2cd2ec2fb6ead54087330',
#     'width': None}],
#   'name': 'Chillout Classics',
#   'owner': {'display_name': 'Spotify',
#    'external_urls': {'spotify': 'https://open.spotify.com/user/spotify'},
#    'href': 'https://api.spotify.com/v1/users/spotify',
#    'id': 'spotify',
#    'type': 'user',
#    'uri': 'spotify:user:spotify'},
#   'primary_color': None,
#   'public': None,
#   'snapshot_id': 'MTU5OTE4MTk3NiwwMDAwMDAwMDVlZDM4OTFhYTM2MWFkZWFlNzg0MmM4N2VkNWIyMTQ5',
#   'tracks': {'href': 'https://api.spotify.com/v1/playlists/37i9dQZF1DXcG4kXwIFULb/tracks',
#    'total': 100},
#   'type': 'playlist',
#   'uri': 'spotify:playlist:37i9dQZF1DXcG4kXwIFULb'},
#  {'collaborative': False,
#   'description': "The best of today's funk. Cover: Adi Oasis",
#   'external_urls': {'spotify': 'https://open.spotify.com/playlist/37i9dQZF1DWZgauS5j6pMv'},
#   'href': 'https://api.spotify.com/v1/playlists/37i9dQZF1DWZgauS5j6pMv',
#   'id': '37i9dQZF1DWZgauS5j6pMv',
#   'images': [{'height': None,
#     'url': 'https://i.scdn.co/image/ab67706f0000000313ae84bfe0405a096765346b',
#     'width': None}],
#   'name': 'Nu-Funk',
#   'owner': {'display_name': 'Spotify',
#    'external_urls': {'spotify': 'https://open.spotify.com/user/spotify'},
#    'href': 'https://api.spotify.com/v1/users/spotify',
#    'id': 'spotify',
#    'type': 'user',
#    'uri': 'spotify:user:spotify'},
#   'primary_color': None,
#   'public': None,
#   'snapshot_id': 'MTY4MzI1OTI2MCwwMDAwMDAwMGFhYzQxYmEwMDllMmU1NDY3ZTdiOGNmMTE5YTQ1MmJm',
#   'tracks': {'href': 'https://api.spotify.com/v1/playlists/37i9dQZF1DWZgauS5j6pMv/tracks',
#    'total': 100},
#   'type': 'playlist',
#   'uri': 'spotify:playlist:37i9dQZF1DWZgauS5j6pMv'},
#  {'collaborative': False,
#   'description': 'Shut out the noise around you with these acoustic instrumentals.',
#   'external_urls': {'spotify': 'https://open.spotify.com/playlist/37i9dQZF1DXcLDm348RRYK'},
#   'href': 'https://api.spotify.com/v1/playlists/37i9dQZF1DXcLDm348RRYK',
#   'id': '37i9dQZF1DXcLDm348RRYK',
#   'images': [{'height': None,
#     'url': 'https://i.scdn.co/image/ab67706f00000003b4e1685e74a864a149f634d5',
#     'width': None}],
#   'name': 'Acoustic Concentration',
#   'owner': {'display_name': 'Spotify',
#    'external_urls': {'spotify': 'https://open.spotify.com/user/spotify'},
#    'href': 'https://api.spotify.com/v1/users/spotify',
#    'id': 'spotify',
#    'type': 'user',
#    'uri': 'spotify:user:spotify'},
#   'primary_color': None,
#   'public': None,
#   'snapshot_id': 'MTY0ODc4NTcyMCwwMDAwMDAwMDkzMmIwZWFhOGU1NjYwODQwMGM1N2U1MzliOTlhYmM2',
#   'tracks': {'href': 'https://api.spotify.com/v1/playlists/37i9dQZF1DXcLDm348RRYK/tracks',
#    'total': 63},
#   'type': 'playlist',
#   'uri': 'spotify:playlist:37i9dQZF1DXcLDm348RRYK'}]

# %% [markdown]
# ___
# ### Category Playlists

# %% [markdown]
# - Similar to featured playlists, pull categories that are available in a users market

# %%
current_categories = sp.categories(country=current_market, limit=50)

# %%
current_categories
# Out:
# {'categories': {'href': 'https://api.spotify.com/v1/browse/categories?country=US&offset=0&limit=50',
#   'items': [{'href': 'https://api.spotify.com/v1/browse/categories/toplists',
#     'icons': [{'height': 275,
#       'url': 'https://t.scdn.co/media/derived/toplists_11160599e6a04ac5d6f2757f5511778f_0_0_275_275.jpg',
#       'width': 275}],
#     'id': 'toplists',
#     'name': 'Top Lists'},
#    {'href': 'https://api.spotify.com/v1/browse/categories/0JQ5DAqbMKFQ00XGBls6ym',
#     'icons': [{'height': 274,
#       'url': 'https://t.scdn.co/media/original/hip-274_0a661854d61e29eace5fe63f73495e68_274x274.jpg',
#       'width': 274}],
#     'id': '0JQ5DAqbMKFQ00XGBls6ym',
#     'name': 'Hip-Hop'},
#    {'href': 'https://api.spotify.com/v1/browse/categories/0JQ5DAqbMKFEC4WFtoNRpw',
#     'icons': [{'height': 274,
#       'url': 'https://t.scdn.co/media/derived/pop-274x274_447148649685019f5e2a03a39e78ba52_0_0_274_274.jpg',
#       'width': 274}],
#     'id': '0JQ5DAqbMKFEC4WFtoNRpw',
#     'name': 'Pop'},
#    {'href': 'https://api.spotify.com/v1/browse/categories/0JQ5DAqbMKFKLfwjuJMoNC',
#     'icons': [{'height': None,
#       'url': 'https://t.scdn.co/images/a2e0ebe2ebed4566ba1d8236b869241f.jpeg',
#       'width': None}],
#     'id': '0JQ5DAqbMKFKLfwjuJMoNC',
#     'name': 'Country'},
#    {'href': 'https://api.spotify.com/v1/browse/categories/0JQ5DAqbMKFxXaXKP7zcDp',
#     'icons': [{'height': None,
#       'url': 'https://t.scdn.co/images/26a60378-a374-4cd7-b894-28efa5e154cb.jpg',
#       'width': None}],
#     'id': '0JQ5DAqbMKFxXaXKP7zcDp',
#     'name': 'Latin'},
#    {'href': 'https://api.spotify.com/v1/browse/categories/0JQ5DAqbMKFDXXwE9BDJAr',
#     'icons': [{'height': 274,
#       'url': 'https://t.scdn.co/media/derived/rock_9ce79e0a4ef901bbd10494f5b855d3cc_0_0_274_274.jpg',
#       'width': 274}],
#     'id': '0JQ5DAqbMKFDXXwE9BDJAr',
#     'name': 'Rock'},
#    {'href': 'https://api.spotify.com/v1/browse/categories/0JQ5DAqbMKFLVaM30PMBm4',
#     'icons': [{'height': None,
#       'url': 'https://t.scdn.co/images/8e508d7eb5b843a89c368c9507ecc429.jpeg',
#       'width': None}],
#     'id': '0JQ5DAqbMKFLVaM30PMBm4',
#     'name': 'Summer'},
#    {'href': 'https://api.spotify.com/v1/browse/categories/0JQ5DAqbMKFAXlCG6QvYQ4',
#     'icons': [{'height': None,
#       'url': 'https://t.scdn.co/media/links/workout-274x274.jpg',
#       'width': None}],
#     'id': '0JQ5DAqbMKFAXlCG6QvYQ4',
#     'name': 'Workout'},
#    {'href': 'https://api.spotify.com/v1/browse/categories/0JQ5DAqbMKFEZPnFQSFB1T',
#     'icons': [{'height': 274,
#       'url': 'https://t.scdn.co/media/derived/r-b-274x274_fd56efa72f4f63764b011b68121581d8_0_0_274_274.jpg',
#       'width': 274}],
#     'id': '0JQ5DAqbMKFEZPnFQSFB1T',
#     'name': 'R&B'},
#    {'href': 'https://api.spotify.com/v1/browse/categories/0JQ5DAqbMKFHOzuVTgTizF',
#     'icons': [{'height': 274,
#       'url': 'https://t.scdn.co/media/derived/edm-274x274_0ef612604200a9c14995432994455a6d_0_0_274_274.jpg',
#       'width': 274}],
#     'id': '0JQ5DAqbMKFHOzuVTgTizF',
#     'name': 'Dance/Electronic'},
#    {'href': 'https://api.spotify.com/v1/browse/categories/0JQ5DAqbMKFEOEBCABAxo9',
#     'icons': [{'height': None,
#       'url': 'https://t.scdn.co/images/1a416fb97f5647858c7f09c9cb6e7301',
#       'width': None}],
#     'id': '0JQ5DAqbMKFEOEBCABAxo9',
#     'name': 'Netflix'},
#    {'href': 'https://api.spotify.com/v1/browse/categories/0JQ5DAqbMKFCWjUTdzaG0e',
#     'icons': [{'height': None,
#       'url': 'https://t.scdn.co/images/fe06caf056474bc58862591cd60b57fc.jpeg',
#       'width': None}],
#     'id': '0JQ5DAqbMKFCWjUTdzaG0e',
#     'name': 'Indie'},
#    {'href': 'https://api.spotify.com/v1/browse/categories/0JQ5DAqbMKFzHmL4tf05da',
#     'icons': [{'height': 274,
#       'url': 'https://t.scdn.co/media/original/mood-274x274_976986a31ac8c49794cbdc7246fd5ad7_274x274.jpg',
#       'width': 274}],
#     'id': '0JQ5DAqbMKFzHmL4tf05da',
#     'name': 'Mood'},
#    {'href': 'https://api.spotify.com/v1/browse/categories/0JQ5DAqbMKFCuoRTxhYWow',
#     'icons': [{'height': 274,
#       'url': 'https://t.scdn.co/media/derived/sleep-274x274_0d4f836af8fab7bf31526968073e671c_0_0_274_274.jpg',
#       'width': 274}],
#     'id': '0JQ5DAqbMKFCuoRTxhYWow',
#     'name': 'Sleep'},
#    {'href': 'https://api.spotify.com/v1/browse/categories/0JQ5DAqbMKFy0OenPG51Av',
#     'icons': [{'height': None,
#       'url': 'https://t.scdn.co/images/e023f691436b4518aec8c3b18973268e',
#       'width': None}],
#     'id': '0JQ5DAqbMKFy0OenPG51Av',
#     'name': 'Christian & Gospel'},
#    {'href': 'https://api.spotify.com/v1/browse/categories/0JQ5DAqbMKFDTEtSaS4R92',
#     'icons': [{'height': None,
#       'url': 'https://t.scdn.co/images/c765fa1ce6994fce8796d2d0d93c1e61.jpeg',
#       'width': None}],
#     'id': '0JQ5DAqbMKFDTEtSaS4R92',
#     'name': 'Regional Mexican'},
#    {'href': 'https://api.spotify.com/v1/browse/categories/0JQ5DAqbMKFLb2EqgLtpjC',
#     'icons': [{'height': None,
#       'url': 'https://t.scdn.co/images/3710b68657574bc79df14bd74629e5ac',
#       'width': None}],
#     'id': '0JQ5DAqbMKFLb2EqgLtpjC',
#     'name': 'Wellness'},
#    {'href': 'https://api.spotify.com/v1/browse/categories/0JQ5DAqbMKFFzDl7qN9Apr',
#     'icons': [{'height': 274,
#       'url': 'https://t.scdn.co/media/derived/chill-274x274_4c46374f007813dd10b37e8d8fd35b4b_0_0_274_274.jpg',
#       'width': 274}],
#     'id': '0JQ5DAqbMKFFzDl7qN9Apr',
#     'name': 'Chill'},
#    {'href': 'https://api.spotify.com/v1/browse/categories/0JQ5DAqbMKFPw634sFwguI',
#     'icons': [{'height': None,
#       'url': 'https://t.scdn.co/images/084155aeaa724ea1bd393a017d67b709',
#       'width': None}],
#     'id': '0JQ5DAqbMKFPw634sFwguI',
#     'name': 'EQUAL'},
#    {'href': 'https://api.spotify.com/v1/browse/categories/0JQ5DAqbMKFCfObibaOZbv',
#     'icons': [{'height': None,
#       'url': 'https://t.scdn.co/images/0d39395309ba47838ef12ce987f19d16.jpeg',
#       'width': None}],
#     'id': '0JQ5DAqbMKFCfObibaOZbv',
#     'name': 'Gaming'},
#    {'href': 'https://api.spotify.com/v1/browse/categories/0JQ5DAqbMKFF9bY76LXmfI',
#     'icons': [{'height': None,
#       'url': 'https://t.scdn.co/images/cad629fb65a14de4beddb38510e27cb1',
#       'width': None}],
#     'id': '0JQ5DAqbMKFF9bY76LXmfI',
#     'name': 'Frequency'},
#    {'href': 'https://api.spotify.com/v1/browse/categories/0JQ5DAqbMKFF1br7dZcRtK',
#     'icons': [{'height': None,
#       'url': 'https://t.scdn.co/images/c5495b9f0f694ffcb39c9217d4ed4375',
#       'width': None}],
#     'id': '0JQ5DAqbMKFF1br7dZcRtK',
#     'name': 'Pride'},
#    {'href': 'https://api.spotify.com/v1/browse/categories/0JQ5DAqbMKFFoimhOqWzLB',
#     'icons': [{'height': None,
#       'url': 'https://t.scdn.co/images/664bb84f7a774e1eadb7c227aed98f3c',
#       'width': None}],
#     'id': '0JQ5DAqbMKFFoimhOqWzLB',
#     'name': 'Kids & Family'},
#    {'href': 'https://api.spotify.com/v1/browse/categories/0JQ5DAqbMKFA6SOHvT3gck',
#     'icons': [{'height': None,
#       'url': 'https://t.scdn.co/images/fada056dcfd54cd28faf80d62b7059c6.jpeg',
#       'width': None}],
#     'id': '0JQ5DAqbMKFA6SOHvT3gck',
#     'name': 'Party'},
#    {'href': 'https://api.spotify.com/v1/browse/categories/0JQ5DAqbMKFIVNxQgRNSg0',
#     'icons': [{'height': None,
#       'url': 'https://t.scdn.co/images/b611cf5145764c64b80e91ccd5f357c8',
#       'width': None}],
#     'id': '0JQ5DAqbMKFIVNxQgRNSg0',
#     'name': 'Decades'},
#    {'href': 'https://api.spotify.com/v1/browse/categories/0JQ5DAqbMKFImHYGo3eTSg',
#     'icons': [{'height': None,
#       'url': 'https://t.scdn.co/images/16e40e64d2a74fa8a0a020d456e6541d.jpeg',
#       'width': None}],
#     'id': '0JQ5DAqbMKFImHYGo3eTSg',
#     'name': 'Fresh Finds'},
#    {'href': 'https://api.spotify.com/v1/browse/categories/0JQ5DAqbMKFAJ5xb0fwo9m',
#     'icons': [{'height': None,
#       'url': 'https://t.scdn.co/images/568f37f1cab54136939d63bd1f59d40c',
#       'width': None}],
#     'id': '0JQ5DAqbMKFAJ5xb0fwo9m',
#     'name': 'Jazz'},
#    {'href': 'https://api.spotify.com/v1/browse/categories/0JQ5DAqbMKFCbimwdOYlsl',
#     'icons': [{'height': 274,
#       'url': 'https://t.scdn.co/media/original/genre-images-square-274x274_5e50d72b846a198fcd2ca9b3aef5f0c8_274x274.jpg',
#       'width': 274}],
#     'id': '0JQ5DAqbMKFCbimwdOYlsl',
#     'name': 'Focus'},
#    {'href': 'https://api.spotify.com/v1/browse/categories/0JQ5DAqbMKFAUsdyVjCQuL',
#     'icons': [{'height': 274,
#       'url': 'https://t.scdn.co/media/derived/romance-274x274_8100794c94847b6d27858bed6fa4d91b_0_0_274_274.jpg',
#       'width': 274}],
#     'id': '0JQ5DAqbMKFAUsdyVjCQuL',
#     'name': 'Romance'},
#    {'href': 'https://api.spotify.com/v1/browse/categories/0JQ5DAqbMKFy78wprEpAjl',
#     'icons': [{'height': None,
#       'url': 'https://t.scdn.co/images/7fe0f2c9c91f45a3b6bae49d298201a4.jpeg',
#       'width': None}],
#     'id': '0JQ5DAqbMKFy78wprEpAjl',
#     'name': 'Folk & Acoustic'},
#    {'href': 'https://api.spotify.com/v1/browse/categories/0JQ5DAqbMKFGvOw3O4nLAf',
#     'icons': [{'height': None,
#       'url': 'https://t.scdn.co/images/2078afd91e4d431eb19efc5bee5ab131.jpeg',
#       'width': None}],
#     'id': '0JQ5DAqbMKFGvOw3O4nLAf',
#     'name': 'K-Pop'},
#    {'href': 'https://api.spotify.com/v1/browse/categories/0JQ5DAqbMKFRieVZLLoo9m',
#     'icons': [{'height': None,
#       'url': 'https://t.scdn.co/images/384c2b595a1648aa801837ff99961188',
#       'width': None}],
#     'id': '0JQ5DAqbMKFRieVZLLoo9m',
#     'name': 'Instrumental'},
#    {'href': 'https://api.spotify.com/v1/browse/categories/0JQ5DAqbMKFLhhtGqqgAsz',
#     'icons': [{'height': None,
#       'url': 'https://t.scdn.co/images/f6af3964b092490884d5249dcf381dc3.jpeg',
#       'width': None}],
#     'id': '0JQ5DAqbMKFLhhtGqqgAsz',
#     'name': 'Sports'},
#    {'href': 'https://api.spotify.com/v1/browse/categories/0JQ5DAqbMKFLjmiZRss79w',
#     'icons': [{'height': None,
#       'url': 'https://t.scdn.co/images/9210c5a26e6a4b4da2c3ea8e5f87fff8',
#       'width': None}],
#     'id': '0JQ5DAqbMKFLjmiZRss79w',
#     'name': 'Ambient'},
#    {'href': 'https://api.spotify.com/v1/browse/categories/0JQ5DAqbMKFFtlLYUHv8bT',
#     'icons': [{'height': None,
#       'url': 'https://t.scdn.co/images/ee9451b3ed474c82b1da8f9b5eafc88f.jpeg',
#       'width': None}],
#     'id': '0JQ5DAqbMKFFtlLYUHv8bT',
#     'name': 'Alternative'},
#    {'href': 'https://api.spotify.com/v1/browse/categories/in_the_car',
#     'icons': [{'height': None,
#       'url': 'https://t.scdn.co/images/57017d435c344bb28efba325b7c9e7c6.jpeg',
#       'width': None}],
#     'id': 'in_the_car',
#     'name': 'In the car'},
#    {'href': 'https://api.spotify.com/v1/browse/categories/0JQ5DAqbMKFRNXsIvgZF9A',
#     'icons': [{'height': None,
#       'url': 'https://t.scdn.co/images/88ac85ae58124f19baba5f41f4bc7582',
#       'width': None}],
#     'id': '0JQ5DAqbMKFRNXsIvgZF9A',
#     'name': 'theLINER'},
#    {'href': 'https://api.spotify.com/v1/browse/categories/0JQ5DAqbMKFPrEiAOxgac3',
#     'icons': [{'height': 274,
#       'url': 'https://t.scdn.co/media/derived/classical-274x274_abf78251ff3d90d2ceaf029253ca7cb4_0_0_274_274.jpg',
#       'width': 274}],
#     'id': '0JQ5DAqbMKFPrEiAOxgac3',
#     'name': 'Classical'},
#    {'href': 'https://api.spotify.com/v1/browse/categories/0JQ5DAqbMKFIpEuaCnimBj',
#     'icons': [{'height': 274,
#       'url': 'https://t.scdn.co/media/derived/soul-274x274_266bc900b35dda8956380cffc73a4d8c_0_0_274_274.jpg',
#       'width': 274}],
#     'id': '0JQ5DAqbMKFIpEuaCnimBj',
#     'name': 'Soul'},
#    {'href': 'https://api.spotify.com/v1/browse/categories/0JQ5DAqbMKFDBgllo2cUIN',
#     'icons': [{'height': None,
#       'url': 'https://t.scdn.co/images/986a6f23-b61b-43c5-85dd-c66cc66e0f40.jpg',
#       'width': None}],
#     'id': '0JQ5DAqbMKFDBgllo2cUIN',
#     'name': 'Spotify Singles'},
#    {'href': 'https://api.spotify.com/v1/browse/categories/0JQ5DAqbMKFRY5ok2pxXJ0',
#     'icons': [{'height': 274,
#       'url': 'https://t.scdn.co/media/original/dinner_1b6506abba0ba52c54e6d695c8571078_274x274.jpg',
#       'width': 274}],
#     'id': '0JQ5DAqbMKFRY5ok2pxXJ0',
#     'name': 'Cooking & Dining'},
#    {'href': 'https://api.spotify.com/v1/browse/categories/0JQ5DAqbMKFAjfauKLOZiv',
#     'icons': [{'height': 274,
#       'url': 'https://t.scdn.co/media/derived/punk-274x274_f3f1528ea7bbb60a625da13e3315a40b_0_0_274_274.jpg',
#       'width': 274}],
#     'id': '0JQ5DAqbMKFAjfauKLOZiv',
#     'name': 'Punk'},
#    {'href': 'https://api.spotify.com/v1/browse/categories/0JQ5DAqbMKFQIL0AXnG5AK',
#     'icons': [{'height': None,
#       'url': 'https://t.scdn.co/images/ac75ec857b714a118c73218bb58664e5.jpeg',
#       'width': None}],
#     'id': '0JQ5DAqbMKFQIL0AXnG5AK',
#     'name': 'Pop culture'},
#    {'href': 'https://api.spotify.com/v1/browse/categories/0JQ5DAqbMKFQiK2EHwyjcU',
#     'icons': [{'height': None,
#       'url': 'https://t.scdn.co/images/6fe5cd3ebc8c4db7bb8013152b153505',
#       'width': None}],
#     'id': '0JQ5DAqbMKFQiK2EHwyjcU',
#     'name': 'Blues'},
#    {'href': 'https://api.spotify.com/v1/browse/categories/0JQ5DAqbMKFQVdc2eQoH2s',
#     'icons': [{'height': None,
#       'url': 'https://t.scdn.co/images/878e1eda3d084a4584465626a8f7dd26.jpeg',
#       'width': None}],
#     'id': '0JQ5DAqbMKFQVdc2eQoH2s',
#     'name': 'Desi'},
#    {'href': 'https://api.spotify.com/v1/browse/categories/0JQ5DAqbMKFQ1UFISXj59F',
#     'icons': [{'height': None,
#       'url': 'https://t.scdn.co/images/0c70e480b55c41858ebcc47061ebcb45.jpeg',
#       'width': None}],
#     'id': '0JQ5DAqbMKFQ1UFISXj59F',
#     'name': 'Arab'},
#    {'href': 'https://api.spotify.com/v1/browse/categories/0JQ5DAqbMKFOOxftoKZxod',
#     'icons': [{'height': None,
#       'url': 'https://t.scdn.co/images/c6677aa51acf4121b66b9d1f231bd427.png',
#       'width': None}],
#     'id': '0JQ5DAqbMKFOOxftoKZxod',
#     'name': 'RADAR'},
#    {'href': 'https://api.spotify.com/v1/browse/categories/0JQ5DAqbMKFJw7QLnM27p6',
#     'icons': [{'height': None,
#       'url': 'https://t.scdn.co/images/67a216e1e07144f889d366fed5c325bc.jpeg',
#       'width': None}],
#     'id': '0JQ5DAqbMKFJw7QLnM27p6',
#     'name': 'Student'},
#    {'href': 'https://api.spotify.com/v1/browse/categories/0JQ5DAqbMKFziKOShCi009',
#     'icons': [{'height': None,
#       'url': 'https://t.scdn.co/images/54841f7d6a774ef096477c99c23f0cf1.jpeg',
#       'width': None}],
#     'id': '0JQ5DAqbMKFziKOShCi009',
#     'name': 'Anime'},
#    {'href': 'https://api.spotify.com/v1/browse/categories/0JQ5DAqbMKFRKBHIxJ5hMm',
#     'icons': [{'height': None,
#       'url': 'https://t.scdn.co/images/b4182906bf244b4994805084c057e9ee.jpeg',
#       'width': None}],
#     'id': '0JQ5DAqbMKFRKBHIxJ5hMm',
#     'name': 'Tastemakers'}],
#   'limit': 50,
#   'next': 'https://api.spotify.com/v1/browse/categories?country=US&offset=50&limit=50',
#   'offset': 0,
#   'previous': None,
#   'total': 55}}

# %%
list_of_cats = [category['id'] for category in current_categories['categories']['items']]

# %%
sp = authenticate(scope='user-library-read')
# Out:
# Please authorize the app by visiting this URL: https://accounts.spotify.com/authorize?client_id=fd5183b4728840a989108098987ef843&response_type=code&redirect_uri=http%3A%2F%2Flocalhost%3A8080%2Fcallback&scope=user-library-read
# Enter the authorization code:  AQB8R6TZahq6nl8q4wAtBPZUVc5m3uFyPWU8r6Ro8Rd6qTT9xo-oA0r0r3b5Nkv58s_0lC9Z-RUqDs6ao7m57Tn_KHL6hYu-1ywxjWIwD0fGFLbmxgd0wQ4iPj87FkNsuWKp-Vih2HT9_8BQQBlMy6_RlO-tSH7Ox6OMJMygtXzh1I4PJj-twFyVn_Nfd7yJob5R1_w

# %%
sp.playlist(playlist_id='37i9dQZF1DWTQwRw56TKNc')
# Out:
# {'collaborative': False,
#  'description': 'Relax with these timeless tunes. Cover: John Denver',
#  'external_urls': {'spotify': 'https://open.spotify.com/playlist/37i9dQZF1DWTQwRw56TKNc'},
#  'followers': {'href': None, 'total': 637521},
#  'href': 'https://api.spotify.com/v1/playlists/37i9dQZF1DWTQwRw56TKNc?additional_types=track',
#  'id': '37i9dQZF1DWTQwRw56TKNc',
#  'images': [{'height': None,
#    'url': 'https://i.scdn.co/image/ab67706f00000003a83b6c9332a62267ed6d4f5f',
#    'width': None}],
#  'name': 'Mellow Classics',
#  'owner': {'display_name': 'Spotify',
#   'external_urls': {'spotify': 'https://open.spotify.com/user/spotify'},
#   'href': 'https://api.spotify.com/v1/users/spotify',
#   'id': 'spotify',
#   'type': 'user',
#   'uri': 'spotify:user:spotify'},
#  'primary_color': '#ffffff',
#  'public': True,
#  'snapshot_id': 'MCwzYjk0ODlkNmNjMDk4Mzc3YzVjYTUzN2ZmZTBhYjE5ODZhZGNlNDE3',
#  'tracks': {'href': 'https://api.spotify.com/v1/playlists/37i9dQZF1DWTQwRw56TKNc/tracks?offset=0&limit=100&additional_types=track',
#   'items': [{'added_at': '2021-09-30T18:53:37Z',
#     'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/'},
#      'href': 'https://api.spotify.com/v1/users/',
#      'id': '',
#      'type': 'user',
#      'uri': 'spotify:user:'},
#     'is_local': False,
#     'primary_color': None,
#     'track': {'album': {'album_group': 'album',
#       'album_type': 'album',
#       'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7EK1bQADBoqbYXnT4Cqv9w'},
#         'href': 'https://api.spotify.com/v1/artists/7EK1bQADBoqbYXnT4Cqv9w',
#         'id': '7EK1bQADBoqbYXnT4Cqv9w',
#         'name': 'John Denver',
#         'type': 'artist',
#         'uri': 'spotify:artist:7EK1bQADBoqbYXnT4Cqv9w'}],
#       'available_markets': ['AD',
#        'AE',
#        'AG',
#        'AL',
#        'AM',
#        'AO',
#        'AR',
#        'AT',
#        'AU',
#        'AZ',
#        'BA',
#        'BB',
#        'BD',
#        'BE',
#        'BF',
#        'BG',
#        'BH',
#        'BI',
#        'BJ',
#        'BN',
#        'BO',
#        'BR',
#        'BS',
#        'BT',
#        'BW',
#        'BY',
#        'BZ',
#        'CA',
#        'CD',
#        'CG',
#        'CH',
#        'CI',
#        'CL',
#        'CM',
#        'CO',
#        'CR',
#        'CV',
#        'CW',
#        'CY',
#        'CZ',
#        'DE',
#        'DJ',
#        'DK',
#        'DM',
#        'DO',
#        'DZ',
#        'EC',
#        'EE',
#        'EG',
#        'ES',
#        'ET',
#        'FI',
#        'FJ',
#        'FM',
#        'FR',
#        'GA',
#        'GB',
#        'GD',
#        'GE',
#        'GH',
#        'GM',
#        'GN',
#        'GQ',
#        'GR',
#        'GT',
#        'GW',
#        'GY',
#        'HK',
#        'HN',
#        'HR',
#        'HT',
#        'HU',
#        'ID',
#        'IE',
#        'IL',
#        'IN',
#        'IQ',
#        'IS',
#        'IT',
#        'JM',
#        'JO',
#        'JP',
#        'KE',
#        'KG',
#        'KH',
#        'KI',
#        'KM',
#        'KN',
#        'KR',
#        'KW',
#        'KZ',
#        'LA',
#        'LB',
#        'LC',
#        'LI',
#        'LK',
#        'LR',
#        'LS',
#        'LT',
#        'LU',
#        'LV',
#        'LY',
#        'MA',
#        'MC',
#        'MD',
#        'ME',
#        'MG',
#        'MH',
#        'MK',
#        'ML',
#        'MN',
#        'MO',
#        'MR',
#        'MT',
#        'MU',
#        'MV',
#        'MW',
#        'MX',
#        'MY',
#        'MZ',
#        'NA',
#        'NE',
#        'NG',
#        'NI',
#        'NL',
#        'NO',
#        'NP',
#        'NR',
#        'NZ',
#        'OM',
#        'PA',
#        'PE',
#        'PG',
#        'PH',
#        'PK',
#        'PL',
#        'PS',
#        'PT',
#        'PW',
#        'PY',
#        'QA',
#        'RO',
#        'RS',
#        'RW',
#        'SA',
#        'SB',
#        'SC',
#        'SE',
#        'SG',
#        'SI',
#        'SK',
#        'SL',
#        'SM',
#        'SN',
#        'SR',
#        'ST',
#        'SV',
#        'SZ',
#        'TD',
#        'TG',
#        'TH',
#        'TJ',
#        'TL',
#        'TN',
#        'TO',
#        'TR',
#        'TT',
#        'TV',
#        'TW',
#        'TZ',
#        'UA',
#        'UG',
#        'US',
#        'UY',
#        'UZ',
#        'VC',
#        'VE',
#        'VN',
#        'VU',
#        'WS',
#        'XK',
#        'ZA',
#        'ZM',
#        'ZW'],
#       'external_urls': {'spotify': 'https://open.spotify.com/album/2gEurk31djZjI3P3SY8ZcC'},
#       'href': 'https://api.spotify.com/v1/albums/2gEurk31djZjI3P3SY8ZcC',
#       'id': '2gEurk31djZjI3P3SY8ZcC',
#       'images': [{'height': 640,
#         'url': 'https://i.scdn.co/image/ab67616d0000b273858a95c04db9252719f70fff',
#         'width': 640},
#        {'height': 300,
#         'url': 'https://i.scdn.co/image/ab67616d00001e02858a95c04db9252719f70fff',
#         'width': 300},
#        {'height': 64,
#         'url': 'https://i.scdn.co/image/ab67616d00004851858a95c04db9252719f70fff',
#         'width': 64}],
#       'name': 'Rocky Mountain High',
#       'release_date': '1972-09-15',
#       'release_date_precision': 'day',
#       'total_tracks': 12,
#       'type': 'album',
#       'uri': 'spotify:album:2gEurk31djZjI3P3SY8ZcC'},
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7EK1bQADBoqbYXnT4Cqv9w'},
#        'href': 'https://api.spotify.com/v1/artists/7EK1bQADBoqbYXnT4Cqv9w',
#        'id': '7EK1bQADBoqbYXnT4Cqv9w',
#        'name': 'John Denver',
#        'type': 'artist',
#        'uri': 'spotify:artist:7EK1bQADBoqbYXnT4Cqv9w'}],
#      'available_markets': ['AR',
#       'AU',
#       'AT',
#       'BE',
#       'BO',
#       'BR',
#       'BG',
#       'CA',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DK',
#       'DO',
#       'DE',
#       'EC',
#       'EE',
#       'SV',
#       'FI',
#       'FR',
#       'GR',
#       'GT',
#       'HN',
#       'HK',
#       'HU',
#       'IS',
#       'IE',
#       'IT',
#       'LV',
#       'LT',
#       'LU',
#       'MY',
#       'MT',
#       'MX',
#       'NL',
#       'NZ',
#       'NI',
#       'NO',
#       'PA',
#       'PY',
#       'PE',
#       'PH',
#       'PL',
#       'PT',
#       'SG',
#       'SK',
#       'ES',
#       'SE',
#       'CH',
#       'TW',
#       'TR',
#       'UY',
#       'US',
#       'GB',
#       'AD',
#       'LI',
#       'MC',
#       'ID',
#       'JP',
#       'TH',
#       'VN',
#       'RO',
#       'IL',
#       'ZA',
#       'SA',
#       'AE',
#       'BH',
#       'QA',
#       'OM',
#       'KW',
#       'EG',
#       'MA',
#       'DZ',
#       'TN',
#       'LB',
#       'JO',
#       'PS',
#       'IN',
#       'BY',
#       'KZ',
#       'MD',
#       'UA',
#       'AL',
#       'BA',
#       'HR',
#       'ME',
#       'MK',
#       'RS',
#       'SI',
#       'KR',
#       'BD',
#       'PK',
#       'LK',
#       'GH',
#       'KE',
#       'NG',
#       'TZ',
#       'UG',
#       'AG',
#       'AM',
#       'BS',
#       'BB',
#       'BZ',
#       'BT',
#       'BW',
#       'BF',
#       'CV',
#       'CW',
#       'DM',
#       'FJ',
#       'GM',
#       'GE',
#       'GD',
#       'GW',
#       'GY',
#       'HT',
#       'JM',
#       'KI',
#       'LS',
#       'LR',
#       'MW',
#       'MV',
#       'ML',
#       'MH',
#       'FM',
#       'NA',
#       'NR',
#       'NE',
#       'PW',
#       'PG',
#       'WS',
#       'SM',
#       'ST',
#       'SN',
#       'SC',
#       'SL',
#       'SB',
#       'KN',
#       'LC',
#       'VC',
#       'SR',
#       'TL',
#       'TO',
#       'TT',
#       'TV',
#       'VU',
#       'AZ',
#       'BN',
#       'BI',
#       'KH',
#       'CM',
#       'TD',
#       'KM',
#       'GQ',
#       'SZ',
#       'GA',
#       'GN',
#       'KG',
#       'LA',
#       'MO',
#       'MR',
#       'MN',
#       'NP',
#       'RW',
#       'TG',
#       'UZ',
#       'ZW',
#       'BJ',
#       'MG',
#       'MU',
#       'MZ',
#       'AO',
#       'CI',
#       'DJ',
#       'ZM',
#       'CD',
#       'CG',
#       'IQ',
#       'LY',
#       'TJ',
#       'VE',
#       'ET',
#       'XK'],
#      'disc_number': 1,
#      'duration_ms': 283640,
#      'episode': False,
#      'explicit': False,
#      'external_ids': {'isrc': 'USRC11100337'},
#      'external_urls': {'spotify': 'https://open.spotify.com/track/1ne9wOtDF2jM6Cm8WBkaER'},
#      'href': 'https://api.spotify.com/v1/tracks/1ne9wOtDF2jM6Cm8WBkaER',
#      'id': '1ne9wOtDF2jM6Cm8WBkaER',
#      'is_local': False,
#      'name': 'Rocky Mountain High',
#      'popularity': 68,
#      'preview_url': 'https://p.scdn.co/mp3-preview/bd4b7edd73e644db2a010625886a4c545a9d8c18?cid=fd5183b4728840a989108098987ef843',
#      'track': True,
#      'track_number': 1,
#      'type': 'track',
#      'uri': 'spotify:track:1ne9wOtDF2jM6Cm8WBkaER'},
#     'video_thumbnail': {'url': None}},
#    {'added_at': '2021-09-30T18:53:37Z',
#     'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/'},
#      'href': 'https://api.spotify.com/v1/users/',
#      'id': '',
#      'type': 'user',
#      'uri': 'spotify:user:'},
#     'is_local': False,
#     'primary_color': None,
#     'track': {'album': {'album_group': 'album',
#       'album_type': 'album',
#       'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/08GQAI4eElDnROBrJRGE0X'},
#         'href': 'https://api.spotify.com/v1/artists/08GQAI4eElDnROBrJRGE0X',
#         'id': '08GQAI4eElDnROBrJRGE0X',
#         'name': 'Fleetwood Mac',
#         'type': 'artist',
#         'uri': 'spotify:artist:08GQAI4eElDnROBrJRGE0X'}],
#       'available_markets': ['AD',
#        'AE',
#        'AG',
#        'AL',
#        'AM',
#        'AO',
#        'AR',
#        'AT',
#        'AU',
#        'AZ',
#        'BA',
#        'BB',
#        'BD',
#        'BE',
#        'BF',
#        'BG',
#        'BH',
#        'BI',
#        'BJ',
#        'BN',
#        'BO',
#        'BR',
#        'BS',
#        'BW',
#        'BY',
#        'BZ',
#        'CA',
#        'CD',
#        'CG',
#        'CH',
#        'CI',
#        'CL',
#        'CM',
#        'CO',
#        'CR',
#        'CV',
#        'CW',
#        'CY',
#        'CZ',
#        'DE',
#        'DJ',
#        'DK',
#        'DM',
#        'DO',
#        'DZ',
#        'EC',
#        'EE',
#        'EG',
#        'ES',
#        'ET',
#        'FI',
#        'FJ',
#        'FM',
#        'FR',
#        'GA',
#        'GB',
#        'GD',
#        'GE',
#        'GH',
#        'GM',
#        'GN',
#        'GQ',
#        'GR',
#        'GT',
#        'GW',
#        'HK',
#        'HN',
#        'HR',
#        'HT',
#        'HU',
#        'ID',
#        'IE',
#        'IL',
#        'IN',
#        'IQ',
#        'IS',
#        'IT',
#        'JM',
#        'JO',
#        'JP',
#        'KE',
#        'KG',
#        'KH',
#        'KM',
#        'KN',
#        'KR',
#        'KW',
#        'KZ',
#        'LA',
#        'LB',
#        'LC',
#        'LI',
#        'LK',
#        'LR',
#        'LS',
#        'LT',
#        'LU',
#        'LV',
#        'LY',
#        'MA',
#        'MC',
#        'MD',
#        'ME',
#        'MG',
#        'MK',
#        'ML',
#        'MN',
#        'MO',
#        'MR',
#        'MT',
#        'MU',
#        'MW',
#        'MX',
#        'MY',
#        'MZ',
#        'NA',
#        'NE',
#        'NG',
#        'NI',
#        'NL',
#        'NO',
#        'NP',
#        'NZ',
#        'OM',
#        'PA',
#        'PE',
#        'PG',
#        'PH',
#        'PK',
#        'PL',
#        'PS',
#        'PT',
#        'PY',
#        'QA',
#        'RO',
#        'RS',
#        'RW',
#        'SA',
#        'SC',
#        'SE',
#        'SG',
#        'SI',
#        'SK',
#        'SL',
#        'SM',
#        'SN',
#        'ST',
#        'SV',
#        'SZ',
#        'TD',
#        'TG',
#        'TH',
#        'TJ',
#        'TL',
#        'TN',
#        'TR',
#        'TT',
#        'TW',
#        'TZ',
#        'UA',
#        'UG',
#        'US',
#        'UY',
#        'UZ',
#        'VC',
#        'VE',
#        'VN',
#        'XK',
#        'ZA',
#        'ZM',
#        'ZW'],
#       'external_urls': {'spotify': 'https://open.spotify.com/album/0BwWUstDMUbgq2NYONRqlu'},
#       'href': 'https://api.spotify.com/v1/albums/0BwWUstDMUbgq2NYONRqlu',
#       'id': '0BwWUstDMUbgq2NYONRqlu',
#       'images': [{'height': 640,
#         'url': 'https://i.scdn.co/image/ab67616d0000b273e52a59a28efa4773dd2bfe1b',
#         'width': 640},
#        {'height': 300,
#         'url': 'https://i.scdn.co/image/ab67616d00001e02e52a59a28efa4773dd2bfe1b',
#         'width': 300},
#        {'height': 64,
#         'url': 'https://i.scdn.co/image/ab67616d00004851e52a59a28efa4773dd2bfe1b',
#         'width': 64}],
#       'name': 'Rumours (Super Deluxe)',
#       'release_date': '1977-02-04',
#       'release_date_precision': 'day',
#       'total_tracks': 58,
#       'type': 'album',
#       'uri': 'spotify:album:0BwWUstDMUbgq2NYONRqlu'},
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/08GQAI4eElDnROBrJRGE0X'},
#        'href': 'https://api.spotify.com/v1/artists/08GQAI4eElDnROBrJRGE0X',
#        'id': '08GQAI4eElDnROBrJRGE0X',
#        'name': 'Fleetwood Mac',
#        'type': 'artist',
#        'uri': 'spotify:artist:08GQAI4eElDnROBrJRGE0X'}],
#      'available_markets': ['AR',
#       'AU',
#       'AT',
#       'BE',
#       'BO',
#       'BR',
#       'BG',
#       'CA',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DK',
#       'DO',
#       'DE',
#       'EC',
#       'EE',
#       'SV',
#       'FI',
#       'FR',
#       'GR',
#       'GT',
#       'HN',
#       'HK',
#       'HU',
#       'IS',
#       'IE',
#       'IT',
#       'LV',
#       'LT',
#       'LU',
#       'MY',
#       'MT',
#       'MX',
#       'NL',
#       'NZ',
#       'NI',
#       'NO',
#       'PA',
#       'PY',
#       'PE',
#       'PH',
#       'PL',
#       'PT',
#       'SG',
#       'SK',
#       'ES',
#       'SE',
#       'CH',
#       'TW',
#       'TR',
#       'UY',
#       'US',
#       'GB',
#       'AD',
#       'LI',
#       'MC',
#       'ID',
#       'JP',
#       'TH',
#       'VN',
#       'RO',
#       'IL',
#       'ZA',
#       'SA',
#       'AE',
#       'BH',
#       'QA',
#       'OM',
#       'KW',
#       'EG',
#       'MA',
#       'DZ',
#       'TN',
#       'LB',
#       'JO',
#       'PS',
#       'IN',
#       'BY',
#       'KZ',
#       'MD',
#       'UA',
#       'AL',
#       'BA',
#       'HR',
#       'ME',
#       'MK',
#       'RS',
#       'SI',
#       'KR',
#       'BD',
#       'PK',
#       'LK',
#       'GH',
#       'KE',
#       'NG',
#       'TZ',
#       'UG',
#       'AG',
#       'AM',
#       'BS',
#       'BB',
#       'BZ',
#       'BW',
#       'BF',
#       'CV',
#       'CW',
#       'DM',
#       'FJ',
#       'GM',
#       'GE',
#       'GD',
#       'GW',
#       'HT',
#       'JM',
#       'LS',
#       'LR',
#       'MW',
#       'ML',
#       'FM',
#       'NA',
#       'NE',
#       'PG',
#       'SM',
#       'ST',
#       'SN',
#       'SC',
#       'SL',
#       'KN',
#       'LC',
#       'VC',
#       'TL',
#       'TT',
#       'AZ',
#       'BN',
#       'BI',
#       'KH',
#       'CM',
#       'TD',
#       'KM',
#       'GQ',
#       'SZ',
#       'GA',
#       'GN',
#       'KG',
#       'LA',
#       'MO',
#       'MR',
#       'MN',
#       'NP',
#       'RW',
#       'TG',
#       'UZ',
#       'ZW',
#       'BJ',
#       'MG',
#       'MU',
#       'MZ',
#       'AO',
#       'CI',
#       'DJ',
#       'ZM',
#       'CD',
#       'CG',
#       'IQ',
#       'LY',
#       'TJ',
#       'VE',
#       'ET',
#       'XK'],
#      'disc_number': 1,
#      'duration_ms': 134400,
#      'episode': False,
#      'explicit': False,
#      'external_ids': {'isrc': 'USWB11301112'},
#      'external_urls': {'spotify': 'https://open.spotify.com/track/19Shlms2uTnOjIUg50TXzd'},
#      'href': 'https://api.spotify.com/v1/tracks/19Shlms2uTnOjIUg50TXzd',
#      'id': '19Shlms2uTnOjIUg50TXzd',
#      'is_local': False,
#      'name': 'Never Going Back Again - 2004 Remaster',
#      'popularity': 74,
#      'preview_url': 'https://p.scdn.co/mp3-preview/b6b7b7598c6e07019d85b116741e5f7b95d515c5?cid=fd5183b4728840a989108098987ef843',
#      'track': True,
#      'track_number': 3,
#      'type': 'track',
#      'uri': 'spotify:track:19Shlms2uTnOjIUg50TXzd'},
#     'video_thumbnail': {'url': None}},
#    {'added_at': '2021-09-30T18:53:37Z',
#     'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/'},
#      'href': 'https://api.spotify.com/v1/users/',
#      'id': '',
#      'type': 'user',
#      'uri': 'spotify:user:'},
#     'is_local': False,
#     'primary_color': None,
#     'track': {'album': {'album_group': 'album',
#       'album_type': 'album',
#       'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3PhoLpVuITZKcymswpck5b'},
#         'href': 'https://api.spotify.com/v1/artists/3PhoLpVuITZKcymswpck5b',
#         'id': '3PhoLpVuITZKcymswpck5b',
#         'name': 'Elton John',
#         'type': 'artist',
#         'uri': 'spotify:artist:3PhoLpVuITZKcymswpck5b'}],
#       'available_markets': ['AD',
#        'AE',
#        'AG',
#        'AL',
#        'AM',
#        'AO',
#        'AR',
#        'AT',
#        'AU',
#        'AZ',
#        'BA',
#        'BB',
#        'BD',
#        'BE',
#        'BF',
#        'BG',
#        'BH',
#        'BI',
#        'BJ',
#        'BN',
#        'BO',
#        'BR',
#        'BS',
#        'BT',
#        'BW',
#        'BY',
#        'BZ',
#        'CA',
#        'CD',
#        'CG',
#        'CH',
#        'CI',
#        'CL',
#        'CM',
#        'CO',
#        'CR',
#        'CV',
#        'CW',
#        'CY',
#        'CZ',
#        'DE',
#        'DJ',
#        'DK',
#        'DM',
#        'DO',
#        'DZ',
#        'EC',
#        'EE',
#        'EG',
#        'ES',
#        'ET',
#        'FI',
#        'FJ',
#        'FM',
#        'FR',
#        'GA',
#        'GB',
#        'GD',
#        'GE',
#        'GH',
#        'GM',
#        'GN',
#        'GQ',
#        'GR',
#        'GT',
#        'GW',
#        'GY',
#        'HK',
#        'HN',
#        'HR',
#        'HT',
#        'HU',
#        'ID',
#        'IE',
#        'IL',
#        'IN',
#        'IQ',
#        'IS',
#        'IT',
#        'JM',
#        'JO',
#        'JP',
#        'KE',
#        'KG',
#        'KH',
#        'KI',
#        'KM',
#        'KN',
#        'KR',
#        'KW',
#        'KZ',
#        'LA',
#        'LB',
#        'LC',
#        'LI',
#        'LK',
#        'LR',
#        'LS',
#        'LT',
#        'LU',
#        'LV',
#        'LY',
#        'MA',
#        'MC',
#        'MD',
#        'ME',
#        'MG',
#        'MH',
#        'MK',
#        'ML',
#        'MN',
#        'MO',
#        'MR',
#        'MT',
#        'MU',
#        'MV',
#        'MW',
#        'MX',
#        'MY',
#        'MZ',
#        'NA',
#        'NE',
#        'NG',
#        'NI',
#        'NL',
#        'NO',
#        'NP',
#        'NR',
#        'NZ',
#        'OM',
#        'PA',
#        'PE',
#        'PG',
#        'PH',
#        'PK',
#        'PL',
#        'PS',
#        'PT',
#        'PW',
#        'PY',
#        'QA',
#        'RO',
#        'RS',
#        'RW',
#        'SA',
#        'SB',
#        'SC',
#        'SE',
#        'SG',
#        'SI',
#        'SK',
#        'SL',
#        'SM',
#        'SN',
#        'SR',
#        'ST',
#        'SV',
#        'SZ',
#        'TD',
#        'TG',
#        'TH',
#        'TJ',
#        'TL',
#        'TN',
#        'TO',
#        'TR',
#        'TT',
#        'TV',
#        'TW',
#        'TZ',
#        'UA',
#        'UG',
#        'US',
#        'UY',
#        'UZ',
#        'VC',
#        'VE',
#        'VN',
#        'VU',
#        'WS',
#        'XK',
#        'ZA',
#        'ZM',
#        'ZW'],
#       'external_urls': {'spotify': 'https://open.spotify.com/album/2OZbaW9tgO62ndm375lFZr'},
#       'href': 'https://api.spotify.com/v1/albums/2OZbaW9tgO62ndm375lFZr',
#       'id': '2OZbaW9tgO62ndm375lFZr',
#       'images': [{'height': 640,
#         'url': 'https://i.scdn.co/image/ab67616d0000b273d03ab2da904d8251a87bbc31',
#         'width': 640},
#        {'height': 300,
#         'url': 'https://i.scdn.co/image/ab67616d00001e02d03ab2da904d8251a87bbc31',
#         'width': 300},
#        {'height': 64,
#         'url': 'https://i.scdn.co/image/ab67616d00004851d03ab2da904d8251a87bbc31',
#         'width': 64}],
#       'name': 'Madman Across The Water',
#       'release_date': '1971-11-05',
#       'release_date_precision': 'day',
#       'total_tracks': 9,
#       'type': 'album',
#       'uri': 'spotify:album:2OZbaW9tgO62ndm375lFZr'},
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3PhoLpVuITZKcymswpck5b'},
#        'href': 'https://api.spotify.com/v1/artists/3PhoLpVuITZKcymswpck5b',
#        'id': '3PhoLpVuITZKcymswpck5b',
#        'name': 'Elton John',
#        'type': 'artist',
#        'uri': 'spotify:artist:3PhoLpVuITZKcymswpck5b'}],
#      'available_markets': ['AR',
#       'AU',
#       'AT',
#       'BE',
#       'BO',
#       'BR',
#       'BG',
#       'CA',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DK',
#       'DO',
#       'DE',
#       'EC',
#       'EE',
#       'SV',
#       'FI',
#       'FR',
#       'GR',
#       'GT',
#       'HN',
#       'HK',
#       'HU',
#       'IS',
#       'IE',
#       'IT',
#       'LV',
#       'LT',
#       'LU',
#       'MY',
#       'MT',
#       'MX',
#       'NL',
#       'NZ',
#       'NI',
#       'NO',
#       'PA',
#       'PY',
#       'PE',
#       'PH',
#       'PL',
#       'PT',
#       'SG',
#       'SK',
#       'ES',
#       'SE',
#       'CH',
#       'TW',
#       'TR',
#       'UY',
#       'US',
#       'GB',
#       'AD',
#       'LI',
#       'MC',
#       'ID',
#       'JP',
#       'TH',
#       'VN',
#       'RO',
#       'IL',
#       'ZA',
#       'SA',
#       'AE',
#       'BH',
#       'QA',
#       'OM',
#       'KW',
#       'EG',
#       'MA',
#       'DZ',
#       'TN',
#       'LB',
#       'JO',
#       'PS',
#       'IN',
#       'BY',
#       'KZ',
#       'MD',
#       'UA',
#       'AL',
#       'BA',
#       'HR',
#       'ME',
#       'MK',
#       'RS',
#       'SI',
#       'KR',
#       'BD',
#       'PK',
#       'LK',
#       'GH',
#       'KE',
#       'NG',
#       'TZ',
#       'UG',
#       'AG',
#       'AM',
#       'BS',
#       'BB',
#       'BZ',
#       'BT',
#       'BW',
#       'BF',
#       'CV',
#       'CW',
#       'DM',
#       'FJ',
#       'GM',
#       'GE',
#       'GD',
#       'GW',
#       'GY',
#       'HT',
#       'JM',
#       'KI',
#       'LS',
#       'LR',
#       'MW',
#       'MV',
#       'ML',
#       'MH',
#       'FM',
#       'NA',
#       'NR',
#       'NE',
#       'PW',
#       'PG',
#       'WS',
#       'SM',
#       'ST',
#       'SN',
#       'SC',
#       'SL',
#       'SB',
#       'KN',
#       'LC',
#       'VC',
#       'SR',
#       'TL',
#       'TO',
#       'TT',
#       'TV',
#       'VU',
#       'AZ',
#       'BN',
#       'BI',
#       'KH',
#       'CM',
#       'TD',
#       'KM',
#       'GQ',
#       'SZ',
#       'GA',
#       'GN',
#       'KG',
#       'LA',
#       'MO',
#       'MR',
#       'MN',
#       'NP',
#       'RW',
#       'TG',
#       'UZ',
#       'ZW',
#       'BJ',
#       'MG',
#       'MU',
#       'MZ',
#       'AO',
#       'CI',
#       'DJ',
#       'ZM',
#       'CD',
#       'CG',
#       'IQ',
#       'LY',
#       'TJ',
#       'VE',
#       'ET',
#       'XK'],
#      'disc_number': 1,
#      'duration_ms': 377093,
#      'episode': False,
#      'explicit': False,
#      'external_ids': {'isrc': 'GBAMB7100001'},
#      'external_urls': {'spotify': 'https://open.spotify.com/track/2TVxnKdb3tqe1nhQWwwZCO'},
#      'href': 'https://api.spotify.com/v1/tracks/2TVxnKdb3tqe1nhQWwwZCO',
#      'id': '2TVxnKdb3tqe1nhQWwwZCO',
#      'is_local': False,
#      'name': 'Tiny Dancer',
#      'popularity': 78,
#      'preview_url': 'https://p.scdn.co/mp3-preview/dec7d3447047ab13ad2c2be75e8e2916262f301b?cid=fd5183b4728840a989108098987ef843',
#      'track': True,
#      'track_number': 1,
#      'type': 'track',
#      'uri': 'spotify:track:2TVxnKdb3tqe1nhQWwwZCO'},
#     'video_thumbnail': {'url': None}},
#    {'added_at': '2021-09-30T18:53:37Z',
#     'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/'},
#      'href': 'https://api.spotify.com/v1/users/',
#      'id': '',
#      'type': 'user',
#      'uri': 'spotify:user:'},
#     'is_local': False,
#     'primary_color': None,
#     'track': {'album': {'album_group': 'compilation',
#       'album_type': 'compilation',
#       'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0LyfQWJT6nXafLPZqxe9Of'},
#         'href': 'https://api.spotify.com/v1/artists/0LyfQWJT6nXafLPZqxe9Of',
#         'id': '0LyfQWJT6nXafLPZqxe9Of',
#         'name': 'Various Artists',
#         'type': 'artist',
#         'uri': 'spotify:artist:0LyfQWJT6nXafLPZqxe9Of'}],
#       'available_markets': ['AD',
#        'AE',
#        'AG',
#        'AL',
#        'AM',
#        'AO',
#        'AR',
#        'AT',
#        'AU',
#        'AZ',
#        'BA',
#        'BB',
#        'BD',
#        'BE',
#        'BF',
#        'BG',
#        'BH',
#        'BI',
#        'BJ',
#        'BN',
#        'BO',
#        'BR',
#        'BS',
#        'BT',
#        'BW',
#        'BY',
#        'BZ',
#        'CA',
#        'CD',
#        'CG',
#        'CH',
#        'CI',
#        'CL',
#        'CM',
#        'CO',
#        'CR',
#        'CV',
#        'CW',
#        'CY',
#        'CZ',
#        'DE',
#        'DJ',
#        'DK',
#        'DM',
#        'DO',
#        'DZ',
#        'EC',
#        'EE',
#        'EG',
#        'ES',
#        'ET',
#        'FI',
#        'FJ',
#        'FM',
#        'FR',
#        'GA',
#        'GB',
#        'GD',
#        'GE',
#        'GH',
#        'GM',
#        'GN',
#        'GQ',
#        'GR',
#        'GT',
#        'GW',
#        'GY',
#        'HK',
#        'HN',
#        'HR',
#        'HT',
#        'HU',
#        'ID',
#        'IE',
#        'IL',
#        'IN',
#        'IQ',
#        'IS',
#        'IT',
#        'JM',
#        'JO',
#        'JP',
#        'KE',
#        'KG',
#        'KH',
#        'KI',
#        'KM',
#        'KN',
#        'KR',
#        'KW',
#        'KZ',
#        'LA',
#        'LB',
#        'LC',
#        'LI',
#        'LK',
#        'LR',
#        'LS',
#        'LT',
#        'LU',
#        'LV',
#        'LY',
#        'MA',
#        'MC',
#        'MD',
#        'ME',
#        'MG',
#        'MH',
#        'MK',
#        'ML',
#        'MN',
#        'MO',
#        'MR',
#        'MT',
#        'MU',
#        'MV',
#        'MW',
#        'MX',
#        'MY',
#        'MZ',
#        'NA',
#        'NE',
#        'NG',
#        'NI',
#        'NL',
#        'NO',
#        'NP',
#        'NR',
#        'NZ',
#        'OM',
#        'PA',
#        'PE',
#        'PG',
#        'PH',
#        'PK',
#        'PL',
#        'PS',
#        'PT',
#        'PW',
#        'PY',
#        'QA',
#        'RO',
#        'RS',
#        'RW',
#        'SA',
#        'SB',
#        'SC',
#        'SE',
#        'SG',
#        'SI',
#        'SK',
#        'SL',
#        'SM',
#        'SN',
#        'SR',
#        'ST',
#        'SV',
#        'SZ',
#        'TD',
#        'TG',
#        'TH',
#        'TJ',
#        'TL',
#        'TN',
#        'TO',
#        'TR',
#        'TT',
#        'TV',
#        'TW',
#        'TZ',
#        'UA',
#        'UG',
#        'US',
#        'UY',
#        'UZ',
#        'VC',
#        'VE',
#        'VN',
#        'VU',
#        'WS',
#        'XK',
#        'ZA',
#        'ZM',
#        'ZW'],
#       'external_urls': {'spotify': 'https://open.spotify.com/album/1LBWNRMsbEWb17KmDD4jfD'},
#       'href': 'https://api.spotify.com/v1/albums/1LBWNRMsbEWb17KmDD4jfD',
#       'id': '1LBWNRMsbEWb17KmDD4jfD',
#       'images': [{'height': 640,
#         'url': 'https://i.scdn.co/image/ab67616d0000b27346a64b08174858852449135d',
#         'width': 640},
#        {'height': 300,
#         'url': 'https://i.scdn.co/image/ab67616d00001e0246a64b08174858852449135d',
#         'width': 300},
#        {'height': 64,
#         'url': 'https://i.scdn.co/image/ab67616d0000485146a64b08174858852449135d',
#         'width': 64}],
#       'name': 'Atlantic 60th: Soul, Sweat And Strut',
#       'release_date': '2007-10-30',
#       'release_date_precision': 'day',
#       'total_tracks': 12,
#       'type': 'album',
#       'uri': 'spotify:album:1LBWNRMsbEWb17KmDD4jfD'},
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/60df5JBRRPcnSpsIMxxwQm'},
#        'href': 'https://api.spotify.com/v1/artists/60df5JBRRPcnSpsIMxxwQm',
#        'id': '60df5JBRRPcnSpsIMxxwQm',
#        'name': 'Otis Redding',
#        'type': 'artist',
#        'uri': 'spotify:artist:60df5JBRRPcnSpsIMxxwQm'}],
#      'available_markets': ['AR',
#       'AU',
#       'AT',
#       'BE',
#       'BO',
#       'BR',
#       'BG',
#       'CA',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DK',
#       'DO',
#       'DE',
#       'EC',
#       'EE',
#       'SV',
#       'FI',
#       'FR',
#       'GR',
#       'GT',
#       'HN',
#       'HK',
#       'HU',
#       'IS',
#       'IE',
#       'IT',
#       'LV',
#       'LT',
#       'LU',
#       'MY',
#       'MT',
#       'MX',
#       'NL',
#       'NZ',
#       'NI',
#       'NO',
#       'PA',
#       'PY',
#       'PE',
#       'PH',
#       'PL',
#       'PT',
#       'SG',
#       'SK',
#       'ES',
#       'SE',
#       'CH',
#       'TW',
#       'TR',
#       'UY',
#       'US',
#       'GB',
#       'AD',
#       'LI',
#       'MC',
#       'ID',
#       'JP',
#       'TH',
#       'VN',
#       'RO',
#       'IL',
#       'ZA',
#       'SA',
#       'AE',
#       'BH',
#       'QA',
#       'OM',
#       'KW',
#       'EG',
#       'MA',
#       'DZ',
#       'TN',
#       'LB',
#       'JO',
#       'PS',
#       'IN',
#       'BY',
#       'KZ',
#       'MD',
#       'UA',
#       'AL',
#       'BA',
#       'HR',
#       'ME',
#       'MK',
#       'RS',
#       'SI',
#       'KR',
#       'BD',
#       'PK',
#       'LK',
#       'GH',
#       'KE',
#       'NG',
#       'TZ',
#       'UG',
#       'AG',
#       'AM',
#       'BS',
#       'BB',
#       'BZ',
#       'BT',
#       'BW',
#       'BF',
#       'CV',
#       'CW',
#       'DM',
#       'FJ',
#       'GM',
#       'GE',
#       'GD',
#       'GW',
#       'GY',
#       'HT',
#       'JM',
#       'KI',
#       'LS',
#       'LR',
#       'MW',
#       'MV',
#       'ML',
#       'MH',
#       'FM',
#       'NA',
#       'NR',
#       'NE',
#       'PW',
#       'PG',
#       'WS',
#       'SM',
#       'ST',
#       'SN',
#       'SC',
#       'SL',
#       'SB',
#       'KN',
#       'LC',
#       'VC',
#       'SR',
#       'TL',
#       'TO',
#       'TT',
#       'TV',
#       'VU',
#       'AZ',
#       'BN',
#       'BI',
#       'KH',
#       'CM',
#       'TD',
#       'KM',
#       'GQ',
#       'SZ',
#       'GA',
#       'GN',
#       'KG',
#       'LA',
#       'MO',
#       'MR',
#       'MN',
#       'NP',
#       'RW',
#       'TG',
#       'UZ',
#       'ZW',
#       'BJ',
#       'MG',
#       'MU',
#       'MZ',
#       'AO',
#       'CI',
#       'DJ',
#       'ZM',
#       'CD',
#       'CG',
#       'IQ',
#       'LY',
#       'TJ',
#       'VE',
#       'ET',
#       'XK'],
#      'disc_number': 1,
#      'duration_ms': 166826,
#      'episode': False,
#      'explicit': False,
#      'external_ids': {'isrc': 'USAT29900865'},
#      'external_urls': {'spotify': 'https://open.spotify.com/track/50uGbeaQIxKiSc7jvRTjWx'},
#      'href': 'https://api.spotify.com/v1/tracks/50uGbeaQIxKiSc7jvRTjWx',
#      'id': '50uGbeaQIxKiSc7jvRTjWx',
#      'is_local': False,
#      'name': "(Sittin' On) the Dock of the Bay",
#      'popularity': 63,
#      'preview_url': 'https://p.scdn.co/mp3-preview/03c3f9fda56106de1d9b8f4b93c81e0bbc1f2f56?cid=fd5183b4728840a989108098987ef843',
#      'track': True,
#      'track_number': 10,
#      'type': 'track',
#      'uri': 'spotify:track:50uGbeaQIxKiSc7jvRTjWx'},
#     'video_thumbnail': {'url': None}},
#    {'added_at': '2022-10-03T15:40:03Z',
#     'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/'},
#      'href': 'https://api.spotify.com/v1/users/',
#      'id': '',
#      'type': 'user',
#      'uri': 'spotify:user:'},
#     'is_local': False,
#     'primary_color': None,
#     'track': {'album': {'album_group': 'album',
#       'album_type': 'album',
#       'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4HVmeVTQBgvTuvjB1JYwaf'},
#         'href': 'https://api.spotify.com/v1/artists/4HVmeVTQBgvTuvjB1JYwaf',
#         'id': '4HVmeVTQBgvTuvjB1JYwaf',
#         'name': "Gilbert O'Sullivan",
#         'type': 'artist',
#         'uri': 'spotify:artist:4HVmeVTQBgvTuvjB1JYwaf'}],
#       'available_markets': ['CA', 'US'],
#       'external_urls': {'spotify': 'https://open.spotify.com/album/1INjTJtV8EwpUZF2xgwvAt'},
#       'href': 'https://api.spotify.com/v1/albums/1INjTJtV8EwpUZF2xgwvAt',
#       'id': '1INjTJtV8EwpUZF2xgwvAt',
#       'images': [{'height': 640,
#         'url': 'https://i.scdn.co/image/ab67616d0000b273a9260985285d2bb1d362b824',
#         'width': 640},
#        {'height': 300,
#         'url': 'https://i.scdn.co/image/ab67616d00001e02a9260985285d2bb1d362b824',
#         'width': 300},
#        {'height': 64,
#         'url': 'https://i.scdn.co/image/ab67616d00004851a9260985285d2bb1d362b824',
#         'width': 64}],
#       'name': 'Back to Front',
#       'release_date': '1972-01-01',
#       'release_date_precision': 'day',
#       'total_tracks': 13,
#       'type': 'album',
#       'uri': 'spotify:album:1INjTJtV8EwpUZF2xgwvAt'},
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4HVmeVTQBgvTuvjB1JYwaf'},
#        'href': 'https://api.spotify.com/v1/artists/4HVmeVTQBgvTuvjB1JYwaf',
#        'id': '4HVmeVTQBgvTuvjB1JYwaf',
#        'name': "Gilbert O'Sullivan",
#        'type': 'artist',
#        'uri': 'spotify:artist:4HVmeVTQBgvTuvjB1JYwaf'}],
#      'available_markets': ['CA', 'US'],
#      'disc_number': 1,
#      'duration_ms': 216840,
#      'episode': False,
#      'explicit': False,
#      'external_ids': {'isrc': 'GBEQJ0400002'},
#      'external_urls': {'spotify': 'https://open.spotify.com/track/6vuEG9sZtC4W2zT64f7zLF'},
#      'href': 'https://api.spotify.com/v1/tracks/6vuEG9sZtC4W2zT64f7zLF',
#      'id': '6vuEG9sZtC4W2zT64f7zLF',
#      'is_local': False,
#      'name': 'Alone Again (Naturally)',
#      'popularity': 60,
#      'preview_url': 'https://p.scdn.co/mp3-preview/d24e950fdaba5d5a1db720a8eb2268378cc86e6a?cid=fd5183b4728840a989108098987ef843',
#      'track': True,
#      'track_number': 13,
#      'type': 'track',
#      'uri': 'spotify:track:6vuEG9sZtC4W2zT64f7zLF'},
#     'video_thumbnail': {'url': None}},
#    {'added_at': '2021-09-30T18:53:37Z',
#     'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/'},
#      'href': 'https://api.spotify.com/v1/users/',
#      'id': '',
#      'type': 'user',
#      'uri': 'spotify:user:'},
#     'is_local': False,
#     'primary_color': None,
#     'track': {'album': {'album_group': 'album',
#       'album_type': 'album',
#       'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3dkbV4qihUeMsqN4vBGg93'},
#         'href': 'https://api.spotify.com/v1/artists/3dkbV4qihUeMsqN4vBGg93',
#         'id': '3dkbV4qihUeMsqN4vBGg93',
#         'name': 'Al Green',
#         'type': 'artist',
#         'uri': 'spotify:artist:3dkbV4qihUeMsqN4vBGg93'}],
#       'available_markets': ['AD',
#        'AE',
#        'AG',
#        'AL',
#        'AM',
#        'AO',
#        'AR',
#        'AT',
#        'AZ',
#        'BA',
#        'BB',
#        'BD',
#        'BE',
#        'BF',
#        'BG',
#        'BH',
#        'BI',
#        'BJ',
#        'BN',
#        'BO',
#        'BR',
#        'BS',
#        'BW',
#        'BY',
#        'BZ',
#        'CA',
#        'CD',
#        'CG',
#        'CH',
#        'CI',
#        'CL',
#        'CM',
#        'CO',
#        'CR',
#        'CV',
#        'CW',
#        'CY',
#        'CZ',
#        'DE',
#        'DJ',
#        'DK',
#        'DM',
#        'DO',
#        'DZ',
#        'EC',
#        'EE',
#        'EG',
#        'ES',
#        'ET',
#        'FI',
#        'FJ',
#        'FM',
#        'FR',
#        'GA',
#        'GB',
#        'GD',
#        'GE',
#        'GH',
#        'GM',
#        'GN',
#        'GQ',
#        'GR',
#        'GT',
#        'GW',
#        'GY',
#        'HK',
#        'HN',
#        'HR',
#        'HT',
#        'HU',
#        'ID',
#        'IE',
#        'IL',
#        'IN',
#        'IQ',
#        'IS',
#        'IT',
#        'JM',
#        'JO',
#        'KE',
#        'KG',
#        'KH',
#        'KI',
#        'KM',
#        'KN',
#        'KR',
#        'KW',
#        'KZ',
#        'LA',
#        'LB',
#        'LC',
#        'LI',
#        'LK',
#        'LR',
#        'LS',
#        'LT',
#        'LU',
#        'LV',
#        'LY',
#        'MA',
#        'MC',
#        'MD',
#        'ME',
#        'MG',
#        'MH',
#        'MK',
#        'ML',
#        'MN',
#        'MO',
#        'MR',
#        'MT',
#        'MU',
#        'MV',
#        'MW',
#        'MX',
#        'MY',
#        'MZ',
#        'NA',
#        'NE',
#        'NG',
#        'NI',
#        'NL',
#        'NO',
#        'NP',
#        'NR',
#        'OM',
#        'PA',
#        'PE',
#        'PG',
#        'PH',
#        'PK',
#        'PL',
#        'PS',
#        'PT',
#        'PW',
#        'PY',
#        'QA',
#        'RO',
#        'RS',
#        'RW',
#        'SA',
#        'SB',
#        'SC',
#        'SE',
#        'SG',
#        'SI',
#        'SK',
#        'SL',
#        'SM',
#        'SN',
#        'SR',
#        'ST',
#        'SV',
#        'SZ',
#        'TD',
#        'TG',
#        'TH',
#        'TJ',
#        'TL',
#        'TN',
#        'TO',
#        'TR',
#        'TT',
#        'TV',
#        'TW',
#        'TZ',
#        'UA',
#        'UG',
#        'US',
#        'UY',
#        'UZ',
#        'VC',
#        'VE',
#        'VN',
#        'VU',
#        'WS',
#        'XK',
#        'ZA',
#        'ZM',
#        'ZW'],
#       'external_urls': {'spotify': 'https://open.spotify.com/album/6A2T77SSF5TUglshWSQAiC'},
#       'href': 'https://api.spotify.com/v1/albums/6A2T77SSF5TUglshWSQAiC',
#       'id': '6A2T77SSF5TUglshWSQAiC',
#       'images': [{'height': 640,
#         'url': 'https://i.scdn.co/image/ab67616d0000b273fec6bb271749b854c35e5f5c',
#         'width': 640},
#        {'height': 300,
#         'url': 'https://i.scdn.co/image/ab67616d00001e02fec6bb271749b854c35e5f5c',
#         'width': 300},
#        {'height': 64,
#         'url': 'https://i.scdn.co/image/ab67616d00004851fec6bb271749b854c35e5f5c',
#         'width': 64}],
#       'name': 'Gets Next to You',
#       'release_date': '1971-08-14',
#       'release_date_precision': 'day',
#       'total_tracks': 10,
#       'type': 'album',
#       'uri': 'spotify:album:6A2T77SSF5TUglshWSQAiC'},
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3dkbV4qihUeMsqN4vBGg93'},
#        'href': 'https://api.spotify.com/v1/artists/3dkbV4qihUeMsqN4vBGg93',
#        'id': '3dkbV4qihUeMsqN4vBGg93',
#        'name': 'Al Green',
#        'type': 'artist',
#        'uri': 'spotify:artist:3dkbV4qihUeMsqN4vBGg93'}],
#      'available_markets': ['AR',
#       'AT',
#       'BE',
#       'BO',
#       'BR',
#       'BG',
#       'CA',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DK',
#       'DO',
#       'DE',
#       'EC',
#       'EE',
#       'SV',
#       'FI',
#       'FR',
#       'GR',
#       'GT',
#       'HN',
#       'HK',
#       'HU',
#       'IS',
#       'IE',
#       'IT',
#       'LV',
#       'LT',
#       'LU',
#       'MY',
#       'MT',
#       'MX',
#       'NL',
#       'NI',
#       'NO',
#       'PA',
#       'PY',
#       'PE',
#       'PH',
#       'PL',
#       'PT',
#       'SG',
#       'SK',
#       'ES',
#       'SE',
#       'CH',
#       'TW',
#       'TR',
#       'UY',
#       'US',
#       'GB',
#       'AD',
#       'LI',
#       'MC',
#       'ID',
#       'TH',
#       'VN',
#       'RO',
#       'IL',
#       'ZA',
#       'SA',
#       'AE',
#       'BH',
#       'QA',
#       'OM',
#       'KW',
#       'EG',
#       'MA',
#       'DZ',
#       'TN',
#       'LB',
#       'JO',
#       'PS',
#       'IN',
#       'BY',
#       'KZ',
#       'MD',
#       'UA',
#       'AL',
#       'BA',
#       'HR',
#       'ME',
#       'MK',
#       'RS',
#       'SI',
#       'KR',
#       'BD',
#       'PK',
#       'LK',
#       'GH',
#       'KE',
#       'NG',
#       'TZ',
#       'UG',
#       'AG',
#       'AM',
#       'BS',
#       'BB',
#       'BZ',
#       'BW',
#       'BF',
#       'CV',
#       'CW',
#       'DM',
#       'FJ',
#       'GM',
#       'GE',
#       'GD',
#       'GW',
#       'GY',
#       'HT',
#       'JM',
#       'KI',
#       'LS',
#       'LR',
#       'MW',
#       'MV',
#       'ML',
#       'MH',
#       'FM',
#       'NA',
#       'NR',
#       'NE',
#       'PW',
#       'PG',
#       'WS',
#       'SM',
#       'ST',
#       'SN',
#       'SC',
#       'SL',
#       'SB',
#       'KN',
#       'LC',
#       'VC',
#       'SR',
#       'TL',
#       'TO',
#       'TT',
#       'TV',
#       'VU',
#       'AZ',
#       'BN',
#       'BI',
#       'KH',
#       'CM',
#       'TD',
#       'KM',
#       'GQ',
#       'SZ',
#       'GA',
#       'GN',
#       'KG',
#       'LA',
#       'MO',
#       'MR',
#       'MN',
#       'NP',
#       'RW',
#       'TG',
#       'UZ',
#       'ZW',
#       'BJ',
#       'MG',
#       'MU',
#       'MZ',
#       'AO',
#       'CI',
#       'DJ',
#       'ZM',
#       'CD',
#       'CG',
#       'IQ',
#       'LY',
#       'TJ',
#       'VE',
#       'ET',
#       'XK'],
#      'disc_number': 1,
#      'duration_ms': 172320,
#      'episode': False,
#      'explicit': False,
#      'external_ids': {'isrc': 'US2HK0914104'},
#      'external_urls': {'spotify': 'https://open.spotify.com/track/10vkYRKw6Jjr7try1ir50G'},
#      'href': 'https://api.spotify.com/v1/tracks/10vkYRKw6Jjr7try1ir50G',
#      'id': '10vkYRKw6Jjr7try1ir50G',
#      'is_local': False,
#      'name': 'Tired of Being Alone',
#      'popularity': 70,
#      'preview_url': 'https://p.scdn.co/mp3-preview/ede61086d1b33613da862ba3f33fdc1caf398b84?cid=fd5183b4728840a989108098987ef843',
#      'track': True,
#      'track_number': 4,
#      'type': 'track',
#      'uri': 'spotify:track:10vkYRKw6Jjr7try1ir50G'},
#     'video_thumbnail': {'url': None}},
#    {'added_at': '2022-10-03T15:40:03Z',
#     'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/'},
#      'href': 'https://api.spotify.com/v1/users/',
#      'id': '',
#      'type': 'user',
#      'uri': 'spotify:user:'},
#     'is_local': False,
#     'primary_color': None,
#     'track': {'album': {'album_group': 'album',
#       'album_type': 'album',
#       'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/70ZTdbPEcEugBNay4MvxfL'},
#         'href': 'https://api.spotify.com/v1/artists/70ZTdbPEcEugBNay4MvxfL',
#         'id': '70ZTdbPEcEugBNay4MvxfL',
#         'name': 'Bread',
#         'type': 'artist',
#         'uri': 'spotify:artist:70ZTdbPEcEugBNay4MvxfL'}],
#       'available_markets': ['AD',
#        'AE',
#        'AG',
#        'AL',
#        'AM',
#        'AO',
#        'AR',
#        'AT',
#        'AU',
#        'AZ',
#        'BA',
#        'BB',
#        'BD',
#        'BE',
#        'BF',
#        'BG',
#        'BH',
#        'BI',
#        'BJ',
#        'BN',
#        'BO',
#        'BR',
#        'BS',
#        'BT',
#        'BW',
#        'BY',
#        'BZ',
#        'CA',
#        'CD',
#        'CG',
#        'CH',
#        'CI',
#        'CL',
#        'CM',
#        'CO',
#        'CR',
#        'CV',
#        'CW',
#        'CY',
#        'CZ',
#        'DE',
#        'DJ',
#        'DK',
#        'DM',
#        'DO',
#        'DZ',
#        'EC',
#        'EE',
#        'EG',
#        'ES',
#        'ET',
#        'FI',
#        'FJ',
#        'FM',
#        'FR',
#        'GA',
#        'GB',
#        'GD',
#        'GE',
#        'GH',
#        'GM',
#        'GN',
#        'GQ',
#        'GR',
#        'GT',
#        'GW',
#        'GY',
#        'HK',
#        'HN',
#        'HR',
#        'HT',
#        'HU',
#        'ID',
#        'IE',
#        'IL',
#        'IN',
#        'IQ',
#        'IS',
#        'IT',
#        'JM',
#        'JO',
#        'JP',
#        'KE',
#        'KG',
#        'KH',
#        'KI',
#        'KM',
#        'KN',
#        'KR',
#        'KW',
#        'KZ',
#        'LA',
#        'LB',
#        'LC',
#        'LI',
#        'LK',
#        'LR',
#        'LS',
#        'LT',
#        'LU',
#        'LV',
#        'LY',
#        'MA',
#        'MC',
#        'MD',
#        'ME',
#        'MG',
#        'MH',
#        'MK',
#        'ML',
#        'MN',
#        'MO',
#        'MR',
#        'MT',
#        'MU',
#        'MV',
#        'MW',
#        'MX',
#        'MY',
#        'MZ',
#        'NA',
#        'NE',
#        'NG',
#        'NI',
#        'NL',
#        'NO',
#        'NP',
#        'NR',
#        'NZ',
#        'OM',
#        'PA',
#        'PE',
#        'PG',
#        'PH',
#        'PK',
#        'PL',
#        'PS',
#        'PT',
#        'PW',
#        'PY',
#        'QA',
#        'RO',
#        'RS',
#        'RW',
#        'SA',
#        'SB',
#        'SC',
#        'SE',
#        'SG',
#        'SI',
#        'SK',
#        'SL',
#        'SM',
#        'SN',
#        'SR',
#        'ST',
#        'SV',
#        'SZ',
#        'TD',
#        'TG',
#        'TH',
#        'TJ',
#        'TL',
#        'TN',
#        'TO',
#        'TR',
#        'TT',
#        'TV',
#        'TW',
#        'TZ',
#        'UA',
#        'UG',
#        'US',
#        'UY',
#        'UZ',
#        'VC',
#        'VE',
#        'VN',
#        'VU',
#        'WS',
#        'XK',
#        'ZA',
#        'ZM',
#        'ZW'],
#       'external_urls': {'spotify': 'https://open.spotify.com/album/38mhQ9p2BiHpz60gthzEVy'},
#       'href': 'https://api.spotify.com/v1/albums/38mhQ9p2BiHpz60gthzEVy',
#       'id': '38mhQ9p2BiHpz60gthzEVy',
#       'images': [{'height': 640,
#         'url': 'https://i.scdn.co/image/ab67616d0000b273e9c2ddff377423fcdea5d44a',
#         'width': 640},
#        {'height': 300,
#         'url': 'https://i.scdn.co/image/ab67616d00001e02e9c2ddff377423fcdea5d44a',
#         'width': 300},
#        {'height': 64,
#         'url': 'https://i.scdn.co/image/ab67616d00004851e9c2ddff377423fcdea5d44a',
#         'width': 64}],
#       'name': 'Guitar Man',
#       'release_date': '1972',
#       'release_date_precision': 'year',
#       'total_tracks': 12,
#       'type': 'album',
#       'uri': 'spotify:album:38mhQ9p2BiHpz60gthzEVy'},
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/70ZTdbPEcEugBNay4MvxfL'},
#        'href': 'https://api.spotify.com/v1/artists/70ZTdbPEcEugBNay4MvxfL',
#        'id': '70ZTdbPEcEugBNay4MvxfL',
#        'name': 'Bread',
#        'type': 'artist',
#        'uri': 'spotify:artist:70ZTdbPEcEugBNay4MvxfL'}],
#      'available_markets': ['AR',
#       'AU',
#       'AT',
#       'BE',
#       'BO',
#       'BR',
#       'BG',
#       'CA',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DK',
#       'DO',
#       'DE',
#       'EC',
#       'EE',
#       'SV',
#       'FI',
#       'FR',
#       'GR',
#       'GT',
#       'HN',
#       'HK',
#       'HU',
#       'IS',
#       'IE',
#       'IT',
#       'LV',
#       'LT',
#       'LU',
#       'MY',
#       'MT',
#       'MX',
#       'NL',
#       'NZ',
#       'NI',
#       'NO',
#       'PA',
#       'PY',
#       'PE',
#       'PH',
#       'PL',
#       'PT',
#       'SG',
#       'SK',
#       'ES',
#       'SE',
#       'CH',
#       'TW',
#       'TR',
#       'UY',
#       'US',
#       'GB',
#       'AD',
#       'LI',
#       'MC',
#       'ID',
#       'JP',
#       'TH',
#       'VN',
#       'RO',
#       'IL',
#       'ZA',
#       'SA',
#       'AE',
#       'BH',
#       'QA',
#       'OM',
#       'KW',
#       'EG',
#       'MA',
#       'DZ',
#       'TN',
#       'LB',
#       'JO',
#       'PS',
#       'IN',
#       'BY',
#       'KZ',
#       'MD',
#       'UA',
#       'AL',
#       'BA',
#       'HR',
#       'ME',
#       'MK',
#       'RS',
#       'SI',
#       'KR',
#       'BD',
#       'PK',
#       'LK',
#       'GH',
#       'KE',
#       'NG',
#       'TZ',
#       'UG',
#       'AG',
#       'AM',
#       'BS',
#       'BB',
#       'BZ',
#       'BT',
#       'BW',
#       'BF',
#       'CV',
#       'CW',
#       'DM',
#       'FJ',
#       'GM',
#       'GE',
#       'GD',
#       'GW',
#       'GY',
#       'HT',
#       'JM',
#       'KI',
#       'LS',
#       'LR',
#       'MW',
#       'MV',
#       'ML',
#       'MH',
#       'FM',
#       'NA',
#       'NR',
#       'NE',
#       'PW',
#       'PG',
#       'WS',
#       'SM',
#       'ST',
#       'SN',
#       'SC',
#       'SL',
#       'SB',
#       'KN',
#       'LC',
#       'VC',
#       'SR',
#       'TL',
#       'TO',
#       'TT',
#       'TV',
#       'VU',
#       'AZ',
#       'BN',
#       'BI',
#       'KH',
#       'CM',
#       'TD',
#       'KM',
#       'GQ',
#       'SZ',
#       'GA',
#       'GN',
#       'KG',
#       'LA',
#       'MO',
#       'MR',
#       'MN',
#       'NP',
#       'RW',
#       'TG',
#       'UZ',
#       'ZW',
#       'BJ',
#       'MG',
#       'MU',
#       'MZ',
#       'AO',
#       'CI',
#       'DJ',
#       'ZM',
#       'CD',
#       'CG',
#       'IQ',
#       'LY',
#       'TJ',
#       'VE',
#       'ET',
#       'XK'],
#      'disc_number': 1,
#      'duration_ms': 226213,
#      'episode': False,
#      'explicit': False,
#      'external_ids': {'isrc': 'USEE10180675'},
#      'external_urls': {'spotify': 'https://open.spotify.com/track/0gZXockVcE7rEhSf4mcGLO'},
#      'href': 'https://api.spotify.com/v1/tracks/0gZXockVcE7rEhSf4mcGLO',
#      'id': '0gZXockVcE7rEhSf4mcGLO',
#      'is_local': False,
#      'name': 'Guitar Man',
#      'popularity': 68,
#      'preview_url': 'https://p.scdn.co/mp3-preview/52e228fe6617449ff468d0e2262bb0064e5e2ac5?cid=fd5183b4728840a989108098987ef843',
#      'track': True,
#      'track_number': 2,
#      'type': 'track',
#      'uri': 'spotify:track:0gZXockVcE7rEhSf4mcGLO'},
#     'video_thumbnail': {'url': None}},
#    {'added_at': '2021-09-30T18:53:37Z',
#     'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/'},
#      'href': 'https://api.spotify.com/v1/users/',
#      'id': '',
#      'type': 'user',
#      'uri': 'spotify:user:'},
#     'is_local': False,
#     'primary_color': None,
#     'track': {'album': {'album_group': 'album',
#       'album_type': 'album',
#       'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4vpDg7Y7fU982Ds30zawDA'},
#         'href': 'https://api.spotify.com/v1/artists/4vpDg7Y7fU982Ds30zawDA',
#         'id': '4vpDg7Y7fU982Ds30zawDA',
#         'name': 'The Band',
#         'type': 'artist',
#         'uri': 'spotify:artist:4vpDg7Y7fU982Ds30zawDA'}],
#       'available_markets': ['AD',
#        'AE',
#        'AG',
#        'AL',
#        'AM',
#        'AO',
#        'AR',
#        'AT',
#        'AU',
#        'AZ',
#        'BA',
#        'BB',
#        'BD',
#        'BE',
#        'BF',
#        'BG',
#        'BH',
#        'BI',
#        'BJ',
#        'BN',
#        'BO',
#        'BR',
#        'BS',
#        'BT',
#        'BW',
#        'BY',
#        'BZ',
#        'CA',
#        'CD',
#        'CG',
#        'CH',
#        'CI',
#        'CL',
#        'CM',
#        'CO',
#        'CR',
#        'CV',
#        'CW',
#        'CY',
#        'CZ',
#        'DE',
#        'DJ',
#        'DK',
#        'DM',
#        'DO',
#        'DZ',
#        'EC',
#        'EE',
#        'EG',
#        'ES',
#        'ET',
#        'FI',
#        'FJ',
#        'FM',
# ...
#       'PW',
#       'PG',
#       'WS',
#       'SM',
#       'ST',
#       'SN',
#       'SC',
#       'SL',
#       'SB',
#       'KN',
#       'LC',
#       'VC',
#       'SR',
#       'TL',
#       'TO',
#       'TT',
#       'TV',
#       'VU',
#       'AZ',
#       'BN',
#       'BI',
#       'KH',
#       'CM',
#       'TD',
#       'KM',
#       'GQ',
#       'SZ',
#       'GA',
#       'GN',
#       'KG',
#       'LA',
#       'MO',
#       'MR',
#       'MN',
#       'NP',
#       'RW',
#       'TG',
#       'UZ',
#       'ZW',
#       'BJ',
#       'MG',
#       'MU',
#       'MZ',
#       'AO',
#       'CI',
#       'DJ',
#       'ZM',
#       'CD',
#       'CG',
#       'IQ',
#       'LY',
#       'TJ',
#       'VE',
#       'ET',
#       'XK'],
#      'disc_number': 1,
#      'duration_ms': 365240,
#      'episode': False,
#      'explicit': False,
#      'external_ids': {'isrc': 'GBCCS1100097'},
#      'external_urls': {'spotify': 'https://open.spotify.com/track/6WLcfx5k7piKZWUm1SwFco'},
#      'href': 'https://api.spotify.com/v1/tracks/6WLcfx5k7piKZWUm1SwFco',
#      'id': '6WLcfx5k7piKZWUm1SwFco',
#      'is_local': False,
#      'name': 'Long Haired Lady - Remastered 2012',
#      'popularity': 45,
#      'preview_url': 'https://p.scdn.co/mp3-preview/b47189bf84b6a3817321303b75da5996acb91d01?cid=fd5183b4728840a989108098987ef843',
#      'track': True,
#      'track_number': 10,
#      'type': 'track',
#      'uri': 'spotify:track:6WLcfx5k7piKZWUm1SwFco'},
#     'video_thumbnail': {'url': None}},
#    {'added_at': '2022-04-25T13:48:17Z',
#     'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/'},
#      'href': 'https://api.spotify.com/v1/users/',
#      'id': '',
#      'type': 'user',
#      'uri': 'spotify:user:'},
#     'is_local': False,
#     'primary_color': None,
#     'track': {'album': {'album_group': 'album',
#       'album_type': 'album',
#       'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6yrBBtqX2gKCHCrZOYBDrB'},
#         'href': 'https://api.spotify.com/v1/artists/6yrBBtqX2gKCHCrZOYBDrB',
#         'id': '6yrBBtqX2gKCHCrZOYBDrB',
#         'name': 'Peter, Paul and Mary',
#         'type': 'artist',
#         'uri': 'spotify:artist:6yrBBtqX2gKCHCrZOYBDrB'}],
#       'available_markets': ['AD',
#        'AE',
#        'AG',
#        'AL',
#        'AM',
#        'AO',
#        'AR',
#        'AT',
#        'AU',
#        'AZ',
#        'BA',
#        'BB',
#        'BD',
#        'BE',
#        'BF',
#        'BG',
#        'BH',
#        'BI',
#        'BJ',
#        'BN',
#        'BO',
#        'BR',
#        'BS',
#        'BT',
#        'BW',
#        'BY',
#        'BZ',
#        'CA',
#        'CD',
#        'CG',
#        'CH',
#        'CI',
#        'CL',
#        'CM',
#        'CO',
#        'CR',
#        'CV',
#        'CW',
#        'CY',
#        'CZ',
#        'DE',
#        'DJ',
#        'DK',
#        'DM',
#        'DO',
#        'DZ',
#        'EC',
#        'EE',
#        'EG',
#        'ES',
#        'ET',
#        'FI',
#        'FJ',
#        'FM',
#        'FR',
#        'GA',
#        'GB',
#        'GD',
#        'GE',
#        'GH',
#        'GM',
#        'GN',
#        'GQ',
#        'GR',
#        'GT',
#        'GW',
#        'GY',
#        'HK',
#        'HN',
#        'HR',
#        'HT',
#        'HU',
#        'ID',
#        'IE',
#        'IL',
#        'IN',
#        'IQ',
#        'IS',
#        'IT',
#        'JM',
#        'JO',
#        'JP',
#        'KE',
#        'KG',
#        'KH',
#        'KI',
#        'KM',
#        'KN',
#        'KR',
#        'KW',
#        'KZ',
#        'LA',
#        'LB',
#        'LC',
#        'LI',
#        'LK',
#        'LR',
#        'LS',
#        'LT',
#        'LU',
#        'LV',
#        'LY',
#        'MA',
#        'MC',
#        'MD',
#        'ME',
#        'MG',
#        'MH',
#        'MK',
#        'ML',
#        'MN',
#        'MO',
#        'MR',
#        'MT',
#        'MU',
#        'MV',
#        'MW',
#        'MX',
#        'MY',
#        'MZ',
#        'NA',
#        'NE',
#        'NG',
#        'NI',
#        'NL',
#        'NO',
#        'NP',
#        'NR',
#        'NZ',
#        'OM',
#        'PA',
#        'PE',
#        'PG',
#        'PH',
#        'PK',
#        'PL',
#        'PS',
#        'PT',
#        'PW',
#        'PY',
#        'QA',
#        'RO',
#        'RS',
#        'RW',
#        'SA',
#        'SB',
#        'SC',
#        'SE',
#        'SG',
#        'SI',
#        'SK',
#        'SL',
#        'SM',
#        'SN',
#        'SR',
#        'ST',
#        'SV',
#        'SZ',
#        'TD',
#        'TG',
#        'TH',
#        'TJ',
#        'TL',
#        'TN',
#        'TO',
#        'TR',
#        'TT',
#        'TV',
#        'TW',
#        'TZ',
#        'UA',
#        'UG',
#        'US',
#        'UY',
#        'UZ',
#        'VC',
#        'VE',
#        'VN',
#        'VU',
#        'WS',
#        'XK',
#        'ZA',
#        'ZM',
#        'ZW'],
#       'external_urls': {'spotify': 'https://open.spotify.com/album/5XresJcJBgYkVQE9PATjli'},
#       'href': 'https://api.spotify.com/v1/albums/5XresJcJBgYkVQE9PATjli',
#       'id': '5XresJcJBgYkVQE9PATjli',
#       'images': [{'height': 640,
#         'url': 'https://i.scdn.co/image/ab67616d0000b2739239355346a8804ea5b362e3',
#         'width': 640},
#        {'height': 300,
#         'url': 'https://i.scdn.co/image/ab67616d00001e029239355346a8804ea5b362e3',
#         'width': 300},
#        {'height': 64,
#         'url': 'https://i.scdn.co/image/ab67616d000048519239355346a8804ea5b362e3',
#         'width': 64}],
#       'name': 'In the Wind',
#       'release_date': '1963',
#       'release_date_precision': 'year',
#       'total_tracks': 12,
#       'type': 'album',
#       'uri': 'spotify:album:5XresJcJBgYkVQE9PATjli'},
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6yrBBtqX2gKCHCrZOYBDrB'},
#        'href': 'https://api.spotify.com/v1/artists/6yrBBtqX2gKCHCrZOYBDrB',
#        'id': '6yrBBtqX2gKCHCrZOYBDrB',
#        'name': 'Peter, Paul and Mary',
#        'type': 'artist',
#        'uri': 'spotify:artist:6yrBBtqX2gKCHCrZOYBDrB'}],
#      'available_markets': ['AR',
#       'AU',
#       'AT',
#       'BE',
#       'BO',
#       'BR',
#       'BG',
#       'CA',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DK',
#       'DO',
#       'DE',
#       'EC',
#       'EE',
#       'SV',
#       'FI',
#       'FR',
#       'GR',
#       'GT',
#       'HN',
#       'HK',
#       'HU',
#       'IS',
#       'IE',
#       'IT',
#       'LV',
#       'LT',
#       'LU',
#       'MY',
#       'MT',
#       'MX',
#       'NL',
#       'NZ',
#       'NI',
#       'NO',
#       'PA',
#       'PY',
#       'PE',
#       'PH',
#       'PL',
#       'PT',
#       'SG',
#       'SK',
#       'ES',
#       'SE',
#       'CH',
#       'TW',
#       'TR',
#       'UY',
#       'US',
#       'GB',
#       'AD',
#       'LI',
#       'MC',
#       'ID',
#       'JP',
#       'TH',
#       'VN',
#       'RO',
#       'IL',
#       'ZA',
#       'SA',
#       'AE',
#       'BH',
#       'QA',
#       'OM',
#       'KW',
#       'EG',
#       'MA',
#       'DZ',
#       'TN',
#       'LB',
#       'JO',
#       'PS',
#       'IN',
#       'BY',
#       'KZ',
#       'MD',
#       'UA',
#       'AL',
#       'BA',
#       'HR',
#       'ME',
#       'MK',
#       'RS',
#       'SI',
#       'KR',
#       'BD',
#       'PK',
#       'LK',
#       'GH',
#       'KE',
#       'NG',
#       'TZ',
#       'UG',
#       'AG',
#       'AM',
#       'BS',
#       'BB',
#       'BZ',
#       'BT',
#       'BW',
#       'BF',
#       'CV',
#       'CW',
#       'DM',
#       'FJ',
#       'GM',
#       'GE',
#       'GD',
#       'GW',
#       'GY',
#       'HT',
#       'JM',
#       'KI',
#       'LS',
#       'LR',
#       'MW',
#       'MV',
#       'ML',
#       'MH',
#       'FM',
#       'NA',
#       'NR',
#       'NE',
#       'PW',
#       'PG',
#       'WS',
#       'SM',
#       'ST',
#       'SN',
#       'SC',
#       'SL',
#       'SB',
#       'KN',
#       'LC',
#       'VC',
#       'SR',
#       'TL',
#       'TO',
#       'TT',
#       'TV',
#       'VU',
#       'AZ',
#       'BN',
#       'BI',
#       'KH',
#       'CM',
#       'TD',
#       'KM',
#       'GQ',
#       'SZ',
#       'GA',
#       'GN',
#       'KG',
#       'LA',
#       'MO',
#       'MR',
#       'MN',
#       'NP',
#       'RW',
#       'TG',
#       'UZ',
#       'ZW',
#       'BJ',
#       'MG',
#       'MU',
#       'MZ',
#       'AO',
#       'CI',
#       'DJ',
#       'ZM',
#       'CD',
#       'CG',
#       'IQ',
#       'LY',
#       'TJ',
#       'VE',
#       'ET',
#       'XK'],
#      'disc_number': 1,
#      'duration_ms': 196466,
#      'episode': False,
#      'explicit': False,
#      'external_ids': {'isrc': 'USWB10001216'},
#      'external_urls': {'spotify': 'https://open.spotify.com/track/7IsXXgpowAB48crGjV1oGb'},
#      'href': 'https://api.spotify.com/v1/tracks/7IsXXgpowAB48crGjV1oGb',
#      'id': '7IsXXgpowAB48crGjV1oGb',
#      'is_local': False,
#      'name': "Don't Think Twice, It's All Right",
#      'popularity': 61,
#      'preview_url': 'https://p.scdn.co/mp3-preview/56c2064ef76d2f5248fd910d5ab350f8eac17110?cid=fd5183b4728840a989108098987ef843',
#      'track': True,
#      'track_number': 9,
#      'type': 'track',
#      'uri': 'spotify:track:7IsXXgpowAB48crGjV1oGb'},
#     'video_thumbnail': {'url': None}},
#    {'added_at': '2021-09-30T18:53:37Z',
#     'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/'},
#      'href': 'https://api.spotify.com/v1/users/',
#      'id': '',
#      'type': 'user',
#      'uri': 'spotify:user:'},
#     'is_local': False,
#     'primary_color': None,
#     'track': {'album': {'album_group': 'album',
#       'album_type': 'album',
#       'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7EK1bQADBoqbYXnT4Cqv9w'},
#         'href': 'https://api.spotify.com/v1/artists/7EK1bQADBoqbYXnT4Cqv9w',
#         'id': '7EK1bQADBoqbYXnT4Cqv9w',
#         'name': 'John Denver',
#         'type': 'artist',
#         'uri': 'spotify:artist:7EK1bQADBoqbYXnT4Cqv9w'}],
#       'available_markets': ['AD',
#        'AE',
#        'AG',
#        'AL',
#        'AM',
#        'AO',
#        'AR',
#        'AT',
#        'AU',
#        'AZ',
#        'BA',
#        'BB',
#        'BD',
#        'BE',
#        'BF',
#        'BG',
#        'BH',
#        'BI',
#        'BJ',
#        'BN',
#        'BO',
#        'BR',
#        'BS',
#        'BT',
#        'BW',
#        'BY',
#        'BZ',
#        'CA',
#        'CD',
#        'CG',
#        'CH',
#        'CI',
#        'CL',
#        'CM',
#        'CO',
#        'CR',
#        'CV',
#        'CW',
#        'CY',
#        'CZ',
#        'DE',
#        'DJ',
#        'DK',
#        'DM',
#        'DO',
#        'DZ',
#        'EC',
#        'EE',
#        'EG',
#        'ES',
#        'ET',
#        'FI',
#        'FJ',
#        'FM',
#        'FR',
#        'GA',
#        'GB',
#        'GD',
#        'GE',
#        'GH',
#        'GM',
#        'GN',
#        'GQ',
#        'GR',
#        'GT',
#        'GW',
#        'GY',
#        'HK',
#        'HN',
#        'HR',
#        'HT',
#        'HU',
#        'ID',
#        'IE',
#        'IL',
#        'IN',
#        'IQ',
#        'IS',
#        'IT',
#        'JM',
#        'JO',
#        'JP',
#        'KE',
#        'KG',
#        'KH',
#        'KI',
#        'KM',
#        'KN',
#        'KR',
#        'KW',
#        'KZ',
#        'LA',
#        'LB',
#        'LC',
#        'LI',
#        'LK',
#        'LR',
#        'LS',
#        'LT',
#        'LU',
#        'LV',
#        'LY',
#        'MA',
#        'MC',
#        'MD',
#        'ME',
#        'MG',
#        'MH',
#        'MK',
#        'ML',
#        'MN',
#        'MO',
#        'MR',
#        'MT',
#        'MU',
#        'MV',
#        'MW',
#        'MX',
#        'MY',
#        'MZ',
#        'NA',
#        'NE',
#        'NG',
#        'NI',
#        'NL',
#        'NO',
#        'NP',
#        'NR',
#        'NZ',
#        'OM',
#        'PA',
#        'PE',
#        'PG',
#        'PH',
#        'PK',
#        'PL',
#        'PS',
#        'PT',
#        'PW',
#        'PY',
#        'QA',
#        'RO',
#        'RS',
#        'RW',
#        'SA',
#        'SB',
#        'SC',
#        'SE',
#        'SG',
#        'SI',
#        'SK',
#        'SL',
#        'SM',
#        'SN',
#        'SR',
#        'ST',
#        'SV',
#        'SZ',
#        'TD',
#        'TG',
#        'TH',
#        'TJ',
#        'TL',
#        'TN',
#        'TO',
#        'TR',
#        'TT',
#        'TV',
#        'TW',
#        'TZ',
#        'UA',
#        'UG',
#        'US',
#        'UY',
#        'UZ',
#        'VC',
#        'VE',
#        'VN',
#        'VU',
#        'WS',
#        'XK',
#        'ZA',
#        'ZM',
#        'ZW'],
#       'external_urls': {'spotify': 'https://open.spotify.com/album/6zWmAA39H0c4SjnD4MB1Dm'},
#       'href': 'https://api.spotify.com/v1/albums/6zWmAA39H0c4SjnD4MB1Dm',
#       'id': '6zWmAA39H0c4SjnD4MB1Dm',
#       'images': [{'height': 640,
#         'url': 'https://i.scdn.co/image/ab67616d0000b2733c16761584c4015495bdda87',
#         'width': 640},
#        {'height': 300,
#         'url': 'https://i.scdn.co/image/ab67616d00001e023c16761584c4015495bdda87',
#         'width': 300},
#        {'height': 64,
#         'url': 'https://i.scdn.co/image/ab67616d000048513c16761584c4015495bdda87',
#         'width': 64}],
#       'name': 'Back Home Again',
#       'release_date': '1974-06-15',
#       'release_date_precision': 'day',
#       'total_tracks': 14,
#       'type': 'album',
#       'uri': 'spotify:album:6zWmAA39H0c4SjnD4MB1Dm'},
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7EK1bQADBoqbYXnT4Cqv9w'},
#        'href': 'https://api.spotify.com/v1/artists/7EK1bQADBoqbYXnT4Cqv9w',
#        'id': '7EK1bQADBoqbYXnT4Cqv9w',
#        'name': 'John Denver',
#        'type': 'artist',
#        'uri': 'spotify:artist:7EK1bQADBoqbYXnT4Cqv9w'}],
#      'available_markets': ['AR',
#       'AU',
#       'AT',
#       'BE',
#       'BO',
#       'BR',
#       'BG',
#       'CA',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DK',
#       'DO',
#       'DE',
#       'EC',
#       'EE',
#       'SV',
#       'FI',
#       'FR',
#       'GR',
#       'GT',
#       'HN',
#       'HK',
#       'HU',
#       'IS',
#       'IE',
#       'IT',
#       'LV',
#       'LT',
#       'LU',
#       'MY',
#       'MT',
#       'MX',
#       'NL',
#       'NZ',
#       'NI',
#       'NO',
#       'PA',
#       'PY',
#       'PE',
#       'PH',
#       'PL',
#       'PT',
#       'SG',
#       'SK',
#       'ES',
#       'SE',
#       'CH',
#       'TW',
#       'TR',
#       'UY',
#       'US',
#       'GB',
#       'AD',
#       'LI',
#       'MC',
#       'ID',
#       'JP',
#       'TH',
#       'VN',
#       'RO',
#       'IL',
#       'ZA',
#       'SA',
#       'AE',
#       'BH',
#       'QA',
#       'OM',
#       'KW',
#       'EG',
#       'MA',
#       'DZ',
#       'TN',
#       'LB',
#       'JO',
#       'PS',
#       'IN',
#       'BY',
#       'KZ',
#       'MD',
#       'UA',
#       'AL',
#       'BA',
#       'HR',
#       'ME',
#       'MK',
#       'RS',
#       'SI',
#       'KR',
#       'BD',
#       'PK',
#       'LK',
#       'GH',
#       'KE',
#       'NG',
#       'TZ',
#       'UG',
#       'AG',
#       'AM',
#       'BS',
#       'BB',
#       'BZ',
#       'BT',
#       'BW',
#       'BF',
#       'CV',
#       'CW',
#       'DM',
#       'FJ',
#       'GM',
#       'GE',
#       'GD',
#       'GW',
#       'GY',
#       'HT',
#       'JM',
#       'KI',
#       'LS',
#       'LR',
#       'MW',
#       'MV',
#       'ML',
#       'MH',
#       'FM',
#       'NA',
#       'NR',
#       'NE',
#       'PW',
#       'PG',
#       'WS',
#       'SM',
#       'ST',
#       'SN',
#       'SC',
#       'SL',
#       'SB',
#       'KN',
#       'LC',
#       'VC',
#       'SR',
#       'TL',
#       'TO',
#       'TT',
#       'TV',
#       'VU',
#       'AZ',
#       'BN',
#       'BI',
#       'KH',
#       'CM',
#       'TD',
#       'KM',
#       'GQ',
#       'SZ',
#       'GA',
#       'GN',
#       'KG',
#       'LA',
#       'MO',
#       'MR',
#       'MN',
#       'NP',
#       'RW',
#       'TG',
#       'UZ',
#       'ZW',
#       'BJ',
#       'MG',
#       'MU',
#       'MZ',
#       'AO',
#       'CI',
#       'DJ',
#       'ZM',
#       'CD',
#       'CG',
#       'IQ',
#       'LY',
#       'TJ',
#       'VE',
#       'ET',
#       'XK'],
#      'disc_number': 1,
#      'duration_ms': 180693,
#      'episode': False,
#      'explicit': False,
#      'external_ids': {'isrc': 'USRC17403082'},
#      'external_urls': {'spotify': 'https://open.spotify.com/track/4J0DbyODwZJcmIAiTSJfMF'},
#      'href': 'https://api.spotify.com/v1/tracks/4J0DbyODwZJcmIAiTSJfMF',
#      'id': '4J0DbyODwZJcmIAiTSJfMF',
#      'is_local': False,
#      'name': "Annie's Song",
#      'popularity': 72,
#      'preview_url': 'https://p.scdn.co/mp3-preview/465e75f7e04d6552dc42f03801279b8a56aaaa52?cid=fd5183b4728840a989108098987ef843',
#      'track': True,
#      'track_number': 7,
#      'type': 'track',
#      'uri': 'spotify:track:4J0DbyODwZJcmIAiTSJfMF'},
#     'video_thumbnail': {'url': None}}],
#   'limit': 100,
#   'next': None,
#   'offset': 0,
#   'previous': None,
#   'total': 70},
#  'type': 'playlist',
#  'uri': 'spotify:playlist:37i9dQZF1DWTQwRw56TKNc'}

# %% [markdown]
# - iterate through each available category and pull a set of playlists

# %%
cat_playlists = []

for cat_id in list_of_cats:
    try:
        cats = sp.category_playlists(category_id=cat_id,country=current_market)
        cat_playlists.extend(cats['playlists']['items'])
    except:
        continue
    time.sleep(.1)
# Out:
# HTTP Error for GET to https://api.spotify.com/v1/browse/categories/0JQ5DAqbMKFF1br7dZcRtK/playlists with Params: {'country': 'US', 'limit': 20, 'offset': 0} returned 404 due to Not found.
# HTTP Error for GET to https://api.spotify.com/v1/browse/categories/0JQ5DAqbMKFRNXsIvgZF9A/playlists with Params: {'country': 'US', 'limit': 20, 'offset': 0} returned 404 due to Not found.

# %%
len(cat_playlists)
# Out:
# 911

# %% [markdown]
# - After pulling category playlists and feature playlists, we combine them into 1 item to pull their tracks in one go

# %%
general_pool_playlists = cat_playlists + featured_playlists

# %%
general_pool_playlists[0]['id']
# Out:
# '37i9dQZF1DXcBWIGoYBM5M'

# %% [markdown]
# ___
# ### Getting Tracks from Featured and Category Playlists

# %% [markdown]
# - We now have a list of featured playlists available to the current user's country/market as well as category playlists based off of categories that the current user has access to from their country market.
# - We were able to get 922 playlists, we will:
#     - use a list comprehension to get the ids for track scrubbing
#     - remove duplicates
#     - get tracks, append to our explicit and implicit tracks to create our giant pool of tracks
#     - remove duplicates
#     - get track audio features on the whole pool
#     - get genres
#     - try a clustering model and then some eda

# %%
gen_pool_ids = [playlist['id'] for playlist in general_pool_playlists if playlist is not None]

# %% [markdown]
# - Pull playlist items per playlist id from the general pool

# %%
# %%time
gen_pool_tracks = []
for pid in gen_pool_ids:
    
    results = sp.playlist_items(pid)
    
    tracks = results['items']
    
    while results['next']:
        
        results = sp.next(results)
        
        tracks.extend(results['items'])
        
    gen_pool_tracks.extend(tracks)
# Out:
# CPU times: user 31.1 s, sys: 5.39 s, total: 36.5 s
# Wall time: 8min 14s

# %% [markdown]
# - Note potential runtime problems with the application as this data collection took 8 minutes
# - Might have to find other methods of data collection for current timeline

# %%
len(gen_pool_tracks)
# Out:
# 94189

# %%
gen_pool_df = pd.DataFrame(flatten_tracks(gen_pool_tracks))

# %% [markdown]
# - Set user_liked to 0

# %%
gen_pool_df['user_liked'] = 0

# %%
gen_pool_df.head()
# Out:
#                        id                     track_name       artist  \
# 0  6ZZf5a8oiInHDkBe9zXfLP                       Curtains   Ed Sheeran
# 1  0WtM2NBVQNNJLh6scP13H8  Calm Down (with Selena Gomez)         Rema
# 2  0yLdNVWF3Srea0uzk55zFn                        Flowers  Miley Cyrus
# 3  1Qrg8KqiBpW07V7PNxwwwL                      Kill Bill          SZA
# 4  5w40ZYhbBMAlHYNDaVJIUu                       Chemical  Post Malone
#
#                               artist_uri  \
# 0  spotify:artist:6eUKZXaKkcviH0Ku9w2n3V
# 1  spotify:artist:46pWGuE3dSwY3bMMXGBvVS
# 2  spotify:artist:5YGY8feqx7naU7z4HrwZM6
# 3  spotify:artist:7tYKF4w9nC0nq9CsPZTHyP
# 4  spotify:artist:246dkjvS1zLTtiykXe5h60
#
#                               album_uri                          album  \
# 0  spotify:album:2WFFcvzM0CgLaSq4MSkyZk                     - (Deluxe)
# 1  spotify:album:2b2GHWESCWEuHiCZ2Skedp  Calm Down (with Selena Gomez)
# 2  spotify:album:7I0tjwFtxUwBC1vgyeMAax                        Flowers
# 3  spotify:album:1nrVofqDRs7cpWXJ49qTnP                            SOS
# 4  spotify:album:7qcSUc5Af63mhfTF60KTEA                       Chemical
#
#   release_date  popularity  explicit  user_liked
# 0   2023-05-05          76     False           0
# 1   2022-08-25          95     False           0
# 2   2023-01-13          98     False           0
# 3   2022-12-08          94     False           0
# 4   2023-04-14          89      True           0

# %%
gen_pool_df.to_csv('../data/general_pool_tracks_without_features.csv')

# %% [markdown]
# ____
# ### Pull Track Audio Features and Genres
# - Let's combine our explicit tracks, implicit tracks, and our general pool tracks into one large dataframe to try clustering as well as pulling genres

# %%
user_track_library = pd.concat([exp_imp_tracks, gen_pool_df])

# %%
user_track_library.shape
# Out:
# (99474, 10)

# %% [markdown]
# - resort values to have explicit tracks on top

# %%
user_track_library.sort_values(by='user_liked', ascending=False)
# Out:
#                            id  \
# 0      1nFtiJxYdhtFfFtfXBv06s
# 1683   3BCe21LqWVOWWDfHjuoeeR
# 1676   19L0jgD9mr8QOy9kxr7LZS
# 1677   6Pk7XpaiMsXAM6dXN3kQEo
# 1678   0zOI6bMCkjd10vCrDy3voc
# ...                       ...
# 34834  40WDnUnzQL4XTo81vUJlKt
# 34833  5aIWSE31yrW7hbrjMpeJVl
# 34832  1LCiZ4QclxrAcuT1JhFM1D
# 34831  1t3koreZmmgvTYvxATwqfz
# 99473  2LdMVnYJrvDL2HGajCDzXa
#
#                                             track_name  \
# 0                                 Something In The Way
# 1683                          Nightcall - From "Drive"
# 1676   Total Eclipse of the Heart (feat. Simply Three)
# 1677                                          Firework
# 1678                            Wellerman (arr. piano)
# ...                                                ...
# 34834                                        All Of Me
# 34833                                             you.
# 34832                                        Your Love
# 34831                                           Pilots
# 99473                              Blinded by Sunshine
#
#                        artist                             artist_uri  \
# 0                     Nirvana  spotify:artist:6olE6TJLqED3rqDCT0FyPh
# 1683          Thibault Cauvin  spotify:artist:6d81rjlV6r9u8qPMAjavRV
# 1676   Vitamin String Quartet  spotify:artist:6MERXsiRbur2oJZFgYRDKz
# 1677             Jeremy Green  spotify:artist:32jiRxDN9Nb9QbXh88uo42
# 1678     Music Lab Collective  spotify:artist:1ylcY77FWeSVQKh5et1VGp
# ...                       ...                                    ...
# 34834            Matt Hammitt  spotify:artist:0o77vi5tCsW348tzvdjNPw
# 34833                outr.cty  spotify:artist:44p6xbyBk8khm2UotlfH2w
# 34832          Blessing Offor  spotify:artist:55qfDfgj4Qi3JGe6KpqGtC
# 34831             Andrew Ripp  spotify:artist:7oAskcd3mX9ZzxMPFHYqoN
# 99473           Casper Esmann  spotify:artist:6HAdDbfnR8PXoiGqU5cJeD
#
#                                   album_uri  \
# 0      spotify:album:2guirTSEqLizK7j9i1MTTZ
# 1683   spotify:album:3j4Luk2uwaiahexJJUIioz
# 1676   spotify:album:0sZwPaM40mIDElKRmnYvAb
# 1677   spotify:album:7wBmPhdZlYiDa4h6rGDSbG
# 1678   spotify:album:1f9nDMa1wlNsPxDtygkg4B
# ...                                     ...
# 34834  spotify:album:57KfddAY3ffu3A3F7M5b0h
# 34833  spotify:album:6B7etnFvfuyy0H0cY7DsrD
# 34832  spotify:album:6BiS5wWmp1iWnRsxkq4BzD
# 34831  spotify:album:3ziyaxQziaPPYaUYKl4uR0
# 99473  spotify:album:6fZrrNfreBmXblDjliOTB1
#
#                                                  album release_date  \
# 0                               Nevermind (Remastered)   1991-09-26
# 1683                          Nightcall (From "Drive")   2021-04-23
# 1676   Total Eclipse of the Heart (feat. Simply Three)   2021-05-21
# 1677                                          Firework   2022-01-21
# 1678                            Wellerman (arr. piano)   2021-07-30
# ...                                                ...          ...
# 34834                               Every Falling Tear   2011-01-01
# 34833                                             you.   2022-02-14
# 34832                                         My Tribe   2023-01-13
# 34831                                         The Soul   2019-11-29
# 99473                              Blinded by Sunshine   2019-02-08
#
#        popularity  explicit  user_liked
# 0              73     False           1
# 1683           45     False           1
# 1676           46     False           1
# 1677           43     False           1
# 1678           48     False           1
# ...           ...       ...         ...
# 34834          39     False           0
# 34833          19     False           0
# 34832          39     False           0
# 34831          35     False           0
# 99473          27     False           0
#
# [99474 rows x 10 columns]

# %% [markdown]
# - reset index

# %%
user_track_library.reset_index(inplace=True,drop=True)

# %%
user_track_library.head()
# Out:
#                        id            track_name   artist  \
# 0  1nFtiJxYdhtFfFtfXBv06s  Something In The Way  Nirvana
# 1  5Ddlk6C2JVxb1SReZ6O1wk             Drain You  Nirvana
# 2  4l012k8ZcAdVbUvZ4kae5Q             Stay Away  Nirvana
# 3  2YodwKJnbPyNKe8XXSE9V7               Lithium  Nirvana
# 4  4P5KoWXOxwuobLmHXLMobV       Come As You Are  Nirvana
#
#                               artist_uri  \
# 0  spotify:artist:6olE6TJLqED3rqDCT0FyPh
# 1  spotify:artist:6olE6TJLqED3rqDCT0FyPh
# 2  spotify:artist:6olE6TJLqED3rqDCT0FyPh
# 3  spotify:artist:6olE6TJLqED3rqDCT0FyPh
# 4  spotify:artist:6olE6TJLqED3rqDCT0FyPh
#
#                               album_uri                   album release_date  \
# 0  spotify:album:2guirTSEqLizK7j9i1MTTZ  Nevermind (Remastered)   1991-09-26
# 1  spotify:album:2guirTSEqLizK7j9i1MTTZ  Nevermind (Remastered)   1991-09-26
# 2  spotify:album:2guirTSEqLizK7j9i1MTTZ  Nevermind (Remastered)   1991-09-26
# 3  spotify:album:2guirTSEqLizK7j9i1MTTZ  Nevermind (Remastered)   1991-09-26
# 4  spotify:album:2guirTSEqLizK7j9i1MTTZ  Nevermind (Remastered)   1991-09-26
#
#    popularity  explicit  user_liked
# 0          73     False           1
# 1          63     False           1
# 2          56     False           1
# 3          72     False           1
# 4          78     False           1

# %% [markdown]
# - drop potential track duplicates with preference for keeping the first record which will be the explicit tracks after resorting

# %%
user_track_library.drop_duplicates(subset=['id'],keep='first',inplace=True)

# %%
user_track_library.shape
# Out:
# (61854, 10)

# %%
user_track_library.to_csv('../data/user_track_library.csv')

# %%
sp = authenticate(scope='user-library-read')

# %% [markdown]
# - Pull Audio Track Features for each Track

# %%
# %%time
user_track_library = get_track_audio_features(sp, user_track_library)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <timed exec> in <module>
#
# ~/Desktop/dsi_221/capstone_project/code/get_tracks_methods.py in get_track_audio_features(sp, df)
#     234         audio_features += audio_features_batch
#     235     # turn audio features into a df
# --> 236     audio_features_df = pd.DataFrame(audio_features)
#     237     # drop columns we dont need
#     238     audio_features_df = audio_features_df.drop(columns=['type', 'uri', 'track_href', 'analysis_url'])
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/frame.py in __init__(self, data, index, columns, dtype, copy)
#     719                         # ndarray], Index, Series], Sequence[Any]]"
#     720                         columns = ensure_index(columns)  # type: ignore[arg-type]
# --> 721                     arrays, columns, index = nested_data_to_arrays(
#     722                         # error: Argument 3 to "nested_data_to_arrays" has incompatible
#     723                         # type "Optional[Collection[Any]]"; expected "Optional[Index]"
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/internals/construction.py in nested_data_to_arrays(data, columns, index, dtype)
#     517         columns = ensure_index(data[0]._fields)
#     518
# --> 519     arrays, columns = to_arrays(data, columns, dtype=dtype)
#     520     columns = ensure_index(columns)
#     521
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/internals/construction.py in to_arrays(data, columns, dtype)
#     873         arr = _list_to_arrays(data)
#     874     elif isinstance(data[0], abc.Mapping):
# --> 875         arr, columns = _list_of_dict_to_arrays(data, columns)
#     876     elif isinstance(data[0], ABCSeries):
#     877         arr, columns = _list_of_series_to_arrays(data, columns)
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/internals/construction.py in _list_of_dict_to_arrays(data, columns)
#     958         gen = (list(x.keys()) for x in data)
#     959         sort = not any(isinstance(d, dict) for d in data)
# --> 960         pre_cols = lib.fast_unique_multiple_list_gen(gen, sort=sort)
#     961         columns = ensure_index(pre_cols)
#     962
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/_libs/lib.pyx in pandas._libs.lib.fast_unique_multiple_list_gen()
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/internals/construction.py in <genexpr>(.0)
#     956     """
#     957     if columns is None:
# --> 958         gen = (list(x.keys()) for x in data)
#     959         sort = not any(isinstance(d, dict) for d in data)
#     960         pre_cols = lib.fast_unique_multiple_list_gen(gen, sort=sort)
#
# AttributeError: 'NoneType' object has no attribute 'keys'

# %%
# %%time
# Use List Comprehension to get List of all track ids
track_ids = [track for track in user_track_library['id']]
# set list for audio features
audio_features = []
# iterate through list of track ids 100 at a time to account for api call limit
for i in range(0, len(track_ids), 100):
    # get batch of audio features for each chunk of 100
    audio_features_batch = sp.audio_features(tracks=track_ids[i:i+100])
    # add batch to audio features
    audio_features += audio_features_batch
# Out:
# CPU times: user 11.7 s, sys: 1.11 s, total: 12.8 s
# Wall time: 2min 53s

# %%
len(audio_features)
# Out:
# 61854

# %%
audio_features[0]
# Out:
# {'danceability': 0.427,
#  'energy': 0.201,
#  'key': 8,
#  'loudness': -13.044,
#  'mode': 1,
#  'speechiness': 0.0317,
#  'acousticness': 0.745,
#  'instrumentalness': 0.263,
#  'liveness': 0.109,
#  'valence': 0.0668,
#  'tempo': 105.218,
#  'type': 'audio_features',
#  'id': '1nFtiJxYdhtFfFtfXBv06s',
#  'uri': 'spotify:track:1nFtiJxYdhtFfFtfXBv06s',
#  'track_href': 'https://api.spotify.com/v1/tracks/1nFtiJxYdhtFfFtfXBv06s',
#  'analysis_url': 'https://api.spotify.com/v1/audio-analysis/1nFtiJxYdhtFfFtfXBv06s',
#  'duration_ms': 232147,
#  'time_signature': 4}

# %%
audio_feats = [af for af in audio_features if af is not None]

# %%
len(audio_feats)
# Out:
# 61580

# %%
# turn audio features into a df
audio_features_df = pd.DataFrame(audio_feats)
# drop columns we dont need
audio_features_df = audio_features_df.drop(columns=['type', 'uri', 'track_href', 'analysis_url'])
# merge original df and audio features df
tracks_w_features = merger(user_track_library, audio_features_df)

# %%
tracks_w_features.shape
# Out:
# (61580, 23)

# %%
tracks_w_features.head()
# Out:
#                        id            track_name   artist  \
# 0  1nFtiJxYdhtFfFtfXBv06s  Something In The Way  Nirvana
# 1  5Ddlk6C2JVxb1SReZ6O1wk             Drain You  Nirvana
# 2  4l012k8ZcAdVbUvZ4kae5Q             Stay Away  Nirvana
# 3  2YodwKJnbPyNKe8XXSE9V7               Lithium  Nirvana
# 4  4P5KoWXOxwuobLmHXLMobV       Come As You Are  Nirvana
#
#                               artist_uri  \
# 0  spotify:artist:6olE6TJLqED3rqDCT0FyPh
# 1  spotify:artist:6olE6TJLqED3rqDCT0FyPh
# 2  spotify:artist:6olE6TJLqED3rqDCT0FyPh
# 3  spotify:artist:6olE6TJLqED3rqDCT0FyPh
# 4  spotify:artist:6olE6TJLqED3rqDCT0FyPh
#
#                               album_uri                   album release_date  \
# 0  spotify:album:2guirTSEqLizK7j9i1MTTZ  Nevermind (Remastered)   1991-09-26
# 1  spotify:album:2guirTSEqLizK7j9i1MTTZ  Nevermind (Remastered)   1991-09-26
# 2  spotify:album:2guirTSEqLizK7j9i1MTTZ  Nevermind (Remastered)   1991-09-26
# 3  spotify:album:2guirTSEqLizK7j9i1MTTZ  Nevermind (Remastered)   1991-09-26
# 4  spotify:album:2guirTSEqLizK7j9i1MTTZ  Nevermind (Remastered)   1991-09-26
#
#    popularity  explicit  user_liked  ...  loudness  mode  speechiness  \
# 0          73     False           1  ...   -13.044     1       0.0317
# 1          63     False           1  ...    -5.625     0       0.0695
# 2          56     False           1  ...    -5.100     0       0.1280
# 3          72     False           1  ...    -6.410     1       0.0381
# 4          78     False           1  ...    -5.846     0       0.0388
#
#    acousticness  instrumentalness  liveness  valence    tempo  duration_ms  \
# 0      0.745000          0.263000    0.1090   0.0668  105.218       232147
# 1      0.000129          0.000002    0.1840   0.1980  133.358       223880
# 2      0.000005          0.046100    0.0822   0.2050  165.210       211440
# 3      0.001740          0.000000    0.0631   0.4850  123.207       257053
# 4      0.000160          0.001610    0.0916   0.5390  120.125       218920
#
#    time_signature
# 0               4
# 1               4
# 2               4
# 3               4
# 4               4
#
# [5 rows x 23 columns]

# %%
tracks_w_features.to_csv('../data/user_lib_tracks_feats.csv')

# %% [markdown]
# ### User Profile Track Library Complete!

# %% [markdown]
# ___
# ## Version 2's attempt at filling in Genres: Ultimately Unsuccessful

# %% [markdown]
# - Final step in the get phase of this project is capturing genre and separating the lists of genres into one-hot-encoded like columns as each artist will bring back more than one genre
# - Minor Update: retrieving genres has been difficult and slow with the given record size of ~61k, going to try my hand at ThreadPoolExecutor to help call the artist api multiple times to speed up the record processing
#     - Was successful in creating a ThreadPoolExecutor but I am pretty sure i am now being throttled by the Spotify service after trying to run 8 simultaneous threads over the 61k records.
#     - learned the limit was 180 calls per 30 secs...

# %% [markdown]
# - In both of the below sections: ThreadPoolExecutor and Pull Genres without TPE we ultimately were timed out of the Web API Service.
# - These are kept here for context as to different attempts at Pulling Genres.
# - The code for successfully pulling Genres is in both the Web App as well as in item 03_Model_User_Data

# %% [markdown]
# ___
# ### ThreadPoolExecutor

# %%
df = tracks_w_features.copy()

# %%
# Define a function to call the API on each chunk of artist URIs and create a df
def get_artist_genres(uri_list):
    # call artists api on uri_chunk
    results = sp.artists(uri_list)['artists']
    # extract genres and create a dataframe with the matching artist uri for merge later
    genres_df = pd.DataFrame({'artist_uri': [artist['uri'] for artist in results],
                                  'genres': [artist['genres'] for artist in results]})
    return genres_df

# %%
# https://more-itertools.readthedocs.io/en/stable/
chunk_size = 1000
chunks = list(chunked(df['artist_uri'], chunk_size))

# %%
# %%time
# Create a ThreadPoolExecutor with the specified number of workers
# https://www.digitalocean.com/community/tutorials/how-to-use-threadpoolexecutor-in-python-3
# https://superfastpython.com/threadpoolexecutor-in-python/
# https://www.geeksforgeeks.org/how-to-use-threadpoolexecutor-in-python3/

with ThreadPoolExecutor(max_workers=2) as executor:
   
    # Submit tasks to executor
    futures = [executor.submit(get_artist_genres, chunk) for chunk in chunks]
    
    # Collect results as they become available
    results = []
    for future in futures:
        results.extend(future.result())
# Out:
# Max Retries reached
# Max Retries reached
# Max Retries reached
# Max Retries reached
# Max Retries reached
# Max Retries reached
# Max Retries reached
# Max Retries reached
# Max Retries reached
# Max Retries reached
# ---------------------------------------------------------------------------
# MaxRetryError                             Traceback (most recent call last)
# ~/opt/anaconda3/lib/python3.9/site-packages/requests/adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     488             if not chunked:
# --> 489                 resp = conn.urlopen(
#     490                     method=request.method,
#
# ~/opt/anaconda3/lib/python3.9/site-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     877             log.debug("Retry: %s", url)
# --> 878             return self.urlopen(
#     879                 method,
#
# ~/opt/anaconda3/lib/python3.9/site-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     877             log.debug("Retry: %s", url)
# --> 878             return self.urlopen(
#     879                 method,
#
# ~/opt/anaconda3/lib/python3.9/site-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     877             log.debug("Retry: %s", url)
# --> 878             return self.urlopen(
#     879                 method,
#
# ~/opt/anaconda3/lib/python3.9/site-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     867             try:
# --> 868                 retries = retries.increment(method, url, response=response, _pool=self)
#     869             except MaxRetryError:
#
# ~/opt/anaconda3/lib/python3.9/site-packages/urllib3/util/retry.py in increment(self, method, url, response, error, _pool, _stacktrace)
#     591         if new_retry.is_exhausted():
# --> 592             raise MaxRetryError(_pool, url, error or ResponseError(cause))
#     593
#
# MaxRetryError: HTTPSConnectionPool(host='api.spotify.com', port=443): Max retries exceeded with url: /v1/artists/?ids=6olE6TJLqED3rqDCT0FyPh,6olE6TJLqED3rqDCT0FyPh,6olE6TJLqED3rqDCT0FyPh,6olE6TJLqED3rqDCT0FyPh,6olE6TJLqED3rqDCT0FyPh,6olE6TJLqED3rqDCT0FyPh,6olE6TJLqED3rqDCT0FyPh,3hyGGjxu73JuzBa757H6R5,6V70yeZQCoSR2M3fyW8qiA,5KeQyt1QJBjcutJ2AuLNO2,4gzpq5DPGxSnKTe4SA8HAU,1h6Cn3P4NGzXbaXidqURXs,67tgMwUfnmqzYsNAtnP6YJ,3C8RpaI3Go0yFF9whvKoED,3534yWWzmxx8NbKVoNolsK,0AkpPlFLnr0VQwZQeMGht0,1gR0gsQYfi6joyO1dlp76N,7gjAu1qr5C2grXeQFFOGeh,0qudezVgvl4Chd9BgNFB83,57anmI1X2hXWPrNagFdzZr,6veTV9sF06FBf2KN0xAdvo,57dN52uHvrHOxijzpIgu3E,6vWDO969PvNqNYHIOW5v0m,7bHm3B3jJju0q9FUdOgp3b,3C8RpaI3Go0yFF9whvKoED,4pb4rqWSoGUgxm63xmJ8xc,7tjbDPvrdvDshcpEMXKRVb,2pAWfrd7WFF3XhVt9GooDL,4IJczjB0fJ04gs4uvP0Fli,4YPh2MOSO13IAsOM2ouSXy,6vWDO969PvNqNYHIOW5v0m,6vWDO969PvNqNYHIOW5v0m,6vWDO969PvNqNYHIOW5v0m,5VptPtXbT0T4imW6GcobiW,587PA35pRGL1JwQr6idJbb,2S11VlKvbvSKyyb7Wk4YP1,4EVpmkEwrLYEg6jIsiPMIb,4IJczjB0fJ04gs4uvP0Fli,3gnrmLahFhVXRI9DA1MImH,3gnrmLahFhVXRI9DA1MImH,3gnrmLahFhVXRI9DA1MImH,4EVpmkEwrLYEg6jIsiPMIb,4EVpmkEwrLYEg6jIsiPMIb,4EVpmkEwrLYEg6jIsiPMIb,4EVpmkEwrLYEg6jIsiPMIb,3XSqByZe2kuUAquw8seGD6,4rwCk3DZwQa8uY7Cvfu4aM,7nkLRaWHImCvWGHdNGnhVE,6TsSBSisvQYCupsHmXe1iK,6lOCVUQbb9wzuZQbZQV9zn,0xOeVMOz2fVg5BJY3N6akT,5aMIbwZQvP2MHPMVC5zCGj,3yg8VEfEzpr8T9NkiEsycS,587PA35pRGL1JwQr6idJbb,23KIrX6iPiVOkx60F4bjNq,4EMtGVFvfCSrEmWaGV0roE,23KIrX6iPiVOkx60F4bjNq,7aA592KWirLsnfb5ulGWvU,3lLHpTOJ11tWiUNGYN14gt,59oA5WbbQvomJz2BuRG071,5lpdJ3wNP63XGxuoa7HkMS,7sgWBYtJpblXpJl2lU5WVs,0fA0VVWsXO9YnASrzqfmYu,4LLpKhyESsyAXpc4laK94U,4qwGe91Bz9K2T8jXTZ815W,2Xu7q46Hf02xOoEIm4E1Qs,4OBJLual30L7gRl5UkeRcT,5EvFsr3kj42KNv97ZEnqij,6DPYiyq5kWVQS4RGwxzPC7,3r0OeTcOw37N9juMYyyw39,1XkoF8ryArs86LZvFOkbyr,2MGT7CYlixSPxAnnkhLpaA,6V3F8MZrOKdT9fU686ybE9,6DPYiyq5kWVQS4RGwxzPC7,3ScY9CQxNLQei8Umvpx5g6,22bE4uQ6baNwSHPVcDxLCe,0F4ybIPzwLfT5xzZQlYBXP,0F4ybIPzwLfT5xzZQlYBXP,3oGVQWQy7lgTMuTnKUZZNZ,3oGVQWQy7lgTMuTnKUZZNZ,4uN3DsfENc7dp0OLO0FEIb,0Mz5XE0kb1GBnbLQm2VbcO,0av074qUwLn5eyzwqoq3xh,22WZ7M8sxp5THdruNY3gXt,2iEvnFsWxR0Syqu2JNopAd,1lZvg4fNAqHoj6I9N8naBM,4F84IBURUo98rz4r61KF70,36QJpDe2go2KgaRleHCDTp,1lZvg4fNAqHoj6I9N8naBM,0rpMdBzQXf7aYRnu5fDBJy,2yDodJUwXfdHzg4crwslUp,7pXu47GoqSYRajmBCjxdD6,2JRvXPGWiINrnJljNJhG5s,7sVQKNtdP2NylxMgbNOJMM,0K1q0nXQ8is36PzOKAMbNe,6qyi8X6MdP1lu6B1K6yh3h,6A43Djmhbe9100UwnI7epV,6A43Djmhbe9100UwnI7epV,0TcYeHEK9sBtv7xPbKhzHz,3TQ9JTBI2n2hfo7aRONEYV,1Y8cdNmUJH7yBTd9yOvr5i,2P3cjUru4H3fhSXXNxE9kA,0cQbJU1aAzvbEmTuljWLlF,6A43Djmhbe9100UwnI7epV,5me0Irg2ANcsgc93uaYrpb,3dXaa6jwM7B52GZpaJEIr5,4UXqAaa6dQYAk18Lv7PEgX,24XtlMhEMNdi822vi0MhY1,0cQbJU1aAzvbEmTuljWLlF,3PhoLpVuITZKcymswpck5b,6FBDaR13swtiWwGhX1WQsP,4Ui2kfOqGujY81UcPrb5KE,0LyfQWJT6nXafLPZqxe9Of,5f4QpKfy7ptCHwTqspnSJI,0YsLR3SQd5QTXAhGIGX7cl,1W9qOBYRTfP7HcizWN43G1,6xyaria4AcxjRuJZLkWvMW,2WKdxPFRD7IqZvlIAvhMgY,3ZotbHeyVQKxQCPDJuQ4SU,4kYSro6naA4h99UJvo89HB,4kYSro6naA4h99UJvo89HB,2Waw2sSbqvAwK8NwACNjVo,0nyc9SZGLITSOJASmTZsnZ,2Mu5NfyYm8n5iTomuKAEHl,2YZyLoL8N0Wb9xBt1NhZWg,1UQRtt7eHW6Bt4INNTUtb3,4kYSro6naA4h99UJvo89HB,2WImpqiHxgOKw0sXNOGtWl,5LfGQac0EIXyAN8aUwmNAQ,4EVpmkEwrLYEg6jIsiPMIb,5K4W6rqBFWDnAN6FQUkS6x,5K4W6rqBFWDnAN6FQUkS6x,0fA0VVWsXO9YnASrzqfmYu,1G9G7WwrXka3Z1r7aIDjI7,73sIBHcqh3Z3NyqHKZ7FOL,6Qm9stX6XO1a4c7BXQDDgc,4l1cKWYW591xnwEGxpUg3J,6aUgzC0cMh0StjV7LyFEDr,5K4W6rqBFWDnAN6FQUkS6x,1IELhvOMg5VQlU7syRm6CS,3tCxM1rTj2qUXsiQZxvt2I,6wFId9Jhuf9AKVzWboOj2B,3AA28KZvwAUcZuOKwyblJQ,066X20Nz7iquqkkCW6Jxy6,3AA28KZvwAUcZuOKwyblJQ,3AA28KZvwAUcZuOKwyblJQ,3AA28KZvwAUcZuOKwyblJQ,5wPoxI5si3eJsYYwyXV4Wi,1W9qOBYRTfP7HcizWN43G1,7nW3rZPhwZWlGPZgdDiJea,4EVpmkEwrLYEg6jIsiPMIb,1hak05VDAWZqSimeBx6fjQ,0FrpdcVlJQqibaz5HfBUrL,6zyPKJ4ePhYLsBEy4A6BVX,3RTzAwFprBqiskp550eSJX,2W8UTum7bU7ue6m0r14H97,0SwO7SWeDHJijQ3XNS7xEE,0IecGJbdBeYSOVtSPRehh5,4CTKqs11Zgsv8EZTVzx764,57dN52uHvrHOxijzpIgu3E,7hJcb9fa4alzcOq3EaNPoG,1G9G7WwrXka3Z1r7aIDjI7,1gR0gsQYfi6joyO1dlp76N,4l1cKWYW591xnwEGxpUg3J,3C8RpaI3Go0yFF9whvKoED,1LeVJ5GPeYDOVUjxx1y7Rp,066X20Nz7iquqkkCW6Jxy6,4ytkhMSAnrDP8XzRNlw9FS,4ytkhMSAnrDP8XzRNl ...
#
# During handling of the above exception, another exception occurred:
#
# RetryError                                Traceback (most recent call last)
# ~/opt/anaconda3/lib/python3.9/site-packages/spotipy/client.py in _internal_call(self, method, url, payload, params)
#     265         try:
# --> 266             response = self._session.request(
#     267                 method, url, headers=headers, proxies=self.proxies,
#
# ~/opt/anaconda3/lib/python3.9/site-packages/requests/sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     586         send_kwargs.update(settings)
# --> 587         resp = self.send(prep, **send_kwargs)
#     588
#
# ~/opt/anaconda3/lib/python3.9/site-packages/requests/sessions.py in send(self, request, **kwargs)
#     700         # Send the request
# --> 701         r = adapter.send(request, **kwargs)
#     702
#
# ~/opt/anaconda3/lib/python3.9/site-packages/requests/adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     555             if isinstance(e.reason, ResponseError):
# --> 556                 raise RetryError(e, request=request)
#     557
#
# RetryError: HTTPSConnectionPool(host='api.spotify.com', port=443): Max retries exceeded with url: /v1/artists/?ids=6olE6TJLqED3rqDCT0FyPh,6olE6TJLqED3rqDCT0FyPh,6olE6TJLqED3rqDCT0FyPh,6olE6TJLqED3rqDCT0FyPh,6olE6TJLqED3rqDCT0FyPh,6olE6TJLqED3rqDCT0FyPh,6olE6TJLqED3rqDCT0FyPh,3hyGGjxu73JuzBa757H6R5,6V70yeZQCoSR2M3fyW8qiA,5KeQyt1QJBjcutJ2AuLNO2,4gzpq5DPGxSnKTe4SA8HAU,1h6Cn3P4NGzXbaXidqURXs,67tgMwUfnmqzYsNAtnP6YJ,3C8RpaI3Go0yFF9whvKoED,3534yWWzmxx8NbKVoNolsK,0AkpPlFLnr0VQwZQeMGht0,1gR0gsQYfi6joyO1dlp76N,7gjAu1qr5C2grXeQFFOGeh,0qudezVgvl4Chd9BgNFB83,57anmI1X2hXWPrNagFdzZr,6veTV9sF06FBf2KN0xAdvo,57dN52uHvrHOxijzpIgu3E,6vWDO969PvNqNYHIOW5v0m,7bHm3B3jJju0q9FUdOgp3b,3C8RpaI3Go0yFF9whvKoED,4pb4rqWSoGUgxm63xmJ8xc,7tjbDPvrdvDshcpEMXKRVb,2pAWfrd7WFF3XhVt9GooDL,4IJczjB0fJ04gs4uvP0Fli,4YPh2MOSO13IAsOM2ouSXy,6vWDO969PvNqNYHIOW5v0m,6vWDO969PvNqNYHIOW5v0m,6vWDO969PvNqNYHIOW5v0m,5VptPtXbT0T4imW6GcobiW,587PA35pRGL1JwQr6idJbb,2S11VlKvbvSKyyb7Wk4YP1,4EVpmkEwrLYEg6jIsiPMIb,4IJczjB0fJ04gs4uvP0Fli,3gnrmLahFhVXRI9DA1MImH,3gnrmLahFhVXRI9DA1MImH,3gnrmLahFhVXRI9DA1MImH,4EVpmkEwrLYEg6jIsiPMIb,4EVpmkEwrLYEg6jIsiPMIb,4EVpmkEwrLYEg6jIsiPMIb,4EVpmkEwrLYEg6jIsiPMIb,3XSqByZe2kuUAquw8seGD6,4rwCk3DZwQa8uY7Cvfu4aM,7nkLRaWHImCvWGHdNGnhVE,6TsSBSisvQYCupsHmXe1iK,6lOCVUQbb9wzuZQbZQV9zn,0xOeVMOz2fVg5BJY3N6akT,5aMIbwZQvP2MHPMVC5zCGj,3yg8VEfEzpr8T9NkiEsycS,587PA35pRGL1JwQr6idJbb,23KIrX6iPiVOkx60F4bjNq,4EMtGVFvfCSrEmWaGV0roE,23KIrX6iPiVOkx60F4bjNq,7aA592KWirLsnfb5ulGWvU,3lLHpTOJ11tWiUNGYN14gt,59oA5WbbQvomJz2BuRG071,5lpdJ3wNP63XGxuoa7HkMS,7sgWBYtJpblXpJl2lU5WVs,0fA0VVWsXO9YnASrzqfmYu,4LLpKhyESsyAXpc4laK94U,4qwGe91Bz9K2T8jXTZ815W,2Xu7q46Hf02xOoEIm4E1Qs,4OBJLual30L7gRl5UkeRcT,5EvFsr3kj42KNv97ZEnqij,6DPYiyq5kWVQS4RGwxzPC7,3r0OeTcOw37N9juMYyyw39,1XkoF8ryArs86LZvFOkbyr,2MGT7CYlixSPxAnnkhLpaA,6V3F8MZrOKdT9fU686ybE9,6DPYiyq5kWVQS4RGwxzPC7,3ScY9CQxNLQei8Umvpx5g6,22bE4uQ6baNwSHPVcDxLCe,0F4ybIPzwLfT5xzZQlYBXP,0F4ybIPzwLfT5xzZQlYBXP,3oGVQWQy7lgTMuTnKUZZNZ,3oGVQWQy7lgTMuTnKUZZNZ,4uN3DsfENc7dp0OLO0FEIb,0Mz5XE0kb1GBnbLQm2VbcO,0av074qUwLn5eyzwqoq3xh,22WZ7M8sxp5THdruNY3gXt,2iEvnFsWxR0Syqu2JNopAd,1lZvg4fNAqHoj6I9N8naBM,4F84IBURUo98rz4r61KF70,36QJpDe2go2KgaRleHCDTp,1lZvg4fNAqHoj6I9N8naBM,0rpMdBzQXf7aYRnu5fDBJy,2yDodJUwXfdHzg4crwslUp,7pXu47GoqSYRajmBCjxdD6,2JRvXPGWiINrnJljNJhG5s,7sVQKNtdP2NylxMgbNOJMM,0K1q0nXQ8is36PzOKAMbNe,6qyi8X6MdP1lu6B1K6yh3h,6A43Djmhbe9100UwnI7epV,6A43Djmhbe9100UwnI7epV,0TcYeHEK9sBtv7xPbKhzHz,3TQ9JTBI2n2hfo7aRONEYV,1Y8cdNmUJH7yBTd9yOvr5i,2P3cjUru4H3fhSXXNxE9kA,0cQbJU1aAzvbEmTuljWLlF,6A43Djmhbe9100UwnI7epV,5me0Irg2ANcsgc93uaYrpb,3dXaa6jwM7B52GZpaJEIr5,4UXqAaa6dQYAk18Lv7PEgX,24XtlMhEMNdi822vi0MhY1,0cQbJU1aAzvbEmTuljWLlF,3PhoLpVuITZKcymswpck5b,6FBDaR13swtiWwGhX1WQsP,4Ui2kfOqGujY81UcPrb5KE,0LyfQWJT6nXafLPZqxe9Of,5f4QpKfy7ptCHwTqspnSJI,0YsLR3SQd5QTXAhGIGX7cl,1W9qOBYRTfP7HcizWN43G1,6xyaria4AcxjRuJZLkWvMW,2WKdxPFRD7IqZvlIAvhMgY,3ZotbHeyVQKxQCPDJuQ4SU,4kYSro6naA4h99UJvo89HB,4kYSro6naA4h99UJvo89HB,2Waw2sSbqvAwK8NwACNjVo,0nyc9SZGLITSOJASmTZsnZ,2Mu5NfyYm8n5iTomuKAEHl,2YZyLoL8N0Wb9xBt1NhZWg,1UQRtt7eHW6Bt4INNTUtb3,4kYSro6naA4h99UJvo89HB,2WImpqiHxgOKw0sXNOGtWl,5LfGQac0EIXyAN8aUwmNAQ,4EVpmkEwrLYEg6jIsiPMIb,5K4W6rqBFWDnAN6FQUkS6x,5K4W6rqBFWDnAN6FQUkS6x,0fA0VVWsXO9YnASrzqfmYu,1G9G7WwrXka3Z1r7aIDjI7,73sIBHcqh3Z3NyqHKZ7FOL,6Qm9stX6XO1a4c7BXQDDgc,4l1cKWYW591xnwEGxpUg3J,6aUgzC0cMh0StjV7LyFEDr,5K4W6rqBFWDnAN6FQUkS6x,1IELhvOMg5VQlU7syRm6CS,3tCxM1rTj2qUXsiQZxvt2I,6wFId9Jhuf9AKVzWboOj2B,3AA28KZvwAUcZuOKwyblJQ,066X20Nz7iquqkkCW6Jxy6,3AA28KZvwAUcZuOKwyblJQ,3AA28KZvwAUcZuOKwyblJQ,3AA28KZvwAUcZuOKwyblJQ,5wPoxI5si3eJsYYwyXV4Wi,1W9qOBYRTfP7HcizWN43G1,7nW3rZPhwZWlGPZgdDiJea,4EVpmkEwrLYEg6jIsiPMIb,1hak05VDAWZqSimeBx6fjQ,0FrpdcVlJQqibaz5HfBUrL,6zyPKJ4ePhYLsBEy4A6BVX,3RTzAwFprBqiskp550eSJX,2W8UTum7bU7ue6m0r14H97,0SwO7SWeDHJijQ3XNS7xEE,0IecGJbdBeYSOVtSPRehh5,4CTKqs11Zgsv8EZTVzx764,57dN52uHvrHOxijzpIgu3E,7hJcb9fa4alzcOq3EaNPoG,1G9G7WwrXka3Z1r7aIDjI7,1gR0gsQYfi6joyO1dlp76N,4l1cKWYW591xnwEGxpUg3J,3C8RpaI3Go0yFF9whvKoED,1LeVJ5GPeYDOVUjxx1y7Rp,066X20Nz7iquqkkCW6Jxy6,4ytkhMSAnrDP8XzRNlw9FS,4ytkhMSAnrDP8XzRNlw9F ...
#
# During handling of the above exception, another exception occurred:
#
# SpotifyException                          Traceback (most recent call last)
# <timed exec> in <module>
#
# ~/opt/anaconda3/lib/python3.9/concurrent/futures/_base.py in result(self, timeout)
#     445                 elif self._state == FINISHED:
# --> 446                     return self.__get_result()
#     447                 else:
#
# ~/opt/anaconda3/lib/python3.9/concurrent/futures/_base.py in __get_result(self)
#     390             try:
# --> 391                 raise self._exception
#     392             finally:
#
# ~/opt/anaconda3/lib/python3.9/concurrent/futures/thread.py in run(self)
#      57         try:
# ---> 58             result = self.fn(*self.args, **self.kwargs)
#      59         except BaseException as exc:
#
# /var/folders/6y/v5glmyqn4txdzjjjjdn0r32w0000gn/T/ipykernel_74063/1589118638.py in get_artist_genres(uri_list)
#       3     # call artists api on uri_chunk
# ----> 4     results = sp.artists(uri_list)['artists']
#       5     # extract genres and create a dataframe with the matching artist uri for merge later
#
# ~/opt/anaconda3/lib/python3.9/site-packages/spotipy/client.py in artists(self, artists)
#     401         tlist = [self._get_id("artist", a) for a in artists]
# --> 402         return self._get("artists/?ids=" + ",".join(tlist))
#     403
#
# ~/opt/anaconda3/lib/python3.9/site-packages/spotipy/client.py in _get(self, url, args, payload, **kwargs)
#     322
# --> 323         return self._internal_call("GET", url, payload, kwargs)
#     324
#
# ~/opt/anaconda3/lib/python3.9/site-packages/spotipy/client.py in _internal_call(self, method, url, payload, params)
#     306                 reason = None
# --> 307             raise SpotifyException(
#     308                 429,
#
# SpotifyException: http status: 429, code:-1 - /v1/artists/?ids=6olE6TJLqED3rqDCT0FyPh,6olE6TJLqED3rqDCT0FyPh,6olE6TJLqED3rqDCT0FyPh,6olE6TJLqED3rqDCT0FyPh,6olE6TJLqED3rqDCT0FyPh,6olE6TJLqED3rqDCT0FyPh,6olE6TJLqED3rqDCT0FyPh,3hyGGjxu73JuzBa757H6R5,6V70yeZQCoSR2M3fyW8qiA,5KeQyt1QJBjcutJ2AuLNO2,4gzpq5DPGxSnKTe4SA8HAU,1h6Cn3P4NGzXbaXidqURXs,67tgMwUfnmqzYsNAtnP6YJ,3C8RpaI3Go0yFF9whvKoED,3534yWWzmxx8NbKVoNolsK,0AkpPlFLnr0VQwZQeMGht0,1gR0gsQYfi6joyO1dlp76N,7gjAu1qr5C2grXeQFFOGeh,0qudezVgvl4Chd9BgNFB83,57anmI1X2hXWPrNagFdzZr,6veTV9sF06FBf2KN0xAdvo,57dN52uHvrHOxijzpIgu3E,6vWDO969PvNqNYHIOW5v0m,7bHm3B3jJju0q9FUdOgp3b,3C8RpaI3Go0yFF9whvKoED,4pb4rqWSoGUgxm63xmJ8xc,7tjbDPvrdvDshcpEMXKRVb,2pAWfrd7WFF3XhVt9GooDL,4IJczjB0fJ04gs4uvP0Fli,4YPh2MOSO13IAsOM2ouSXy,6vWDO969PvNqNYHIOW5v0m,6vWDO969PvNqNYHIOW5v0m,6vWDO969PvNqNYHIOW5v0m,5VptPtXbT0T4imW6GcobiW,587PA35pRGL1JwQr6idJbb,2S11VlKvbvSKyyb7Wk4YP1,4EVpmkEwrLYEg6jIsiPMIb,4IJczjB0fJ04gs4uvP0Fli,3gnrmLahFhVXRI9DA1MImH,3gnrmLahFhVXRI9DA1MImH,3gnrmLahFhVXRI9DA1MImH,4EVpmkEwrLYEg6jIsiPMIb,4EVpmkEwrLYEg6jIsiPMIb,4EVpmkEwrLYEg6jIsiPMIb,4EVpmkEwrLYEg6jIsiPMIb,3XSqByZe2kuUAquw8seGD6,4rwCk3DZwQa8uY7Cvfu4aM,7nkLRaWHImCvWGHdNGnhVE,6TsSBSisvQYCupsHmXe1iK,6lOCVUQbb9wzuZQbZQV9zn,0xOeVMOz2fVg5BJY3N6akT,5aMIbwZQvP2MHPMVC5zCGj,3yg8VEfEzpr8T9NkiEsycS,587PA35pRGL1JwQr6idJbb,23KIrX6iPiVOkx60F4bjNq,4EMtGVFvfCSrEmWaGV0roE,23KIrX6iPiVOkx60F4bjNq,7aA592KWirLsnfb5ulGWvU,3lLHpTOJ11tWiUNGYN14gt,59oA5WbbQvomJz2BuRG071,5lpdJ3wNP63XGxuoa7HkMS,7sgWBYtJpblXpJl2lU5WVs,0fA0VVWsXO9YnASrzqfmYu,4LLpKhyESsyAXpc4laK94U,4qwGe91Bz9K2T8jXTZ815W,2Xu7q46Hf02xOoEIm4E1Qs,4OBJLual30L7gRl5UkeRcT,5EvFsr3kj42KNv97ZEnqij,6DPYiyq5kWVQS4RGwxzPC7,3r0OeTcOw37N9juMYyyw39,1XkoF8ryArs86LZvFOkbyr,2MGT7CYlixSPxAnnkhLpaA,6V3F8MZrOKdT9fU686ybE9,6DPYiyq5kWVQS4RGwxzPC7,3ScY9CQxNLQei8Umvpx5g6,22bE4uQ6baNwSHPVcDxLCe,0F4ybIPzwLfT5xzZQlYBXP,0F4ybIPzwLfT5xzZQlYBXP,3oGVQWQy7lgTMuTnKUZZNZ,3oGVQWQy7lgTMuTnKUZZNZ,4uN3DsfENc7dp0OLO0FEIb,0Mz5XE0kb1GBnbLQm2VbcO,0av074qUwLn5eyzwqoq3xh,22WZ7M8sxp5THdruNY3gXt,2iEvnFsWxR0Syqu2JNopAd,1lZvg4fNAqHoj6I9N8naBM,4F84IBURUo98rz4r61KF70,36QJpDe2go2KgaRleHCDTp,1lZvg4fNAqHoj6I9N8naBM,0rpMdBzQXf7aYRnu5fDBJy,2yDodJUwXfdHzg4crwslUp,7pXu47GoqSYRajmBCjxdD6,2JRvXPGWiINrnJljNJhG5s,7sVQKNtdP2NylxMgbNOJMM,0K1q0nXQ8is36PzOKAMbNe,6qyi8X6MdP1lu6B1K6yh3h,6A43Djmhbe9100UwnI7epV,6A43Djmhbe9100UwnI7epV,0TcYeHEK9sBtv7xPbKhzHz,3TQ9JTBI2n2hfo7aRONEYV,1Y8cdNmUJH7yBTd9yOvr5i,2P3cjUru4H3fhSXXNxE9kA,0cQbJU1aAzvbEmTuljWLlF,6A43Djmhbe9100UwnI7epV,5me0Irg2ANcsgc93uaYrpb,3dXaa6jwM7B52GZpaJEIr5,4UXqAaa6dQYAk18Lv7PEgX,24XtlMhEMNdi822vi0MhY1,0cQbJU1aAzvbEmTuljWLlF,3PhoLpVuITZKcymswpck5b,6FBDaR13swtiWwGhX1WQsP,4Ui2kfOqGujY81UcPrb5KE,0LyfQWJT6nXafLPZqxe9Of,5f4QpKfy7ptCHwTqspnSJI,0YsLR3SQd5QTXAhGIGX7cl,1W9qOBYRTfP7HcizWN43G1,6xyaria4AcxjRuJZLkWvMW,2WKdxPFRD7IqZvlIAvhMgY,3ZotbHeyVQKxQCPDJuQ4SU,4kYSro6naA4h99UJvo89HB,4kYSro6naA4h99UJvo89HB,2Waw2sSbqvAwK8NwACNjVo,0nyc9SZGLITSOJASmTZsnZ,2Mu5NfyYm8n5iTomuKAEHl,2YZyLoL8N0Wb9xBt1NhZWg,1UQRtt7eHW6Bt4INNTUtb3,4kYSro6naA4h99UJvo89HB,2WImpqiHxgOKw0sXNOGtWl,5LfGQac0EIXyAN8aUwmNAQ,4EVpmkEwrLYEg6jIsiPMIb,5K4W6rqBFWDnAN6FQUkS6x,5K4W6rqBFWDnAN6FQUkS6x,0fA0VVWsXO9YnASrzqfmYu,1G9G7WwrXka3Z1r7aIDjI7,73sIBHcqh3Z3NyqHKZ7FOL,6Qm9stX6XO1a4c7BXQDDgc,4l1cKWYW591xnwEGxpUg3J,6aUgzC0cMh0StjV7LyFEDr,5K4W6rqBFWDnAN6FQUkS6x,1IELhvOMg5VQlU7syRm6CS,3tCxM1rTj2qUXsiQZxvt2I,6wFId9Jhuf9AKVzWboOj2B,3AA28KZvwAUcZuOKwyblJQ,066X20Nz7iquqkkCW6Jxy6,3AA28KZvwAUcZuOKwyblJQ,3AA28KZvwAUcZuOKwyblJQ,3AA28KZvwAUcZuOKwyblJQ,5wPoxI5si3eJsYYwyXV4Wi,1W9qOBYRTfP7HcizWN43G1,7nW3rZPhwZWlGPZgdDiJea,4EVpmkEwrLYEg6jIsiPMIb,1hak05VDAWZqSimeBx6fjQ,0FrpdcVlJQqibaz5HfBUrL,6zyPKJ4ePhYLsBEy4A6BVX,3RTzAwFprBqiskp550eSJX,2W8UTum7bU7ue6m0r14H97,0SwO7SWeDHJijQ3XNS7xEE,0IecGJbdBeYSOVtSPRehh5,4CTKqs11Zgsv8EZTVzx764,57dN52uHvrHOxijzpIgu3E,7hJcb9fa4alzcOq3EaNPoG,1G9G7WwrXka3Z1r7aIDjI7,1gR0gsQYfi6joyO1dlp76N,4l1cKWYW591xnwEGxpUg3J,3C8RpaI3Go0yFF9whvKoED,1LeVJ5GPeYDOVUjxx1y7Rp,066X20Nz7iquqkkCW6Jxy6,4ytkhMSAnrDP8XzRNlw9FS,4ytkhMSAnrDP8XzRNlw9FS,3C8RpaI3Go0yFF9whvKoED,3VNITwohbvU5Wuy5PC6dsI,3AA2 ...
#  Max Retries, reason: too many 502 error responses
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# <timed exec> in <module>
#
# ~/opt/anaconda3/lib/python3.9/concurrent/futures/_base.py in __exit__(self, exc_type, exc_val, exc_tb)
#     635
#     636     def __exit__(self, exc_type, exc_val, exc_tb):
# --> 637         self.shutdown(wait=True)
#     638         return False
#     639
#
# ~/opt/anaconda3/lib/python3.9/concurrent/futures/thread.py in shutdown(self, wait, cancel_futures)
#     233         if wait:
#     234             for t in self._threads:
# --> 235                 t.join()
#     236     shutdown.__doc__ = _base.Executor.shutdown.__doc__
#
# ~/opt/anaconda3/lib/python3.9/threading.py in join(self, timeout)
#    1058
#    1059         if timeout is None:
# -> 1060             self._wait_for_tstate_lock()
#    1061         else:
#    1062             # the behavior of a negative timeout isn't documented, but
#
# ~/opt/anaconda3/lib/python3.9/threading.py in _wait_for_tstate_lock(self, block, timeout)
#    1078
#    1079         try:
# -> 1080             if lock.acquire(block, timeout):
#    1081                 lock.release()
#    1082                 self._stop()
#
# KeyboardInterrupt:
# Max Retries reached
# Max Retries reached
# Max Retries reached
# Max Retries reached
# Max Retries reached
# Max Retries reached
# Max Retries reached
# Max Retries reached
# Max Retries reached
# Max Retries reached
# Max Retries reached
# Max Retries reached
# Max Retries reached
# Max Retries reached
# Max Retries reached
# Max Retries reached
# Max Retries reached
# Max Retries reached
# Max Retries reached
# Max Retries reached
# Max Retries reached
# Max Retries reached
# Max Retries reached
# Max Retries reached
# Max Retries reached
# Max Retries reached
# Max Retries reached
# Max Retries reached
# Max Retries reached
# Max Retries reached
# Max Retries reached
# Max Retries reached
# Max Retries reached
# Max Retries reached
# Max Retries reached
# Max Retries reached
# Max Retries reached
# Max Retries reached
# Max Retries reached
# Max Retries reached
# Max Retries reached
# Max Retries reached
# Max Retries reached
# Max Retries reached
# Max Retries reached
# Max Retries reached
# Max Retries reached
# Max Retries reached
# Max Retries reached
# Max Retries reached
# Max Retries reached
# Max Retries reached
# Max Retries reached
# Max Retries reached
# Max Retries reached
# Max Retries reached
# Max Retries reached
# Max Retries reached
# Max Retries reached
# Max Retries reached
# Max Retries reached
# Max Retries reached
# Max Retries reached
# Max Retries reached
# Max Retries reached
# Max Retries reached
# Max Retries reached
# Max Retries reached
# Max Retries reached
# Max Retries reached
# Max Retries reached
# Max Retries reached
# Max Retries reached
# Max Retries reached
# Max Retries reached
# Max Retries reached
# Max Retries reached
# Max Retries reached
# Max Retries reached
# Max Retries reached
# Max Retries reached
# Max Retries reached
# Max Retries reached
# Max Retries reached
# Max Retries reached
# Max Retries reached
# Max Retries reached
# Max Retries reached
# Max Retries reached
# Max Retries reached
# Max Retries reached
# Max Retries reached
# Max Retries reached
# Max Retries reached
# Max Retries reached
# Max Retries reached
# Max Retries reached
# Max Retries reached

# %% [markdown]
# ___
# ### Pull Genres without TPE

# %%
sp = authenticate(scope='user-library-read')

# %%
batches = []
for i in range(0, df.shape[0], 50):
    start = time.time()
   
    batches.append(df['artist_uri'][i:i+50])

# %%
batches[0]
# Out:
# 0     spotify:artist:6olE6TJLqED3rqDCT0FyPh
# 1     spotify:artist:6olE6TJLqED3rqDCT0FyPh
# 2     spotify:artist:6olE6TJLqED3rqDCT0FyPh
# 3     spotify:artist:6olE6TJLqED3rqDCT0FyPh
# 4     spotify:artist:6olE6TJLqED3rqDCT0FyPh
# 5     spotify:artist:6olE6TJLqED3rqDCT0FyPh
# 6     spotify:artist:6olE6TJLqED3rqDCT0FyPh
# 7     spotify:artist:3hyGGjxu73JuzBa757H6R5
# 8     spotify:artist:6V70yeZQCoSR2M3fyW8qiA
# 9     spotify:artist:5KeQyt1QJBjcutJ2AuLNO2
# 10    spotify:artist:4gzpq5DPGxSnKTe4SA8HAU
# 11    spotify:artist:1h6Cn3P4NGzXbaXidqURXs
# 12    spotify:artist:67tgMwUfnmqzYsNAtnP6YJ
# 13    spotify:artist:3C8RpaI3Go0yFF9whvKoED
# 14    spotify:artist:3534yWWzmxx8NbKVoNolsK
# 15    spotify:artist:0AkpPlFLnr0VQwZQeMGht0
# 16    spotify:artist:1gR0gsQYfi6joyO1dlp76N
# 17    spotify:artist:7gjAu1qr5C2grXeQFFOGeh
# 18    spotify:artist:0qudezVgvl4Chd9BgNFB83
# 19    spotify:artist:57anmI1X2hXWPrNagFdzZr
# 20    spotify:artist:6veTV9sF06FBf2KN0xAdvo
# 21    spotify:artist:57dN52uHvrHOxijzpIgu3E
# 22    spotify:artist:6vWDO969PvNqNYHIOW5v0m
# 23    spotify:artist:7bHm3B3jJju0q9FUdOgp3b
# 24    spotify:artist:3C8RpaI3Go0yFF9whvKoED
# 25    spotify:artist:4pb4rqWSoGUgxm63xmJ8xc
# 26    spotify:artist:7tjbDPvrdvDshcpEMXKRVb
# 27    spotify:artist:2pAWfrd7WFF3XhVt9GooDL
# 28    spotify:artist:4IJczjB0fJ04gs4uvP0Fli
# 29    spotify:artist:4YPh2MOSO13IAsOM2ouSXy
# 30    spotify:artist:6vWDO969PvNqNYHIOW5v0m
# 31    spotify:artist:6vWDO969PvNqNYHIOW5v0m
# 32    spotify:artist:6vWDO969PvNqNYHIOW5v0m
# 33    spotify:artist:5VptPtXbT0T4imW6GcobiW
# 34    spotify:artist:587PA35pRGL1JwQr6idJbb
# 35    spotify:artist:2S11VlKvbvSKyyb7Wk4YP1
# 36    spotify:artist:4EVpmkEwrLYEg6jIsiPMIb
# 37    spotify:artist:4IJczjB0fJ04gs4uvP0Fli
# 38    spotify:artist:3gnrmLahFhVXRI9DA1MImH
# 39    spotify:artist:3gnrmLahFhVXRI9DA1MImH
# 40    spotify:artist:3gnrmLahFhVXRI9DA1MImH
# 41    spotify:artist:4EVpmkEwrLYEg6jIsiPMIb
# 42    spotify:artist:4EVpmkEwrLYEg6jIsiPMIb
# 43    spotify:artist:4EVpmkEwrLYEg6jIsiPMIb
# 44    spotify:artist:4EVpmkEwrLYEg6jIsiPMIb
# 45    spotify:artist:3XSqByZe2kuUAquw8seGD6
# 46    spotify:artist:4rwCk3DZwQa8uY7Cvfu4aM
# 47    spotify:artist:7nkLRaWHImCvWGHdNGnhVE
# 48    spotify:artist:6TsSBSisvQYCupsHmXe1iK
# 49    spotify:artist:6lOCVUQbb9wzuZQbZQV9zn
# Name: artist_uri, dtype: object

# %%
artists = sp.artists(batches[0])['artists']

# %%
# %%time

genres = []

for i in range(0, df.shape[0], 50):
    start = time.time()
    print(i)
    batch_uris = df['artist_uri'][i:i+50]
    
    artists = sp.artists(batch_uris)['artists']
    
    for artist in artists:
        
        print(artist['genres'])
        genres.append(artist['genres'])
    
    end = time.time()
    print('loop time', end-start)
# Out:
# 0
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <timed exec> in <module>
#
# ~/opt/anaconda3/lib/python3.9/site-packages/spotipy/client.py in artists(self, artists)
#     400
#     401         tlist = [self._get_id("artist", a) for a in artists]
# --> 402         return self._get("artists/?ids=" + ",".join(tlist))
#     403
#     404     def artist_albums(
#
# ~/opt/anaconda3/lib/python3.9/site-packages/spotipy/client.py in _get(self, url, args, payload, **kwargs)
#     321             kwargs.update(args)
#     322
# --> 323         return self._internal_call("GET", url, payload, kwargs)
#     324
#     325     def _post(self, url, args=None, payload=None, **kwargs):
#
# ~/opt/anaconda3/lib/python3.9/site-packages/spotipy/client.py in _internal_call(self, method, url, payload, params)
#     264
#     265         try:
# --> 266             response = self._session.request(
#     267                 method, url, headers=headers, proxies=self.proxies,
#     268                 timeout=self.requests_timeout, **args
#
# ~/opt/anaconda3/lib/python3.9/site-packages/requests/sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     585         }
#     586         send_kwargs.update(settings)
# --> 587         resp = self.send(prep, **send_kwargs)
#     588
#     589         return resp
#
# ~/opt/anaconda3/lib/python3.9/site-packages/requests/sessions.py in send(self, request, **kwargs)
#     699
#     700         # Send the request
# --> 701         r = adapter.send(request, **kwargs)
#     702
#     703         # Total elapsed time of the request (approximately)
#
# ~/opt/anaconda3/lib/python3.9/site-packages/requests/adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     487         try:
#     488             if not chunked:
# --> 489                 resp = conn.urlopen(
#     490                     method=request.method,
#     491                     url=url,
#
# ~/opt/anaconda3/lib/python3.9/site-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     874
#     875             response.drain_conn()
# --> 876             retries.sleep(response)
#     877             log.debug("Retry: %s", url)
#     878             return self.urlopen(
#
# ~/opt/anaconda3/lib/python3.9/site-packages/urllib3/util/retry.py in sleep(self, response)
#     426
#     427         if self.respect_retry_after_header and response:
# --> 428             slept = self.sleep_for_retry(response)
#     429             if slept:
#     430                 return
#
# ~/opt/anaconda3/lib/python3.9/site-packages/urllib3/util/retry.py in sleep_for_retry(self, response)
#     405         retry_after = self.get_retry_after(response)
#     406         if retry_after:
# --> 407             time.sleep(retry_after)
#     408             return True
#     409
#
# KeyboardInterrupt:

# %%
# %%time
df[['genres']] = df['artist_uri'].apply(lambda uri: pd.Series(sp.artist(uri)['genres']))
# Out:
# HTTP Error for GET to https://api.spotify.com/v1/artists/6olE6TJLqED3rqDCT0FyPh with Params: {} returned 401 due to The access token expired
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# ~/opt/anaconda3/lib/python3.9/site-packages/spotipy/client.py in _internal_call(self, method, url, payload, params)
#     270
# --> 271             response.raise_for_status()
#     272             results = response.json()
#
# ~/opt/anaconda3/lib/python3.9/site-packages/requests/models.py in raise_for_status(self)
#    1020         if http_error_msg:
# -> 1021             raise HTTPError(http_error_msg, response=self)
#    1022
#
# HTTPError: 401 Client Error: Unauthorized for url: https://api.spotify.com/v1/artists/6olE6TJLqED3rqDCT0FyPh
#
# During handling of the above exception, another exception occurred:
#
# SpotifyException                          Traceback (most recent call last)
# <timed exec> in <module>
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/series.py in apply(self, func, convert_dtype, args, **kwargs)
#    4431         dtype: float64
#    4432         """
# -> 4433         return SeriesApply(self, func, convert_dtype, args, kwargs).apply()
#    4434
#    4435     def _reduce(
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/apply.py in apply(self)
#    1086             return self.apply_str()
#    1087
# -> 1088         return self.apply_standard()
#    1089
#    1090     def agg(self):
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/apply.py in apply_standard(self)
#    1141                 # List[Union[Callable[..., Any], str]]]]]"; expected
#    1142                 # "Callable[[Any], Any]"
# -> 1143                 mapped = lib.map_infer(
#    1144                     values,
#    1145                     f,  # type: ignore[arg-type]
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/_libs/lib.pyx in pandas._libs.lib.map_infer()
#
# <timed exec> in <lambda>(uri)
#
# ~/opt/anaconda3/lib/python3.9/site-packages/spotipy/client.py in artist(self, artist_id)
#     390
#     391         trid = self._get_id("artist", artist_id)
# --> 392         return self._get("artists/" + trid)
#     393
#     394     def artists(self, artists):
#
# ~/opt/anaconda3/lib/python3.9/site-packages/spotipy/client.py in _get(self, url, args, payload, **kwargs)
#     321             kwargs.update(args)
#     322
# --> 323         return self._internal_call("GET", url, payload, kwargs)
#     324
#     325     def _post(self, url, args=None, payload=None, **kwargs):
#
# ~/opt/anaconda3/lib/python3.9/site-packages/spotipy/client.py in _internal_call(self, method, url, payload, params)
#     291             )
#     292
# --> 293             raise SpotifyException(
#     294                 response.status_code,
#     295                 -1,
#
# SpotifyException: http status: 401, code:-1 - https://api.spotify.com/v1/artists/6olE6TJLqED3rqDCT0FyPh:
#  The access token expired, reason: None

# %% [markdown]
# - Below is Version 1, which was the initial attempt at extracting data
# - Kept this section in case you were curious how I started working with this data and how it ended up

# %% [markdown]
# ___
# ___
# # Version 1

# %% [markdown]
# Now, using the songs we've retrieved we can pull the audio features using our newly generated df and merge them to create my saved tracks with audio features:

# %%
liked_songs_features = handler("get_track_audio_features", my_liked_songs)

# %%
liked_songs_features.head()
# Out:
#                        id                                         track_name  \
# 0  2Nw6tjb0euV6LApzN4fU0a                                       Good for You
# 1  5RHY7WkAjAhpxuPN0CTd4F                                        True Lovers
# 2  5J8m6w5VmswbMBYUAFf44t  Every Teardrop Is A Waterfall (Coldplay Vs. Sw...
# 3  0VffaI2jwQknRrxpECYHsF                                          Greyhound
# 4  2yWyFT6bW1Rd9cjVvYi4v8                                       Superstylin'
#
#                 artist               artist_id                album_id  \
# 0          Spacey Jane  6V70yeZQCoSR2M3fyW8qiA  3zZi1vy6CnNZX7lbcRJtXo
# 1            Holy Holy  5KeQyt1QJBjcutJ2AuLNO2  6J8EzIkd1LeP07kIF77RNz
# 2             Coldplay  4gzpq5DPGxSnKTe4SA8HAU  4ljisoNarj0BpQSMIEv88L
# 3  Swedish House Mafia  1h6Cn3P4NGzXbaXidqURXs  4ljisoNarj0BpQSMIEv88L
# 4        Groove Armada  67tgMwUfnmqzYsNAtnP6YJ  1bS1J4OVGrpu6e2U2pHge6
#
#                                album release_date playlist_name  popularity  \
# 0                           Sunlight   2020-06-12   Liked_Songs          60
# 1                              Paint   2017-02-24   Liked_Songs          54
# 2                          Until Now   2012-01-01   Liked_Songs          51
# 3                          Until Now   2012-01-01   Liked_Songs          64
# 4  Goodbye Country (Hello Nightclub)   2001-07-11   Liked_Songs          63
#
#    explicit  ...  loudness  mode  speechiness  acousticness  instrumentalness  \
# 0      True  ...    -4.741     1       0.0385      0.000056           0.01060
# 1     False  ...    -5.092     0       0.0467      0.433000           0.05340
# 2     False  ...    -5.703     1       0.0585      0.000635           0.00775
# 3     False  ...    -4.989     1       0.0521      0.006660           0.87600
# 4     False  ...    -8.263     1       0.0558      0.003460           0.00131
#
#    liveness  valence    tempo  duration_ms  time_signature
# 0    0.1650    0.931  174.962       174760               4
# 1    0.0903    0.378  139.031       259964               4
# 2    0.5450    0.293  125.022       408829               4
# 3    0.2760    0.539  124.976       410097               4
# 4    0.2590    0.928  128.967       360427               4
#
# [5 rows x 24 columns]

# %% [markdown]
# Success! We've also added a column to signify that the user actively liked these select tracks. Let's save that as a CSV for evaluating music taste using only my liked songs:

# %%
liked_songs_features.to_csv('../data/my_savedtracks_with_features.csv')

# %% [markdown]
# ### Retrieving songs from playlists in my library

# %% [markdown]
# Depending on the user who logs in to the application, they might have more songs in their playlists than they do in their liked songs. Either way, it will be better to have more observations to train the model on when predicting songs they listen to.

# %%
liked_songs_features = pd.read_csv('../data/my_savedtracks_with_features.csv')

# %%
# %%time
users_tracks_features = handler("get_playlist_tracks_df", liked_songs_features)
# Out:
# CPU times: user 1.42 s, sys: 215 ms, total: 1.63 s
# Wall time: 21.3 s

# %% [markdown]
# - Above we called our get_playlist_tracks_df which:
#     - pulls a users playlists and provides a list of playlist_ids and playlist names
#     - pulls all tracks from a given playlist and extends them to a list
#     - creates an observation for each track as a dictionary that mirrors our get liked tracks function
#     - turns it into a dataframe to then pull the playlist tracks audio features
#     - finally concatenates our liked songs with our playlist songs into the final df with the index reset.

# %%
users_tracks_features.drop(columns='Unnamed: 0', inplace=True)

# %% [markdown]
# - We remove the Unnamed: 0 column from the returned total tracks

# %%
users_tracks_features.isnull().sum()
# Out:
# id                  0
# track_name          1
# artist              1
# artist_id           0
# album_id            0
# album               1
# release_date        0
# playlist_name       0
# popularity          0
# explicit            0
# user_liked          0
# danceability        0
# energy              0
# key                 0
# loudness            0
# mode                0
# speechiness         0
# acousticness        0
# instrumentalness    0
# liveness            0
# valence             0
# tempo               0
# duration_ms         0
# time_signature      0
# dtype: int64

# %% [markdown]
# - appears to be a couple null values, potentially all within the same row, let's check it out

# %%
users_tracks_features[users_tracks_features['track_name'].isnull()]
# Out:
#                          id track_name artist               artist_id  \
# 104  4LLvxxkWtt818FNO3cbsdo        NaN    NaN  0LyfQWJT6nXafLPZqxe9Of
#
#                    album_id album release_date playlist_name  popularity  \
# 104  6HBa9wXaZG8WIkhBY8p4aT   NaN         0000   Liked_Songs           0
#
#      explicit  ...  loudness  mode  speechiness  acousticness  \
# 104     False  ...     -3.28     1       0.0635        0.0939
#
#      instrumentalness  liveness  valence    tempo  duration_ms  time_signature
# 104          0.000004     0.105    0.877  145.037       211034               4
#
# [1 rows x 24 columns]

# %% [markdown]
# - Let's see what we get when we run the track_id through the get single track api endpoint
# - Update: When I opened the link to open the song in Spotify Web App, the song was no longer available, thus I will drop this record from my observations

# %%
sp = authenticate(scope='user-library-read')

# %%
sp.track(track_id='4LLvxxkWtt818FNO3cbsdo')
# Out:
# {'album': {'album_group': 'single',
#   'album_type': 'single',
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0LyfQWJT6nXafLPZqxe9Of'},
#     'href': 'https://api.spotify.com/v1/artists/0LyfQWJT6nXafLPZqxe9Of',
#     'id': '0LyfQWJT6nXafLPZqxe9Of',
#     'name': 'Various Artists',
#     'type': 'artist',
#     'uri': 'spotify:artist:0LyfQWJT6nXafLPZqxe9Of'}],
#   'available_markets': [],
#   'external_urls': {'spotify': 'https://open.spotify.com/album/6HBa9wXaZG8WIkhBY8p4aT'},
#   'href': 'https://api.spotify.com/v1/albums/6HBa9wXaZG8WIkhBY8p4aT',
#   'id': '6HBa9wXaZG8WIkhBY8p4aT',
#   'images': [],
#   'name': '',
#   'release_date': '0000',
#   'release_date_precision': 'year',
#   'total_tracks': 1,
#   'type': 'album',
#   'uri': 'spotify:album:6HBa9wXaZG8WIkhBY8p4aT'},
#  'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0LyfQWJT6nXafLPZqxe9Of'},
#    'href': 'https://api.spotify.com/v1/artists/0LyfQWJT6nXafLPZqxe9Of',
#    'id': '0LyfQWJT6nXafLPZqxe9Of',
#    'name': '',
#    'type': 'artist',
#    'uri': 'spotify:artist:0LyfQWJT6nXafLPZqxe9Of'}],
#  'available_markets': [],
#  'disc_number': 1,
#  'duration_ms': 0,
#  'explicit': False,
#  'external_ids': {},
#  'external_urls': {'spotify': 'https://open.spotify.com/track/4LLvxxkWtt818FNO3cbsdo'},
#  'href': 'https://api.spotify.com/v1/tracks/4LLvxxkWtt818FNO3cbsdo',
#  'id': '4LLvxxkWtt818FNO3cbsdo',
#  'is_local': False,
#  'name': '',
#  'popularity': 0,
#  'preview_url': None,
#  'track_number': 1,
#  'type': 'track',
#  'uri': 'spotify:track:4LLvxxkWtt818FNO3cbsdo'}

# %%
users_tracks_features.shape
# Out:
# (3618, 24)

# %%
users_tracks_features.dropna().shape
# Out:
# (3617, 24)

# %%
users_tracks_features.dropna(inplace=True)

# %%
users_tracks_features.isnull().sum().sum()
# Out:
# 0

# %% [markdown]
# - Now that null values have been taken care of, because Liked Songs will most likely be selected from different playlists the users have listened to and the same songs can exist across similar playlists, there will no doubt be duplicate values
# - Let's identify the number of duplicates and then take steps to get rid of rows we don't need and keep the records we want to keep.
#     - in this case, records that are under our Liked Songs Playlist

# %%
users_tracks_features['id'].duplicated().value_counts()
# Out:
# False    2541
# True     1076
# Name: id, dtype: int64

# %% [markdown]
# - As expected we have duplicate tracks (1074), let's create a copy of our tracks df sorting based on the 'user_liked' feature we added denoting that a user actively selected an item.
# - We will sort by DESC order so that when we run drop_duplicates, we can keep the first record which if duplicated, will be in the liked playlist

# %%
cleaned_of_dupes = users_tracks_features.sort_values(by='user_liked', ascending=False).copy()

# %%
cleaned_of_dupes = cleaned_of_dupes.drop_duplicates(subset='id', keep='first')

# %%
cleaned_of_dupes.shape
# Out:
# (2541, 24)

# %%
cleaned_of_dupes[cleaned_of_dupes['user_liked']==1].shape
# Out:
# (634, 24)

# %% [markdown]
# - We have succesfully retained all of our liked songs (635 - null value) and removed all other duplicates for a total record of ~2500 tracks.
# - Using this cleaned df let's save to csv and jump into EDA!

# %%
cleaned_of_dupes.to_csv('../data/allmy_tracks_with_features.csv')

# %%
import get_tracks_methods
import json

# %%
sp = get_tracks_methods.authenticate(scope='user-library-read')
# Out:
# Please authorize the app by visiting this URL: https://accounts.spotify.com/authorize?client_id=fd5183b4728840a989108098987ef843&response_type=code&redirect_uri=http%3A%2F%2Flocalhost%3A8080%2Fcallback&scope=user-library-read
# Enter the authorization code:  AQDCqhJ-KDFVFblmmIy8fXALb-0_jTKDOByOd95cK7MKbanOhg2RUUPBgGz-T2hACZXcmIkp0FpeQe3S6SuyO9XTRN5Pb8C1J4xkURH_npvigJ4fSpASILg9ZWHdjYwhtcSTs2nryTHUpq1-x3eDKqyQaB85qeoqADl-B_EAn72HI3VgXPm-5lji2RTg0dEBtvUuYRk

# %%
# get lists of playlist ids and names
playlist_ids, playlist_names = get_tracks_methods.get_playlists(sp)

# %%
len(playlist_ids), len(playlist_names)
# Out:
# (28, 28)

# %%
playlist_tracks = []
# loop through zippled playlist ids and names
for playlist_id, playlist_name in zip(playlist_ids, playlist_names):
    # get tracks from playlist
    playlist_tracks.extend(get_tracks_methods.get_all_playlist_tracks(sp, playlist_id))

# %%
len(playlist_tracks)
# Out:
# 2396

# %%
type(playlist_tracks)
# Out:
# list

# %%
type(playlist_tracks[0])
# Out:
# dict

# %%
playlist_tracks[0]['track']['id']
# Out:
# '1pUsdir2xhSxP0RyBe9lLH'

# %%
flattened_tracks = []
for i in range(0, len(playlist_tracks)+1):
    # print(i)
    # print(playlist_tracks[i]["track"]["id"])
    try:
        # flattened_track = {"id": playlist_tracks[i]["track"]["id"]}
        # flattened_tracks.append(flattened_track)
        flattened_track = {
                "id": playlist_tracks[i]["track"]["id"],
                "track_name": playlist_tracks[i]["track"]["name"],
                "artist": playlist_tracks[i]["track"]["artists"][0]["name"],
                "artist_id": playlist_tracks[i]["track"]["artists"][0]["id"],
                "album_id": playlist_tracks[i]["track"]["album"]["id"],
                "album": playlist_tracks[i]["track"]["album"]["name"],
                "release_date": playlist_tracks[i]["track"]["album"]["release_date"],
                "playlist_name": playlist_name,
                "popularity": playlist_tracks[i]["track"]["popularity"],
                "explicit": playlist_tracks[i]["track"]["explicit"],
                "user_liked": 0
            }
        flattened_tracks.append(flattened_track)
    except:
        continue

# %%
len(flattened_tracks)
# Out:
# 2391

# %%
# turn flattened tracks into pandas df and return
playlist_tracks_df = pd.DataFrame(flattened_tracks)

playlist_tracks_df.head()


# # track_features = handler('get_track_audio_features',playlist_tracks_df)

# # final_df = merger(df, track_features)
# Out:
#                        id                          track_name  \
# 0  1pUsdir2xhSxP0RyBe9lLH                              Icarus
# 1  3H3cOQ6LBLSvmcaV7QkZEu                         Aerodynamic
# 2  7sLnn2UOttrEPBZSFyIsYh             Wolfgang's 5th Symphony
# 3  3ezkJgagRPZ39KCTrKcSI7  Ghosts 'n' Stuff (feat. Rob Swire)
# 4  0VffaI2jwQknRrxpECYHsF                           Greyhound
#
#                 artist               artist_id                album_id  \
# 0               Madeon  4pb4rqWSoGUgxm63xmJ8xc  3uKLwDjku2Us0c81LEmftR
# 1            Daft Punk  4tZwfgrHOc3mvqYlEYSvVi  2noRn2Aes5aoNVsU6iWThc
# 2     Wolfgang Gartner  3534yWWzmxx8NbKVoNolsK  3kDILp9v0rDVPMAJUQYbZx
# 3             deadmau5  2CIMQHirSU0MQqyYHq0eOx  3eNZDL2rqTVvmiC1f0yFwF
# 4  Swedish House Mafia  1h6Cn3P4NGzXbaXidqURXs  4ljisoNarj0BpQSMIEv88L
#
#                                             album release_date playlist_name  \
# 0                              Adventure (Deluxe)   2015-03-30   Fleet Foxes
# 1                                       Discovery   2001-03-12   Fleet Foxes
# 2                                      Back Story   2012-09-04   Fleet Foxes
# 3  For Lack of a Better Name (The Extended Mixes)         2009   Fleet Foxes
# 4                                       Until Now   2012-01-01   Fleet Foxes
#
#    popularity  explicit  user_liked
# 0          49     False           0
# 1          62     False           0
# 2          43     False           0
# 3          61     False           0
# 4          63     False           0

# %%
track_ids = [track for track in playlist_tracks_df['id']]

# %%
track_ids
# Out:
# ['1pUsdir2xhSxP0RyBe9lLH',
#  '3H3cOQ6LBLSvmcaV7QkZEu',
#  '7sLnn2UOttrEPBZSFyIsYh',
#  '3ezkJgagRPZ39KCTrKcSI7',
#  '0VffaI2jwQknRrxpECYHsF',
#  '3EfOzBsC8in9ZYuD3NR2v9',
#  '2JUNwx3qKeKiNntIKK2rBg',
#  '3ERVrhNx8p2I3xY9RomH9t',
#  '4QwMCXtsoCdIrK7oNJkhGW',
#  '5PtEpuVX03k9bOUwilL5EO',
#  '4Xw9TXNrLhzp2JBx3X8j9l',
#  '64y85LeHY8Z6OlTOM9cpKD',
#  '2xeqCSNWOe59rGppUKggeF',
#  '7bKkIsUZ6sb5Lt73oNTLUw',
#  '11IWX2lE69q4Nt8B0ttt1L',
#  '27Es1J9GNKf0pZLy3sdzjl',
#  '5ZHts4IatJgG1ZIaIN3qIL',
#  '7cMFjxhbXBpOlais7KMF3j',
#  '49X0LAl6faAusYq02PRAY6',
#  '0DiWol3AO6WpXZgp0goxAV',
#  '33yAEqzKXexYM3WlOYtTfQ',
#  '6MpRH2AODF7OM2Md1zzaEV',
#  '4OlWYCYNtAkWdQUiQRA97f',
#  '5noQJkpVfHt2D4df2GXieV',
#  '4wSmqFg31t6LsQWtzYAJob',
#  '0wP9okoDWmbeC2w9E8ZzPu',
#  '72iqZG1zy55rXQPBBB4a21',
#  '2JGIjJEohXvvphtxTqStha',
#  '6fLGuyj9ITWTp4TolAeCaR',
#  '4ZVanZJ1HJdxYd8ABLXGUM',
#  '1ol7LFeUEsEvG1s1n07wGn',
#  '1ScXXDRjg8Xxx2VqWs9Kus',
#  '42pAisqMtyzuWjMzts9jRH',
#  '39CKNNJskTBGnLGOTmgERN',
#  '2YKm2APgaXNsseFrizTsKM',
#  '5CF0XiE4EnI37za2l3WZmH',
#  '0DC6XJuyJIotOK74ahqHEo',
#  '0gabQBBx9aNqYuaxI93lSy',
#  '1nIvUHUPtKLz59eMCGlppe',
#  '6cy80H203NqMxzep7cAdeR',
#  '48eflo2pX0i5bY02tPOBX0',
#  '0uqoO6T12XapKNDvsD0vUz',
#  '56bGndP0p3GQdM1IbyIZSI',
#  '4be2JG8XH6UiVAyJw0WViH',
#  '3X8j1FD6HgKXxj51KUuNY5',
#  '6Ox9p9y3IZM18o0gie9rF2',
#  '7lO0iUML3yOiNZUOzhEfci',
#  '5GFsQYcVVYRYxTwrfj0II5',
#  '0SK07ztwe5CKetJZ6pyN6z',
#  '5f8j3cynO1ev4oi69MBdzF',
#  '7duORjVt6gJWqY2Cbx2NII',
#  '4WbYQldIHAZ5q3bHsSyt4B',
#  '1yLpMPdAuJe9Ioz6YdROCf',
#  '4gIXh6RG8XFpov4DV63foI',
#  '2yaq5pGCOa0VElPp0Rj7rK',
#  '5Sg2yJFvLWaUoBoxSNUSlE',
#  '2D99Uy5lyGomFpbPxvvDSx',
#  '3cLBnxhnvoFzB69xtMSqPl',
#  '1kLsVPA3HnsIqWIvXiiwkY',
#  '53Gat1r9dYQkmqKA00kOkW',
#  '7jvw3ndt4zaVGdnevji6av',
#  '3CzBTb706y2XskRuIioPGQ',
#  '5kFhcbmdoRVKO2st1dvoPG',
#  '59lMFonsVcHZNOvlQvDmlJ',
#  '1AyRpRvLwUwkXwGGuNZHmN',
#  '5EvuUq5j67inDYsln3oM8k',
#  '0FlG0OC5bVK0juDgKzBd3b',
#  '2qPuqNzXKGJxUGix3Ot6ff',
#  '0IhR1VGR8ogQ5C5Q195agT',
#  '7d8HDIkILIKOODgur6TJyX',
#  '3qcTnQQwjuLOhzrBC0yzx7',
#  '2ZIb3X85hIyDl639erNbGV',
#  '43M3Hb61vb3BQVLKPx5zqC',
#  '6w0En75J6OPIeHVUX4mgQk',
#  '1d4Dmarw5cvGO7E064JV6g',
#  '4jxjzPTHm8RxzKHC1y4el2',
#  '1SN0nYSdqfoGYSZLZf4qJb',
#  '3Xy4ef0ZzDHTRjj1UTPoZH',
#  '42BDtgy019hkiSTGhhabQO',
#  '59PNvvlcEnDOwbNZlQnU0b',
#  '7vCWY6sLfV2QJtryUJTijO',
#  '68ywgC593GMnmYFiEEdiGM',
#  '6lfQyw2E3FXchL3dEBLCSv',
#  '0i1oQXqI3DDzyn5VImnJnW',
#  '0UXgLWIRmHi4YHziuO95WH',
#  '6OTtEGdeAgip7GRRegrwj0',
#  '2T1Jy8vfnkcr8gQqnfWa0a',
#  '0KivYtOOhuQTbbnmwvtOpF',
#  '1VEOAiwJr9bdknNu0Tw9pJ',
#  '4yJtGrXjf0jFQBnSUJz6is',
#  '3RLTOAqa72Kn7gh6NzaRot',
#  '5ctxZzMC6rFHAHJRcKmAXV',
#  '2aXB8RMcgvHKzFkT5zTDc2',
#  '1v3wXAhfAzDum5LbznnAeK',
#  '5FHgsxHq7ZpFGbr7B4aZmh',
#  '6oKjXGzJZI2AgB8KQNkFjS',
#  '3w7iexDcL6aI9rVV2Od1Sf',
#  '69zj1JgwiHSpn7QybWk68c',
#  '1CYvZwM5c7PlYLCaGNSUmY',
#  '6juOg9JlOFHLnn59DPg37u',
#  '5NptWVOhMkCcbeiHFVcEU3',
#  '3lLfTXD86fSFhd4HEXSomN',
#  '6KFQArmeZWqgvgsSLZoF2k',
#  '4SzBsaVhi2GfwTKL3jXtQb',
#  '5MkiURj4W62bl7cp65bmE5',
#  '4NwtdokNH5osyLmXLfoxMe',
#  '5WC2QExswNORZSS3Op3osx',
#  '1r9uIhxkwMmhYKAzOxidnH',
#  '3Siz2aFkAy4RabFZUgIh2b',
#  '5dmXlBpxb4kR7yuqJA53hP',
#  '1tHw5r183IimkK6GhdrzEa',
#  '1D7pJ9CBEQa9O48kgB5acI',
#  '5GNwT4AkWakd4RJxyAIB7b',
#  '0pVtxJ7J42rFFt3xCoeFl1',
#  '1gzeeKPqrUPBIK55FuZHwv',
#  '2qLw68DoxlMCZ50hMyeC3r',
#  '7uqwwsWuVbCAQWN5sOZX8y',
#  '4zkSqnyv3re6lZhLRYghY8',
#  '4TVrdSsBbr4RYWBqyVdATT',
#  '5woBPV32uMFJMjofU3SAIF',
#  '3izNNOyxILleM8S1An2pgs',
#  '6ChCmtVm2GMzCxnNcDTG0E',
#  '64FOp40A9iQ7ofF2BXTiuo',
#  '64EseGtnsKO1WazYnOmSQW',
#  '0Tws0QKg2kuKRZbtWjZCCF',
#  '24dKpt8v2WWPUnezRfVIfu',
#  '6S4uXxtsjj2VPcsm5Qc9Sg',
#  '4OHpByZuBmjmirLn7bgLiI',
#  '7anDaJSkAd3iMxh4eREXad',
#  '0gL7REEt5oI4DfvP8dJnUO',
#  '1zdag1IBYD6cx96Recn99f',
#  '52aezt59mUrxPTBvPtGiED',
#  '4LKACHRdsjkkmmqnNk9ltf',
#  '3iGAQ0io73I6cPRWrowOuo',
#  '45KcNtFPkHTJDewKu7CHWN',
#  '4ZtUnXyPDfNIUSDq9ayPJn',
#  '4xapquYYl8L8rJgJKOac4u',
#  '1Dsvo4jg4zbpcAtYTu36Bd',
#  '59CXAYlK1zvnnkzf45PDJh',
#  '7usJ3shL4YCmg6E5G9QyrZ',
#  '2BlShWnePIpXlSUE5H3lFW',
#  '5R2ZqLZeKRzAEH1eehC4LM',
#  '2xDwUbS2Aa95nKOYSYF0yS',
#  '7lIzjavZD2daSv1GcJ20a8',
#  '6aKmBBQbxGwngRdXQiuocE',
#  '1avKBPPKEPbBfkDXw5pgqk',
#  '0CPedjUtWZsOsCfnKE0bh2',
#  '6OyMZCHQSMUwW8bfMep03X',
#  '4pn9rxj3pb6mT4tbEK6U6f',
#  '1p3RlfMwnyB2dHptgYMxmP',
#  '2p4m3kCprNIgAlwtLpna0z',
#  '2we5Kg4V4iL5MXFZyISuxj',
#  '32xyuQ8X1A4x6hih7sXKEw',
#  '1iExAMUXD8UEqsb2dRQFTN',
#  '4bzf6fRnfeoueguZnzmZLu',
#  '7totFdrt6h7u3lvmpvvhMU',
#  '1ss2wROyWzatTXQ5oOxeQV',
#  '3ZE1fdPEB2NsklHOCE57DL',
#  '7rptL6A3YIKxspapba3cVl',
#  '2YSwN4gkDv3ciynj1sCNtI',
#  '6u4ZSORwYzMIgLNxVaSnIv',
#  '1DiQiK4QN2Do4oWFlHhHQN',
#  '1Z5ZpCms35ol3q1puPgvhL',
#  '2DPkdgEZ7Q7mpbbKS5Sd3W',
#  '3H4baOfyJJ3SgiB9Us7Z7v',
#  '1KNrXgDWmhBWcSmTC29JT4',
#  '7piFPg3kuRbodjCBWjUsXS',
#  '4jcPYkd99rQr6J8nw001ep',
#  '6Sw6pt7ksxQjwt1oOT4sU9',
#  '2uIzGnH2EaDONGO0ba5BPx',
#  '3xNj0lb1pvVAdkHi4NUbu5',
#  '72iqZG1zy55rXQPBBB4a21',
#  '5RTCq5iKo2mST6S3FsdTgL',
#  '2JGIjJEohXvvphtxTqStha',
#  '4TZQllvbUyeqYRc97GmEiU',
#  '6fLGuyj9ITWTp4TolAeCaR',
#  '7l97Pv9C9521GzCnVl5j7Q',
#  '4ZVanZJ1HJdxYd8ABLXGUM',
#  '18gMl1DCS7uSGBLvP8lUew',
#  '1ol7LFeUEsEvG1s1n07wGn',
#  '1ScXXDRjg8Xxx2VqWs9Kus',
#  '0aHKoKRiZMVBCJZfn0tMYf',
#  '42pAisqMtyzuWjMzts9jRH',
#  '5gc8pkQrApF4pNB1jqBBo0',
#  '39CKNNJskTBGnLGOTmgERN',
#  '2YKm2APgaXNsseFrizTsKM',
#  '6OcYQzXqIeoqcd0uAVtoDQ',
#  '5CF0XiE4EnI37za2l3WZmH',
#  '0DC6XJuyJIotOK74ahqHEo',
#  '0Ec33EQozu9PYBCYqbTgrs',
#  '0gabQBBx9aNqYuaxI93lSy',
#  '7FWscyNNmpqwX66QUdqUGk',
#  '1nIvUHUPtKLz59eMCGlppe',
#  '3ymLmxKsbzXvy52O2eK0bL',
#  '6cy80H203NqMxzep7cAdeR',
#  '3800Ea0W8Q0YFPX0z7Z9Pj',
#  '2bSU8MSJgztvu1GAZSmdaw',
#  '48eflo2pX0i5bY02tPOBX0',
#  '0uqoO6T12XapKNDvsD0vUz',
#  '0nSchxt6Ucc5gSX5n8HnLV',
#  '56bGndP0p3GQdM1IbyIZSI',
#  '4be2JG8XH6UiVAyJw0WViH',
#  '3X8j1FD6HgKXxj51KUuNY5',
#  '45T6DM5Tu2YR5FvAOg2m7Y',
#  '6Ox9p9y3IZM18o0gie9rF2',
#  '7lO0iUML3yOiNZUOzhEfci',
#  '5GFsQYcVVYRYxTwrfj0II5',
#  '5f8j3cynO1ev4oi69MBdzF',
#  '0SK07ztwe5CKetJZ6pyN6z',
#  '7duORjVt6gJWqY2Cbx2NII',
#  '4WbYQldIHAZ5q3bHsSyt4B',
#  '1yLpMPdAuJe9Ioz6YdROCf',
#  '4gIXh6RG8XFpov4DV63foI',
#  '2yaq5pGCOa0VElPp0Rj7rK',
#  '5Sg2yJFvLWaUoBoxSNUSlE',
#  '2D99Uy5lyGomFpbPxvvDSx',
#  '3cLBnxhnvoFzB69xtMSqPl',
#  '1kLsVPA3HnsIqWIvXiiwkY',
#  '53Gat1r9dYQkmqKA00kOkW',
#  '7jvw3ndt4zaVGdnevji6av',
#  '3CzBTb706y2XskRuIioPGQ',
#  '5kFhcbmdoRVKO2st1dvoPG',
#  '59lMFonsVcHZNOvlQvDmlJ',
#  '1AyRpRvLwUwkXwGGuNZHmN',
#  '5EvuUq5j67inDYsln3oM8k',
#  '0FlG0OC5bVK0juDgKzBd3b',
#  '2qPuqNzXKGJxUGix3Ot6ff',
#  '0IhR1VGR8ogQ5C5Q195agT',
#  '7d8HDIkILIKOODgur6TJyX',
#  '3qcTnQQwjuLOhzrBC0yzx7',
#  '43M3Hb61vb3BQVLKPx5zqC',
#  '2ZIb3X85hIyDl639erNbGV',
#  '6w0En75J6OPIeHVUX4mgQk',
#  '1d4Dmarw5cvGO7E064JV6g',
#  '4jxjzPTHm8RxzKHC1y4el2',
#  '1SN0nYSdqfoGYSZLZf4qJb',
#  '3Xy4ef0ZzDHTRjj1UTPoZH',
#  '42BDtgy019hkiSTGhhabQO',
#  '59PNvvlcEnDOwbNZlQnU0b',
#  '7vCWY6sLfV2QJtryUJTijO',
#  '68ywgC593GMnmYFiEEdiGM',
#  '6lfQyw2E3FXchL3dEBLCSv',
#  '0i1oQXqI3DDzyn5VImnJnW',
#  '0UXgLWIRmHi4YHziuO95WH',
#  '6OTtEGdeAgip7GRRegrwj0',
#  '2T1Jy8vfnkcr8gQqnfWa0a',
#  '0KivYtOOhuQTbbnmwvtOpF',
#  '1VEOAiwJr9bdknNu0Tw9pJ',
#  '4yJtGrXjf0jFQBnSUJz6is',
#  '3RLTOAqa72Kn7gh6NzaRot',
#  '5ctxZzMC6rFHAHJRcKmAXV',
#  '2aXB8RMcgvHKzFkT5zTDc2',
#  '1v3wXAhfAzDum5LbznnAeK',
#  '5FHgsxHq7ZpFGbr7B4aZmh',
#  '6oKjXGzJZI2AgB8KQNkFjS',
#  '3w7iexDcL6aI9rVV2Od1Sf',
#  '69zj1JgwiHSpn7QybWk68c',
#  '1CYvZwM5c7PlYLCaGNSUmY',
#  '6juOg9JlOFHLnn59DPg37u',
#  '5NptWVOhMkCcbeiHFVcEU3',
#  '3lLfTXD86fSFhd4HEXSomN',
#  '6KFQArmeZWqgvgsSLZoF2k',
#  '4SzBsaVhi2GfwTKL3jXtQb',
#  '5MkiURj4W62bl7cp65bmE5',
#  '4NwtdokNH5osyLmXLfoxMe',
#  '5WC2QExswNORZSS3Op3osx',
#  '1r9uIhxkwMmhYKAzOxidnH',
#  '3Siz2aFkAy4RabFZUgIh2b',
#  '5dmXlBpxb4kR7yuqJA53hP',
#  '1tHw5r183IimkK6GhdrzEa',
#  '1D7pJ9CBEQa9O48kgB5acI',
#  '5GNwT4AkWakd4RJxyAIB7b',
#  '0pVtxJ7J42rFFt3xCoeFl1',
#  '1gzeeKPqrUPBIK55FuZHwv',
#  '2qLw68DoxlMCZ50hMyeC3r',
#  '7uqwwsWuVbCAQWN5sOZX8y',
#  '4zkSqnyv3re6lZhLRYghY8',
#  '4TVrdSsBbr4RYWBqyVdATT',
#  '5woBPV32uMFJMjofU3SAIF',
#  '3izNNOyxILleM8S1An2pgs',
#  '6ChCmtVm2GMzCxnNcDTG0E',
#  '64FOp40A9iQ7ofF2BXTiuo',
#  '64EseGtnsKO1WazYnOmSQW',
#  '0Tws0QKg2kuKRZbtWjZCCF',
#  '24dKpt8v2WWPUnezRfVIfu',
#  '6S4uXxtsjj2VPcsm5Qc9Sg',
#  '4OHpByZuBmjmirLn7bgLiI',
#  '7anDaJSkAd3iMxh4eREXad',
#  '0gL7REEt5oI4DfvP8dJnUO',
#  '1zdag1IBYD6cx96Recn99f',
#  '52aezt59mUrxPTBvPtGiED',
#  '4LKACHRdsjkkmmqnNk9ltf',
#  '3iGAQ0io73I6cPRWrowOuo',
#  '45KcNtFPkHTJDewKu7CHWN',
#  '4ZtUnXyPDfNIUSDq9ayPJn',
#  '4xapquYYl8L8rJgJKOac4u',
#  '59CXAYlK1zvnnkzf45PDJh',
#  '7usJ3shL4YCmg6E5G9QyrZ',
#  '2BlShWnePIpXlSUE5H3lFW',
#  '5R2ZqLZeKRzAEH1eehC4LM',
#  '2xDwUbS2Aa95nKOYSYF0yS',
#  '6aKmBBQbxGwngRdXQiuocE',
#  '1avKBPPKEPbBfkDXw5pgqk',
#  '6OyMZCHQSMUwW8bfMep03X',
#  '1p3RlfMwnyB2dHptgYMxmP',
#  '1iExAMUXD8UEqsb2dRQFTN',
#  '2YSwN4gkDv3ciynj1sCNtI',
#  '2DPkdgEZ7Q7mpbbKS5Sd3W',
#  '4jcPYkd99rQr6J8nw001ep',
#  '2uIzGnH2EaDONGO0ba5BPx',
#  '5T3dDauGOuXKFrh4KHfMz4',
#  '0DZVMnB9urCb8ostPjSLcm',
#  '1JVCtAJa6wUM1c1s16LjJS',
#  '43Lr0diCwSkgj3LjrPtLdX',
#  '0i7lfu19rS6aLiILlmxtEy',
#  '7jmVErRH7TIzN3beKCrp1T',
#  '6acEbmgaMXuholTku5DqI3',
#  '5atR7mSPMQhbQUo94FZWfM',
#  '6KEDo5qcETA5cOkXDUjZzK',
#  '7d5f3BB5QBeW499JNGkDWm',
#  '3BYTscqrZx3oFCCJ2SEtFY',
#  '0HcK6zxTTcvVWd1Wrl0X2H',
#  '6QEEL4dneyVz4uc0AK06AH',
#  '4JJ51ar6WUtGNk9UkAwChy',
#  '18Om8CeG9hnbRZAwFpgwG8',
#  '4YXAYNe2eBH4WE98ooq3YS',
#  '72VAZykUYrfGgCPQb1K0Fl',
#  '6L0EgLzg7kse740uBkRHAp',
#  '2AcSfYwSVlz3QC6IWg65fm',
#  '6xTwl9KbqG1bbEAF2wxB24',
#  '3q8qkEMb565kiJL4EsleL1',
#  '2mdhPvFf63SgzDJ0NTJCYC',
#  '1NycBRM33ttxJyoegMIm3L',
#  '5KxwgypVKwLQ9dsYMywfe1',
#  '6AkkiVb66gElHoQ4twGlh2',
#  '1sEq1ekC6mZCNZa8HfY27B',
#  '0XTFwWS1FobeUIsPAAvyXs',
#  '7CIltIGGVQ2HDszvSDLa16',
#  '735PPiFIjTUooMSxe0i8vE',
#  '2HkxiTlpGYN5BBcHdk42WZ',
#  '7nyzASKwXsEe8AGE65s8tf',
#  '7gUflFgpdkBJMDYwBXLCN8',
#  '2RSKEbeLmxViLh7UrSF9rO',
#  '4jq4oouSIg07Dor7VovakH',
#  '2yWbPjLr9atCkyQ06L6tHI',
#  '1HbSDefGvrJCeDHLkBs9ZH',
#  '0A7TK3QF8Bxs0m4Kq9z35e',
#  '27Es1J9GNKf0pZLy3sdzjl',
#  '3td69vL9Py7Ai9wfXYnvji',
#  '7uPmQttafLiJyju14JREY4',
#  '1KBN9lYx9QkfUJC3NSXlhQ',
#  '05oETzWbd4SI33qK2gbJfR',
#  '0IVAlb0cFCH1cQ974iR1TU',
#  '5KUNwkaNf8l5A9sXZhiCgI',
#  '4NpC4SOnLCBEUVOGnWIucV',
#  '19Ym5Sg0YyOCa6ao21bdoG',
#  '2cmRpmO04TLaKPzmAzySYZ',
#  '2I1W3hcSsPIsEJfD69pHrW',
#  '4lJ6YVXQ0jUk5ILu0PSrA4',
#  '3HdcqQpq7zb5GbEKBDY34p',
#  '2VGDntFPvgvqSiUf9ITEfW',
#  '2XLAzm8bMDSI7MhbRW8nVj',
#  '64y85LeHY8Z6OlTOM9cpKD',
#  '6iX1QW1gGIVNEItnqyvFfH',
#  '6MgGapP3EPFm9kYUvYBTZR',
#  '0uEp9E98JB5awlA084uaIg',
#  '5HQ639Z3ms3hnZx0KfWnkp',
#  '16OwZQuzMqnwn3FZsCBZly',
#  '6FY7iUeQAlAGqb9E1GDSPx',
#  '4wSmqFg31t6LsQWtzYAJob',
#  '7aKWgpecgLEqisWcXPElDl',
#  '1QJb6LWvPXZpTMiqqODqkH',
#  '3f3HHRPF5vAo90GwdpDMaQ',
#  '4zVtyyuXiLAzSs9I5meIyO',
#  '471sXvN5C5vfMSBdKrGpo7',
#  '0Q0IVlqMV64kNLlwjPj0Hl',
#  '254bXAqt3zP6P50BdQvEsq',
#  '5hWLHFSmomXmeTXEE478My',
#  '5BYWuQEiyb6bxJGWIvsnpF',
#  '3a6PN6BRB8PP3ms48s7kU1',
#  '2MERKuoczzjTDqEbgsB48J',
#  '7cMFjxhbXBpOlais7KMF3j',
#  '2egGsu9X7zdNJxU9Kftq6l',
#  '3WrhludE014mFOLpDRVbH5',
#  '5lYpHO6ZO4Shys3GD8rav6',
#  '41dDygR3r7e926oGUXfrLt',
#  '0j2T0R9dR9qdJYsB7ciXhf',
#  '07iyEskDCwWEhQ7F0rk34d',
#  '68Wj3g73FAl8Q22q9vO6Fw',
#  '28H3wOEKsaEa8NBEYCLl4j',
#  '6aBUnkXuCEQQHAlTokv9or',
#  '1hHGUdFaiJHw9hVZGJWYO2',
#  '1M4OcYkxAtu3ErzSgDEfoi',
#  '4MLBqAEzNN89o2M9h92Z26',
#  '1g3ErLqysBJ5EIGdYYMWFZ',
#  '0ofHAoxe9vBkTCp2UQIavz',
#  '5Wj1rJnCLpMHdLaxsFtJLs',
#  '7fLTytvnvxy653VWxflTRf',
#  '5qGgBEPQgOEnfL1wN0fzQj',
#  '7yMiX7n9SBvadzox8T5jzT',
#  '1AAYbsAIgEJMbxgLgpjE9y',
#  '1SAkL1mYNJlaqnBQxVZrRl',
#  '1pUsdir2xhSxP0RyBe9lLH',
#  '7mjNEIhe8lRG9sbwM5su3M',
#  '5e9TFTbltYBg2xThimr0rU',
#  '4pnIUqhf1AQMFrJPd4BbrT',
#  '1vQxicuNSODoBECPMFjHMG',
#  '4fUU9WKxEgJXyrZJsUA2iP',
#  '07GvNcU1WdyZJq3XxP0kZa',
#  '393MDhe62s8hbH8ETrlxe5',
#  '1dvOwoHwZB9SwvRw2Gv3nz',
#  '5JJDu0Z5DKe7mR31MGksSg',
#  '02ZdZqhpfrPnxwyakXgxB8',
#  '17KFO56mkVEKR0v8qOPlkU',
#  '3IvTwPCCjfZczCN2k4qPiH',
#  '2lP7CnBYhKaOIBGxHqARRR',
#  '2dgrYdgguVZKeCsrVb9XEs',
#  '0q6LuUqGLUiCPP1cbdwFs3',
#  '3NEjuId3qYDT482ykUBbeI',
#  '1RUTIdTnFs8lHSc0Zr4UJB',
#  '1NHd4UVxT5d5EGYzlDq17T',
#  '5IFCyWplye09HytIP80RCF',
#  '0MyY4WcN7DIfbSmp5yej5z',
#  '1lNRVjK8MukRZpeurYssIx',
#  '3WibbMr6canxRJXhNtAvLU',
#  '4Bjwyj8KM85xblkSt5A24j',
#  '0IedgQjjJ8Ad4B3UDQ5Lyn',
#  '2WxVxmxKgXTgvQaRmAG4ub',
#  '01JIBiK28WrG4TVANW8hJY',
#  '3ptikEjKbpbXvJtOosLMuH',
#  '1x1XQqhBViz4opcpwc7FVs',
#  '2yBVeksU2EtrPJbTu4ZslK',
#  '5ClqcvP4dYDDX6Zv3jPQD1',
#  '1UJNbgfTzG1gZZTWFJdMf1',
#  '6V7SBJsDG9B4iVywka4koo',
#  '7M3E3patpaJZ5nwOtn9WPy',
#  '7nYvUtkQMx1v80S2FH2s9J',
#  '1jsdtlKxAPYSVKwqsIJGLb',
#  '48ZUwXrEOhaXLCxvmRYhZv',
#  '7v9Q0dAb9t7h8gJOkcJHay',
#  '0xwkyhdYcYaDnxrwZditrc',
#  '1JDIArrcepzWDTAWXdGYmP',
#  '3Vby4nGmtbDo7HDJamOWkT',
#  '67xBtV07CC73eFw7z5oCvU',
#  '4HA2jo7wkMdN1lmLO6ryzE',
#  '19Shlms2uTnOjIUg50TXzd',
#  '3OOFEF20WqtsUPcRbPY3L7',
#  '3s44Qv8x974tm0ueLexMWN',
#  '51pshtuYkgUQnt5huMPbKL',
#  '4wqzOaLxiCRy2Et8tRyNSX',
#  '2xQShwyOMYlX10w8dxbFX1',
#  '2AziR5bWTpniyTm2GQNer7',
#  '25AvaE23MXl06YRtQcQoJS',
#  '1hHGUdFaiJHw9hVZGJWYO2',
#  '30KctD1WsHKTIYczXjip5a',
#  '05oETzWbd4SI33qK2gbJfR',
#  '0Kdj7nwaYQmvhxnqZaIQuW',
#  '0DiWol3AO6WpXZgp0goxAV',
#  '393MDhe62s8hbH8ETrlxe5',
#  '2yBVeksU2EtrPJbTu4ZslK',
#  '7av3s72hOwmgzA2VE5pWDa',
#  '6iX1QW1gGIVNEItnqyvFfH',
#  '6MWH4pJQ5QYjidX2A2KECd',
#  '3H3cOQ6LBLSvmcaV7QkZEu',
#  '7d8dqy6GbiUqotcTSs0jXg',
#  '5ZLzl6T8JwqMTMdoE0nCbU',
#  '20bJBbPapGQ4bqs0YcA9xY',
#  '7v9Q0dAb9t7h8gJOkcJHay',
#  '1dqC5KuAYE3bRxeSEeVDF6',
#  '254bXAqt3zP6P50BdQvEsq',
#  '1cdC9TCqyLwAlsw3fVJaJS',
#  '5W3cjX2J3tjhG8zb6u0qHn',
#  '6NBAtnU5ICF7fazEFn2hKL',
#  '19Ym5Sg0YyOCa6ao21bdoG',
#  '1xzUQMiCoY5pdego0pHMeV',
#  '171PWhxgdrIOgcAiBPO3Gr',
#  '3ymKC2QCBeN3hMseX2hUYm',
#  '1XXimziG1uhM0eDNCZCrUl',
#  '77fcAXl6MsFPtFJG45zTUE',
#  '1pEyysRo6PylWXG17v7IDE',
#  '3whAYGfFH2hezD9L9B2oH0',
#  '5taqLrLouA4vCjM7ZQpEtW',
#  '2dgrYdgguVZKeCsrVb9XEs',
#  '6j9Aw31ggzn1Y8PEykeREw',
#  '7uCq4vBPffjaTMlE8EQzJD',
#  '0P7DoyGrr4Wp9w5TotEtUC',
#  '5Wj1rJnCLpMHdLaxsFtJLs',
#  '3jyWPW2PBQGZ9Ebn97suLx',
#  '4qMHIhPg0PdAxGejImhYLu',
#  '4JwjzS9WFkWlpzGCwh82fn',
#  '3wQaW4rEZe7AaDrlrX4eDy',
#  '4Jp5pt7xrG2DLkUtUtqhzl',
#  '2JpoMxTbzx4xbGT81AnPQI',
#  '3zMvotMEQK3xvH01vA9wAP',
#  '6hPSal3ragmfUt1I5mKZjn',
#  '6aBUnkXuCEQQHAlTokv9or',
#  '5kj1lUmBqeEjuLeVqhMRTG',
#  '0dEIca2nhcxDUV8C5QkPYb',
#  '5bkhrGvabAPrugPUm7DvsD',
#  '4MLBqAEzNN89o2M9h92Z26',
#  '4lC0p6LexMrLx7kWUJcNwM',
#  '2VEZx7NWsZ1D0eJ4uv5Fym',
#  '7HQUto39ZFkvGI9q4kRUnN',
#  '41dDygR3r7e926oGUXfrLt',
#  '2qfaDeZhoz8dQJJPle017z',
#  '6vuPZX9fWESg5js2JFTQRJ',
#  '0s1aSsYlLIEiy16LjFWbdp',
#  '0bRXwKfigvpKZUurwqAlEh',
#  '7kK9h00nOXVagkOCXPcBxx',
#  '62r1CS9zL1FL5Ilb7hLX7n',
#  '7uPmQttafLiJyju14JREY4',
#  '1NeLwFETswx8Fzxl2AFl91',
#  '2vA6RftF4o7N95ifeRyJ2z',
#  '30St98Bok3jJmXdkkHVPQe',
#  '2EHEQx2avP1fNBLJf5UGYy',
#  '0oks4FnzhNp5QPTZtoet7c',
#  '47emsK4Cj4dMqctYq18U03',
#  '5NhlpQ6BOIz3S5welptk1W',
#  '246SdvVYT3yrZPXU7NSWwy',
#  '2cGxRwrMyEAp8dEbuZaVv6',
#  '6tfPsgvkgbGHWGwq2PpzCI',
#  '3lh3iiiJeiBXHSZw6u0kh6',
#  '52IuMfbQa9aqRPz2oYPAI8',
#  '63JXZZRbmzooashakb0zbu',
#  '6jNi0f1BiBHi1lK1Wwy9Oi',
#  '3nFJbZCHP4d9vduKjJLdBL',
#  '2pucDx5Wyz9uHCou4wntHa',
#  '098ttCNmncrO4YvqWUNMvn',
#  '1e0GOPXzW5b6W7S4BSE6d8',
#  '6gyaXDZS45uIpyETSTibQ9',
#  '10vS4ZLi4XWlIsNXSQXgqh',
#  '2LD2gT7gwAurzdQDQtILds',
#  '7M7AwtGvWdMYudqx5Iuh1m',
#  '5FEXPoPnzueFJQCPRIrC3c',
#  '4IAE7M8Qw88f59W0uqNujJ',
#  '4npMbTuxrUA3Wd7edACZ2L',
#  '76TpWFiK5YCgw1hy26DWZp',
#  '5iSEsR6NKjlC9SrIJkyL3k',
#  '4lJ6YVXQ0jUk5ILu0PSrA4',
#  '0IedgQjjJ8Ad4B3UDQ5Lyn',
#  '3LklW07tvdx2AHsgfi1Mng',
#  '3ABG1UQTk0eLYUAeWkmfMi',
#  '3dmqIB2Qxe2XZobw9gXxJ6',
#  '186hvCTyrni4KT9nwIQ7zS',
#  '4uQ7wYsuL0DryknoDc11Hk',
#  '1tPEhOQMRKHeWn7nJwUkqO',
#  '6P9uVc2SxCOAiextf4udxk',
#  '7cMFjxhbXBpOlais7KMF3j',
#  '2OoycVJuLzp545g5I22uBW',
#  '3QcuZo6WLcFkqqLmDs0d95',
#  '6vQ2e6wFGceHdm4f3W5XR6',
#  '1Qa0Y05al633fG8f9Peytc',
#  '4yugZvBYaoREkJKtbG08Qr',
#  '3dIJANgsuLPXCpfZ0kUYOd',
#  '53VtetboNPxzMGQ02ftxLR',
#  '5Zyv0v4rPcrXjkaeImuodv',
#  '4vBfS5bYpT7oeDpva8V3wV',
#  '1fMGRxKRtIKNyaMMGrzInM',
#  '436yrzQWA32vb1sTZKXg9r',
#  '5fPgEQlqlMa83hZRlrerFH',
#  '4F1AgKpuFRMLEgtPETVwZk',
#  '0uco0wQkB909zpPlHvu5Cc',
#  '3gdewACMIVMEWVbyb8O9sY',
#  '1CM1wOqD2AIjt2MWd31LV2',
#  '6QvgyZ8xG2OFGjZsH3s8d3',
#  '2S7hH8gCuwlqL8vqia3eJp',
#  '1hKDXDtgKCgdVi0L6wtXN0',
#  '5H6Jp0syB5yEPk7SWYdlmk',
#  '5TkpSHwCFS0wlovQe7TA6T',
#  '57jPG8TAQGEZCxLraVWdEV',
#  '5HWQcpb5SL8IxSZjy8LVpY',
#  '5UlGHbddHJjdRqaZF6OecR',
#  '1x1XQqhBViz4opcpwc7FVs',
#  '3XxBSvDZKH5YvZZjTpn6eR',
#  '4ZNcd1iiFpRe1OoTVXPqgy',
#  '2iAe3yqQ5QYX8SI1iF4kJ6',
#  '4Gmdm6oRVwJgsM8gYnwRoE',
#  '0NnuQYRXNIzncgftfbTV3P',
#  '5xAZDlzqvI1wflhB4mzYoz',
#  '4WiB9ZqUmKU1xJzbn5kh8Y',
#  '3f5JtAsGRIXN8pSAeTi6vA',
#  '18a9EGG4xhRELv7bgAw5hb',
#  '5jCPgpW81gnLJcoYQhFEoZ',
#  '2XKmdfgJ1ev92dhxGc9Eky',
#  '5BYIir2GcICaFUWMFkUhyV',
#  '0NN32Knbyo4gM1DKY9rdzg',
#  '4m6KlFD4eMiQFzh4IVVFVm',
#  '3IvTwPCCjfZczCN2k4qPiH',
#  '35jXTF1ALlzkrS2k1B5dkF',
#  '3isxH73IAtslp0gEftrwoD',
#  '23DgBX8Q1n4GW2jN3qSSxn',
#  '72i08olb2JviCg1ggLzaWs',
#  '4DmBVImaIhE3RyNvbtZTTz',
#  '0ipGD86bKFARjKvVnOu6QW',
#  '7GZ1KaMcHyak0Csx9w078c',
#  '0jnXNaf1SFUucJtrGPvTv5',
#  '4ZKgPZ9d4V5WW6H2s4qMD3',
#  '1DmsXjXTjqQZ3kRl4yLvMw',
#  '7cMFjxhbXBpOlais7KMF3j',
#  '1pUsdir2xhSxP0RyBe9lLH',
#  '33yAEqzKXexYM3WlOYtTfQ',
#  '49X0LAl6faAusYq02PRAY6',
#  '2cGxRwrMyEAp8dEbuZaVv6',
#  '1QR7ARTB6WdrX4eQxAqJUI',
#  '0MyY4WcN7DIfbSmp5yej5z',
#  '3a6PN6BRB8PP3ms48s7kU1',
#  '0DiWol3AO6WpXZgp0goxAV',
#  '2eGHyarZyRvUgFI4d3G8GN',
#  '1xNcBAoUw8Hz6LqK2jt4Ff',
#  '2Foc5Q5nqNiosCNqttzHof',
#  '0U0ldCRmgCqhVvD6ksG63j',
#  '72MoCPAnz0UljAVmwHHw3Y',
#  '7z8sOQkzkoT9SCYQSWenjs',
#  '5QzBm2RCJ9R6yAAFT7rH5Y',
#  '3H3cOQ6LBLSvmcaV7QkZEu',
#  '4Hff1IjRbLGeLgFgxvHflk',
#  '0dEIca2nhcxDUV8C5QkPYb',
#  '0Ct2XTT4UBt9Y196i0Ido2',
#  '1eyzqe2QqGZUmfcPZtrIyt',
#  '1pKYYY0dkg23sQQXi0Q5zN',
#  '0ABUwW2eGGtBMc696DHGkk',
#  '3SfSYQLgcrGajPkU5EEr2E',
#  '2YNJ2wMRwl2L2cudMQ0B6N',
#  '5W3cjX2J3tjhG8zb6u0qHn',
#  '0q6LuUqGLUiCPP1cbdwFs3',
#  '7d7l6Qnbnqv9nkuHrh6p1N',
#  '5CMjjywI0eZMixPeqNd75R',
#  '3Q6mwJseOFYBJ10d5CXp4o',
#  '02CsNQg3AKP7OdDmzzDWc5',
#  '4i7HrBTsaocmoNPoifG7Bd',
#  '3Nxw6eeFpBwUbxVuSY6NC0',
#  '5pgZpHqfv4TSomtkfGZGrG',
#  '2C0KFbb4v9CNWR5c9jWcKC',
#  '5RByQFt9Mlo8hDYJ921tCv',
#  '3Pb9QabepyR9e9D8NqorPH',
#  '2LD2gT7gwAurzdQDQtILds',
#  '0WWBeDKdXmGbZD1XVOVqot',
#  '0IedgQjjJ8Ad4B3UDQ5Lyn',
#  '6LUfuyLgvgqrykiTE6sJHY',
#  '1YucFGqqoZ8nKwsHR1AOmS',
#  '7pbEKdMWHGwPQSDGfcNycM',
#  '0Jc2SfIHv63JNsUZpunh54',
#  '0kLrrh7Z1gySNTunBH790J',
#  '4zu9wo2FXoBSsKjO6tRB3R',
#  '6P0d6HGaGTbW26ngcMpdko',
#  '78H72MElkOY9cRnaudxZFY',
#  '7mCQK9YB25WZw1saUjfL4e',
#  '2VEZx7NWsZ1D0eJ4uv5Fym',
#  '5taqLrLouA4vCjM7ZQpEtW',
#  '4mrR64jwacrmiZluhBelDB',
#  '5Mtt6tZSZA9cXTHGSGpyh0',
#  '7Gc9OoiYsUrByC8tzD7kYY',
#  '25uMfMUWsdJyiaKg6NHGO5',
#  '4C7Ss9bTPOWJMh3rarF1mN',
#  '0C0OKMDnOvUyccUmwZO8AW',
#  '3WibbMr6canxRJXhNtAvLU',
#  '3RlurnnuVkVbaN6lul4136',
#  '7iEoaTyBCqLaAwJnOP1BTn',
#  '101KS2AYeWa98ltX4ewE7h',
#  '3wUX7HpXS382s1DHTRouVk',
#  '2uxudaBcJamtfgvUjSDdkZ',
#  '02RxTXoojHi7ISW3EbqdR5',
#  '4b9cdjpEqR9ufNZTLevuAD',
#  '4pynucrEEPPD3ZRQtnvjSz',
#  '4OKmlgkeGXxdnT7jVGmKbX',
#  '5ED4wu4LKC0iNR28iMtAyv',
#  '4L0jcL1W6bK1H51S5BBFLf',
#  '2maEFaoAyNjQVv14Hm4esN',
#  '6Q1TIMUFgQIiRJlPMgXKsC',
#  '6bGwKHXHNLmTy6yt147FPh',
#  '7satW8tFLasyZbftvrWFBP',
#  '3clX2NMmjaAHmBjeTSa9vV',
#  '1EjzcBTVLV7ATtdsQwyV31',
#  '0uMn8WKu3qtQLaUyal1bsz',
#  '3fgkN4IwsinmrK7gLhZW7J',
#  '6xwkCL4h1pYXqlUu68RAI6',
#  '01zffoSenvp9JnSbl0UgMa',
#  '5AKt3W3OVWidHOD8E9QR6v',
#  '0r83fnVz35a5ajGqQydqi2',
#  '4XkXgUNDVBMj3oJoE8yspZ',
#  '6Q3qFKZ4GysIFL4nVV5h78',
#  '1Jo3u8eXp8xobbrvq0FIi9',
#  '0y1mw940RjaXJ55VXFoAbM',
#  '4AH8GJVosfrbfhe5NVTAnx',
#  '2pVvB487ZwqdzTxEvEEors',
#  '39GBFwBe4GGk7i3yr3F46P',
#  '4NqA2uQZsBGBelv77weqdi',
#  '0G08twG9Snacd3TgJ2IC6r',
#  '2ouMVpv6OJglrFHg2GQPwd',
#  '736y1ZQptSw5iaMkbmvu9X',
#  '2NfIZCEXbDbt6JVYcNerCg',
#  '6Pi4SP8AG5mRVaDd08DNKZ',
#  '1AESnzWt4iMrEPGG7TjXAa',
#  '51DOzyPzT5cDii6iGSXRN2',
#  '6zPMDkXlw0BSKSdY0Ci1Uk',
#  '5OzOQRssjhxaBj0xd78Z2w',
#  '10vS4ZLi4XWlIsNXSQXgqh',
#  '4CpWJkSodVFE3HSylu7ajJ',
#  '5pHVAQ5LD3RgDG5m11r2Jt',
#  '6iX1QW1gGIVNEItnqyvFfH',
#  '4CwpuCZcK6Vym6BZd8Pgfe',
#  '3PgIhd4XmwtmV2XGU5qhzZ',
#  '1hHGUdFaiJHw9hVZGJWYO2',
#  '6Q3vfiVGy07AsbiJwRBOKO',
#  '4RUQVUxaRMwDnsUwW80xz4',
#  '10Q26DXQAlvQlnKRdZJgec',
#  '5L7iH6jMPzRP4kd0pPnnuJ',
#  '3OD2BlIAkr1DkSe94sKIoI',
#  '4euYSSvpQZSAQ4gThyL2QD',
#  '31Ch2wIS1T0ZTZf13XFvfs',
#  '6MCUdqOifrEomDtrgZlJ8O',
#  '6kpqaDEznzrlLFhPDwjNNY',
#  '2CgYegR1bxSUqANxXwss9g',
#  '4CYS95ya2r73ndgQPMo7PW',
#  '1ae0SQx8MpBXo6QsmrpsEj',
#  '3F78T25BJK5VVQN77Rg6Dh',
#  '7t51PlWUNcJQ9E2LJKRpH7',
#  '40ONribzLsYYFHgaeKPtwj',
#  '2mkz7LrEqofmv0PvcihXW7',
#  '4fmgXuPWpYamWWuB98XScd',
#  '3uvEsp3LWHowImpBbZnAtS',
#  '6l6ObuVjdZbc900Q2WgO7K',
#  '7BBg6ZpwfB1KVKEQehUbGl',
#  '0FlJda1kBtfZmyXzKnE7Pj',
#  '1IbC4e3wvgBhRQyQPDHB2r',
#  '5dVtj4IAnYSrI3jVfIFIaC',
#  '23KUlJNvJmKrRVmo3XBvxM',
#  '5gxIn3miRFZBTVCWdDAxYd',
#  '6tBnLpw8NNAIgOthHyLgHv',
#  '6whQt348abLcfqQrygz1YY',
#  '44Z1DDuoNyZuzZtcS39OJ5',
#  '7eVr2GN82f4tJQ8qj4vtju',
#  '6EbMlJZ44lJjPRsdZK64h9',
#  '0UULEN8LeXBFZ15CbtTHgR',
#  '2Kpyrta4L1lyAKznqiL14R',
#  '0YZBkk4ZTgTMZUKgjTVXMd',
#  '4hRSKLxWptKUvKF7wr60B2',
#  '4Po1WkgHeVkmLTQMVE4mm5',
#  '1oSWFvTM2TuZYBU7EbQ02T',
#  '5jIjbtrlKhRUE9Z2VbsMaA',
#  '2tKvbXiqQM7aYhbpEWLbTf',
#  '7CopJCaFaOsTrNpZanANip',
#  '4yL8wnrrF9xqzMmrudRQfl',
#  '33JZwOt4b0YpQuCYiEDP6k',
#  '4cE2TOfDBizu6mJ11M5osq',
#  '1NVlLhQzlB6c8MAsSKncft',
#  '2wpA3SMlJIIc2lmfTwfsS6',
#  '7AN22wQYwiCG49qYosygFq',
#  '00ko9WaS4jOX1kEk3gvHjf',
#  '1g3ErLqysBJ5EIGdYYMWFZ',
#  '4LvRT9c5IKxC8GHVPAAaHb',
#  '3NEjuId3qYDT482ykUBbeI',
#  '01GmGxOPy22EdAZGC0X6q1',
#  '4eAPrbLRlJQ9QbOGSqbWgY',
#  '7BL20x1o7Xp13doge3OeRP',
#  '6iX1QW1gGIVNEItnqyvFfH',
#  '1xsP6AITcWNigBYBYVnVZw',
#  '31AOj9sFz2gM0O3hMARRBx',
#  '3CA9pLiwRIGtUBiMjbZmRw',
#  '5taqLrLouA4vCjM7ZQpEtW',
#  '5LeStoyvjAHpM52IYogOq0',
#  '62r1CS9zL1FL5Ilb7hLX7n',
#  '3yrS2LaeArTQYoORGnxG8r',
#  '6KwSdmAba8BxoxVXPw70LO',
#  '67xBtV07CC73eFw7z5oCvU',
#  '0heMfPADQvvVd7aZvk7q9X',
#  '4JwjzS9WFkWlpzGCwh82fn',
#  '0s1aSsYlLIEiy16LjFWbdp',
#  '4pnIUqhf1AQMFrJPd4BbrT',
#  '68WCiBa9dfDU5PBhTl6MYe',
#  '3lh3iiiJeiBXHSZw6u0kh6',
#  '4lJ6YVXQ0jUk5ILu0PSrA4',
#  '0XPpkGBVE0QIOGSvW1nMEz',
#  '10vS4ZLi4XWlIsNXSQXgqh',
#  '6vegnfDS8DAEaCqWaPYGPy',
#  '51uTbPmQnApLyfnfn0bpC7',
#  '333OkWOgbV6C8I5wRLfuSx',
#  '733tju3KUeatsbjcTRQ04i',
#  '5Tl0HJvynZtKdSUMKbFVVX',
#  '2uxudaBcJamtfgvUjSDdkZ',
#  '1CHhAINmT48RpXE5owAo3Q',
#  '6OG1S805gIrH5nAQbEOPY3',
#  '6dr7ekfhlbquvsVY8D7gyk',
#  '7ohR0qPH6f2Vuj2pUNanJG',
#  '0QBRshHeQLEThdj2TqxM9n',
#  '4LGMSdeKOUoy5Wf75Je0Hl',
#  '71X7bPDljJHrmEGYCe7kQ8',
#  '48dojgnBKfp3drKOFdwycc',
#  '3ZLyt2ndLFBh148XRYjYYZ',
#  '2yBVeksU2EtrPJbTu4ZslK',
#  '2G9lekfCh83S0lt2yfffBz',
#  '5ihS6UUlyQAfmp48eSkxuQ',
#  '2AgnbuzvnfPvq1sAYNB4pj',
#  '44Xgp13T5ab99beJ0edP6b',
#  '4cxvludVmQxryrnx1m9FqL',
#  '1RbdVGt8TF9ovqhTOUO6MG',
#  '2Jv5zlZ7iCZP7K1j26izha',
#  '3KkXRkHbMCARz0aVfEt68P',
#  '2TK2KSrzXD6W01qjXVjNGh',
#  '6tfrMstZ8tw7nZJ6HP0PyW',
#  '7ifYhq7BzEppaiYFi28xlH',
#  '5Wj1rJnCLpMHdLaxsFtJLs',
#  '54Sc7mZQ1RM03STpk4SfaA',
#  '3Osd3Yf8K73aj4ySn6LrvK',
#  '2fl0B0OaXjWbjHCQFx2O8W',
#  '6aBUnkXuCEQQHAlTokv9or',
#  '0NJWhm3hUwIZSy5s0TGJ8q',
#  '4Li2WHPkuyCdtmokzW2007',
#  '37ufe1F2g1nOuI0z2sd6M4',
#  '5jSz894ljfWE0IcHBSM39i',
#  '3nJYcY9yvKP8Oi2Ml8brXt',
#  '2CWOMDYFK4Ef3867nEhnVM',
#  '6MHwMfBCNVCE49tBAVWNJK',
#  '0ofHAoxe9vBkTCp2UQIavz',
#  '3dP0pLbg9OfVwssDjp9aT0',
#  '2sEq2rC3ynYsT49x7utWnd',
#  '10depzcgVJIbEJepVhblzF',
#  '05oETzWbd4SI33qK2gbJfR',
#  '4RVbK6cV0VqWdpCDcx3hiT',
#  '0Iys022UwQ8xBfxE1g4nWZ',
#  '5LWprrbySabBAMm0aE447a',
#  '6lrQo6KAYvb92MGk6ZuZlt',
#  '3Dv1eDb0MEgF93GpLXlucZ',
#  '2qFIJT5hjqaNFA1GKwl9me',
#  '500qWQEycoFAUVK8ijpD5O',
#  '2W9u3whoCkQYOUbmnSrHi1',
#  '0xLRcC54BxwGkDw09zJqrS',
#  '2b9lp5A6CqSzwOrBfAFhof',
#  '0v9Wz8o0BT8DU38R4ddjeH',
#  '7EqpEBPOohgk7NnKvBGFWo',
#  '4YfNXZ97FLHFH9rHbMxfwv',
#  '1PS1QMdUqOal0ai3Gt7sDQ',
#  '4wL6dDN3b0pOtrgW8oExak',
#  '7m9XR7FquXLP1FewdAcNS9',
#  '5ClqcvP4dYDDX6Zv3jPQD1',
#  '0VaIsQoIQY10uxBrOyZ5cQ',
#  '0jx8zY5JQsS4YEQcfkoc5C',
#  '2yBMVrq96wb9OHbMdBs0lF',
#  '6nBQFAIVFmAx2oZ8p6lUg6',
#  '2pVvB487ZwqdzTxEvEEors',
#  '6m9qPYXmhge2QhBLfFKnVF',
#  '7qfoq1JFKBUEIvhqOHzuqX',
#  '2VF5TMGUFgb9D1xlqZPVFu',
#  '3tDIjnh6wdwMWDHRHF97XC',
#  '2VQc9orzwE6a5qFfy54P6e',
#  '3TfKt8mPpdXfQTMfRjHzyz',
#  '27MB0qHaYAZiTlwg25js1Y',
#  '3vrOmd6lTTKXGjaYeq8kni',
#  '0bRXwKfigvpKZUurwqAlEh',
#  '0ofHAoxe9vBkTCp2UQIavz',
#  '0qRR9d89hIS0MHRkQ0ejxX',
#  '1JQ6Xm1JrvHfvAqhl5pwaA',
#  '2eF8pWbiivYsYRpbntYsnc',
#  '7tqhbajSfrz2F7E1Z75ASX',
#  '0q21FNwES2bbtcduB6kjEU',
#  '254bXAqt3zP6P50BdQvEsq',
#  '72PoJMDfdaw9gGECgA9kTZ',
#  '6iGU74CwXuT4XVepjc9Emf',
#  '2LXISHBkx8FyoxCBkckh19',
#  '7Bz8yww6UMbTgTVLG6zbI4',
#  '5O4erNlJ74PIF6kGol1ZrC',
#  '07GvNcU1WdyZJq3XxP0kZa',
#  '7Ar4G7Ci11gpt6sfH9Cgz5',
#  '3gdewACMIVMEWVbyb8O9sY',
#  '3yrSvpt2l1xhsV9Em88Pul',
#  '4UQDZlZhGUDoYMohwrY28v',
#  '5le4sn0iMcnKU56bdmNzso',
#  '4bEb3KE4mSKlTFjtWJQBqO',
#  '3hJLKtTpgct9Y9wKww0BiR',
#  '1hQFF33xi8ruavZNyovtUN',
#  '3B0ms7Xlxl16tRztKHpcu9',
#  '6PgVDY8GTkxF3GmhVGPzoB',
#  '75FYqcxt1YEAtqDLrOeIJn',
#  '4o6BgsqLIBViaGVbx5rbRk',
#  '3zBhihYUHBmGd2bcQIobrF',
#  '1x1XQqhBViz4opcpwc7FVs',
#  '683b4ikwa62JevCjwrmfg6',
#  '4pNiE4LCVV74vfIBaUHm1b',
#  '5u6y4u5EgDv0peILf60H5t',
#  '77oU2rjC5XbjQfNe3bD6so',
#  '6vxHp3CDNo0afgKGp2yi1E',
#  '5lYpHO6ZO4Shys3GD8rav6',
#  '608xszaAxVh4m7NcKJiAbF',
#  '54eZmuggBFJbV7k248bTTt',
#  '1qRA5BS78u3gME0loMl9AA',
#  '0MHXrqn909p0LRTPsNsGEi',
#  '00pGV4EInVd77cnOIwPTCv',
#  '2BY7ALEWdloFHgQZG6VMLA',
#  '0qxYx4F3vm1AOnfux6dDxP',
#  '3kXoKlD84c6OmIcOLfrfEs',
#  '4s6LhHAV5SEsOV0lC2tjvJ',
#  '3Vby4nGmtbDo7HDJamOWkT',
#  '4C426PqeHP8XqHU5mQIAKS',
#  '2TVxnKdb3tqe1nhQWwwZCO',
#  '7i3xpu7SFWvzhGa9AZyySR',
#  '67oyFnjJnn78fZP9KjeZx0',
#  '4lJ6YVXQ0jUk5ILu0PSrA4',
#  '0vJ3Y2MnDXi4hpxSeQdQEC',
#  '68WCiBa9dfDU5PBhTl6MYe',
#  '3bOvAqhaZNSWpGVIvHEx8B',
#  '4C7Ss9bTPOWJMh3rarF1mN',
#  '4dbZObCjUs95HtmEHfKbnU',
#  '0IVAlb0cFCH1cQ974iR1TU',
#  '6gpZSI0xEMTzleBc5ykOVA',
#  '7f1UEGMBMuXfLBP5XANfrW',
#  '4heC6SnTBxTZZDef4AIBOk',
#  '2CPturRUlpvirYr7VpkXCV',
#  '52IuMfbQa9aqRPz2oYPAI8',
#  '3gRlmtdCyNoKiyozn2pqc9',
#  '1WOwGVtrVWtV3WW7X4TZoB',
#  '4sw7D73E8KHAZVQxRNJArP',
#  '2bXI4Rbw1D7aVeHWLjn1Lb',
#  '5YTM7OgQDt9EJAYcfHLniJ',
#  '7nYvUtkQMx1v80S2FH2s9J',
#  '697zIbTO0LMhupzGblYREm',
#  '7qTHHJ8MeXEKBVuopWdw4b',
#  '3Oevx9kwpDeO3vZUYqhVNO',
#  '1mIpDPCehnf3EPk6J4ZCUF',
#  '4uXmPyb5Lk6ETxnMTuvL1G',
#  '0eEXcw3JLVXcRxYrVYMy68',
#  '5SkRLpaGtvYPhw02vZhQQ9',
#  '0s46SltT4On0Z6kglK1I5c',
#  '1xIxMz1sNQ4b6svH1GuTtF',
#  '0iFOG4Ki9aDmJUYUFHQlPG',
#  '2PRsh2LNPxoxC9OnErnelg',
#  '6nz35DNIzbtj5ztpDEcW1j',
#  '1SWVDBtw6h3tm9OehOkDhv',
#  '2ey8VvW7LS4G0q9xtgEtBA',
#  '33rsCCLHklTQav9klbpnAi',
#  '6FI3RJ58Ztl0X1VtA6pVs9',
#  '6NjXLhejj5dVjTyeU8SbVM',
#  '68Wj3g73FAl8Q22q9vO6Fw',
#  '7iXF2W9vKmDoGAhlHdpyIa',
#  '3nDYsXggRQxf7PCNUjR4rz',
#  '5kDkWHFx0AEvJ1Pfm2i0ac',
#  '671sDyeE398eD0sdGuVbZU',
#  '5onGESUxi3P9xLt311oS59',
#  '2Vpj5colB0MPy3Zg5SITEC',
#  '34j4OxJxKznBs88cjSL2j9',
#  '6GbalfYyQC19uareicSK38',
#  '5ED4wu4LKC0iNR28iMtAyv',
#  '30oTS7bm0aH3p7lqjEIu8q',
#  '78A5pMXZaqVMS3mpSddsVW',
#  '3yjVsUq8psgcHm8SQrZ8i4',
#  '7wt6sMZ7RVmb4fiFXePS3K',
#  '1LM6EReMkAxuDXDF26ekl2',
#  '1B53Y95tPd4ah4FExO0egE',
#  '4gQdwwPXSXnDkUh4jYqLoC',
#  '5jkJkA8Dpu9a60s0LYfW2I',
#  '7yRKzNvEQz9cngBQhjJp7L',
#  '4kGuyWcUz59MVQB3Z9021D',
#  '0g1TBY3JUXO8fGD2iI1CM7',
#  '24GGpPxMdDvCpy9vTmDc6U',
#  '0DqU9yL6tcAKzXnJeP2kUs',
#  '1PdnJncOIXLLHOjWq6zQBE',
#  '0pH2mn7degF1qlAYpLubbi',
#  '4zrbbrx6AJ5vSltmwj93eX',
#  '31ZHADyvTbyRgQVw1u2SSW',
#  '2I7beEwUv30n9ESSlGaxQi',
#  '045TksBNi3CO5Y00Z4RqPC',
#  '1TKJu779sVM4bM1Kg0qNEF',
#  '7qLzoarYodaUHezJvndAdK',
#  '08M4RqR7inoJHlarJHv3nY',
#  '50r8xQYk7Gyo4N9mnguBWJ',
#  '56OCZENfcrmeCpufvWZd0P',
#  '1ZohRhX9Opc6uSMDYFEpFP',
#  '2qbPX1fQUyknyc7cZw2L8W',
#  '13CZCdBlWMmulnz3VV2yjv',
#  '2QgZMS7J44N1cHflkK2are',
#  '7CxYBXp6hBFnnyYm7ivNCd',
#  '6uW9fBqgj2IWaNZ7Zf6ZQD',
#  '5DvysWYH5vykA6l2PxzhjH',
#  '40468yGCyxHIbr2CWFa18s',
#  '78pcTFrKHHttuJedO00g8j',
#  '5DlGJh3S6jYf0wZAiESvwA',
#  '3RjbEoLYFuyFj4DaDhR6LA',
#  '24USzMZvsczfg3WsjUruPc',
#  '5m5k5wCQiXimPD5V4ik6VN',
#  '01gXG16eWORzNaZdTqdVWD',
#  '5Meffn7R7UxaTo7LbUjvWV',
#  '3ospmAgXO287SaBU6RV4Gw',
#  '3mFbJ6Ur7gSAAqxQaY3sbq',
#  '4qD7gLqAtSXFmS83Bj9Qyp',
#  '585SL1gwCrAsddD4iYFK2M',
#  '7yPwVv5eIzLAV6wlb5b5bn',
#  '2l9lJ9HxxXyGilNIjTdO3j',
#  '6sKHSin9KPb5mSJS0gysiv',
#  '6sq2nfadF6Riqdbb3e5k8U',
#  '0UuDmmZHUPZb24gIODPiM4',
#  '1oK3iRgQrsfVjPPCRf9KoG',
#  '069VcK8RjjzhZK3UT3A8ja',
#  '7AP03AuSv0uWp0i3ef9HaH',
#  '5V66ktMtWl2d1hmr9mspKw',
#  '0qPQYLhCwZlVQ0yyTYUSTe',
#  '62kqshOHXpzRjnjU32j3tk',
#  '34ENpx8bYPgYCTSTtRMcCC',
#  '43QCn1fqNpaVllvjNXx5eX',
#  '44swRdyN58zo6GzdRtHcub',
#  '5P0RMEJOgtGcZIq5wYjYei',
#  '4d2YgepBRyYjr1EXM6slZq',
#  ...]

# %%
playlist_tracks[0]['track']['id']
playlist_tracks[0]["track"]["name"]
playlist_tracks[0]["track"]["artists"][0]["name"]
playlist_tracks[0]["track"]["artists"][0]["id"]
# Out:
# '4EVpmkEwrLYEg6jIsiPMIb'
